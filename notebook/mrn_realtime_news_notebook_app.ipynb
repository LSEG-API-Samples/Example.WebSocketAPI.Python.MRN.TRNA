# %% [markdown]
# # WebSocket API MRN Example with Python
#
# ## Prerequisite
#
# This article/notebook is focusing on the Refinitiv Machine Readable News (MRN) data processing only. I highly recommend you check the  [WebSocket API Tutorials](https://developers.refinitiv.com/en/api-catalog/elektron/refinitiv-websocket-api/tutorials) page if you are not familiar with WebSocket API.
#
# The Tutorials page provide a step by step guide (connect, login, request data, parse data, etc) for developers who interested in developing a WebSocket application to consume real-time data from Refinitiv Real-Time.
#
#
# ## Machine Readable News Overview
#
# Refinitiv Machine Readable News (MRN) is an advanced service for automating the consumption and systematic analysis of news. It delivers deep historical news archives, ultra-low latency structured news and news analytics directly to your applications. This enables algorithms to exploit the power of news to seize opportunities, capitalize on market inefficiencies and manage event risk.
#
# MRN aims for replacing the legacy News 2K (N2_UBMS and N2_STORY).
#
# ### MRN Data behavior
#
# MRN is published over Refinitiv Real-Time using an Open Message Model (OMM) envelope in News Text Analytics domain messages. The Real-time News content set is made available over MRN_STORY RIC. The content data is contained in a FRAGMENT field that has been compressed, and potentially fragmented across multiple messages, in order to reduce bandwidth and message size.
#
# A FRAGMENT field has a different data type based on a connection type:
# * RSSL connection (RTSDK [C++](https://developers.refinitiv.com/elektron/elektron-sdk-cc)/[Java](https://developers.refinitiv.com/elektron/elektron-sdk-java)): BUFFER type
# * WebSocket connection: Base64 ascii string
#
# The data goes through the following series of transformations:
#
# 1. The core content data is a UTF-8 JSON string
# 2. This JSON string is compressed using gzip
# 3. The compressed JSON is split into a number of fragments (BUFFER or Base64 ascii string) which each fit into a single update message
# 4. The data fragments are added to an update message as the FRAGMENT field value in a FieldList envelope
#
#
# <img src="images/mrn_process.png"/>
#
# Therefore, in order to parse the core content data, the application will need to reverse this process. The WebSocket application also need to convert a received Base64 string in a FRAGMENT field to bytes data before further process this field.

# %% [markdown]
# ### MRN Data model
#
# Five fields, as well as the RIC itself, are necessary to determine whether the entire item has been received in its various fragments and how to concatenate the fragments to reconstruct the item:
# * MRN_SRC: identifier of the scoring/processing system that published the FRAGMENT
# * GUID: a globally unique identifier for the data item. All messages for this data item will have the same GUID values.
# * FRAGMENT: compressed data item fragment, itself
# * TOT_SIZE: total size in bytes of the fragmented data
# * FRAG_NUM: sequence number of fragments within a data item. This is set to 1 for the first fragment of each item published and is incremented for each subsequent fragment for the same item.
#
# A single MRN data item publication is uniquely identified by the combination of RIC, MRN_SRC, and GUID.
#
# #### Fragmentation
# For a given RIC-MRN_SRC-GUID combination, when a data item requires only a single message, then TOT_SIZE will equal the number of bytes in the FRAGMENT and FRAG_NUM will be 1.
#
# When multiple messages are required, then the data item can be deemed as fully received once the sum of the number of bytes of each FRAGMENT equals TOT_SUM. The consumer will also observe that all FRAG_NUM range from 1 to the number of the fragment, with no intermediate integers skipped. In other words, a data item transmitted over three messages will contain FRAG_NUM values of 1, 2 and 3.
#
# #### Compression
# The FRAGMENT field is compressed with gzip compression, thus requiring the consumer to decompress to reveal the JSON plain-text data in that FID.
#
# When an MRN data item is sent in multiple messages, all the messages must be received and their FRAGMENTs concatenated before being decompressed. In other words, the FRAGMENTs should not be decompressed independently of each other.
#
# The decompressed output is encoded in UTF-8 and formatted as JSON.

# %% [markdown]
# Please see a full documentation of this example application in [this article](https://developers.refinitiv.com/article/introduction-machine-readable-news-elektron-websocket-api-refinitiv).
#
# If you are not familiar with MRN concept, please visit the following resources which will give you a full explanation of the MRN data model and implementation logic:
# * [Webinar Recording: Introduction to Machine Readable News](https://developers.refinitiv.com/news#news-accordion-nid-12045)
# * [Introduction to Machine Readable News (MRN) with Enterprise Message API (EMA)](https://developers.refinitiv.com/article/introduction-machine-readable-news-mrn-elektron-message-api-ema).
# * [MRN Data Models and Refinitiv Real-Time Implementation Guide](https://developers.refinitiv.com/elektron/elektron-sdk-java/docs?content=8736&type=documentation_item).
# * [Machine Readable News (MRN) & N2_UBMS Comparison and Migration Guide](https://developers.refinitiv.com/article/machine-readable-news-mrn-n2_ubms-comparison-and-migration-guide).

# %%
# #uncomment if you do not have requests and websocket-client (version 0.49 and above) installed\n
# #Install requests and websocket-client packages in a current Jupyter kernal\n

import sys

# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install websocket-client

# %%
import time
import getopt
import socket
import json
import websocket
import threading
from threading import Thread, Event
import base64
import zlib

# %%
# ADS connection variables

hostname = '127.0.0.0'
port = '15000'
user = 'root'
app_id = '256'
position = socket.gethostbyname(socket.gethostname())
login_id = 1

# %%
# WebSocket connections Variables

web_socket_app = None
web_socket_open = False
_news_envelopes = []

# keeps decompress news JSON messaage
_news_messages = []

# %% [markdown]
# ### MRN Process Code
#
# The MRN data can be subscribed with the *NewsTextAnalytics* domain and MRN-specific RIC name as following:
# - *MRN_STORY*: Real-time News
# - *MRN_TRNA*: News Analytics: Company and C&E assets
# - *MRN_TRNA_DOC*: News Analytics: Macroeconomic News & events
# - *MRN_TRSI*: News Sentiment Indices

# %%
# MRN variables

mrn_domain = 'NewsTextAnalytics'
mrn_item = 'MRN_STORY'

def send_mrn_request(ws):
    """ Create and send MRN request """
    mrn_req_json = {
        'ID': 2,
        "Domain": mrn_domain,
        'Key': {
            'Name': mrn_item
        }
    }

    ws.send(json.dumps(mrn_req_json))
    print("SENT:")
    print(json.dumps(mrn_req_json, sort_keys=True, indent=2, separators=(',', ':')))

# %% [markdown]
# ### Initial Refresh Message
# The Initial Refresh response does not contain any NTA data, all the fields related to news item and fragment are empty or 0. It contains only the relevant feed related or other static Fields.
#
# The application can just print out each incoming field data in a console for informational purpose or just ignore it.

# %%
# Process FieldList, Refresh and Status messages.

def decodeFieldList(fieldList_dict):
    for key, value in fieldList_dict.items():
        print("Name = %s: Value = %s" % (key, value))

def processRefresh(ws, message_json):

    print("RECEIVED: Refresh Message")
    decodeFieldList(message_json["Fields"])

def processStatus(ws, message_json):  # process incoming status message
    print("RECEIVED: Status Message")
    print(json.dumps(message_json, sort_keys=True, indent=2, separators=(',', ':')))

# %% [markdown]
# ### MRN News Update messages Process Code
#
# The updates contain only fields related to the item and the fragment. They do not contain any of the static or per-feed fields. The updates are not cached or conflated.
#
# #### First Update
# The first update contains all the fields related to the item and the first fragment, subsequent updates only contain the fields relating to the fragment they contain. The FRAG_NUM FID is set to 1 for the first Update of each item and is incremented in each subsequent Update for that item. This allows you to you to detect a missing fragment (and ensure correct order of the fragments for re-assembly).
#
#
# #### Subsequent Update and Multi Fragment Items
# The subsequent update contains the fields necessary to identify the MRN data item, the order of this fragment among all the fragments for this item, and the fragment itself. The other point to note is that (for a Multi fragment item), Update messages with FRAG_NUM >1 will have fewer FIDs as the metadata is included in the first Update message (FRAG_NUM=1) for that item
#
# #### News Fragments simple handle logic
#
#
# <img src="images/mrn_flow_reconstruct.png"/>

# %%
def processMRNUpdate(ws, message_json):  # process incoming News Update messages

    fields_data = message_json["Fields"]
    # Dump the FieldList first (for informational purposes)
    # decodeFieldList(message_json["Fields"])

    # declare variables
    tot_size = 0
    guid = None

    try:
        # Get data for all requried fields
        fragment = base64.b64decode(fields_data["FRAGMENT"])
        frag_num = int(fields_data["FRAG_NUM"])
        guid = fields_data["GUID"]
        mrn_src = fields_data["MRN_SRC"]

        #print("GUID  = %s" % guid)
        #print("FRAG_NUM = %d" % frag_num)
        #print("MRN_SRC = %s" % mrn_src)

        if frag_num > 1:  # We are now processing more than one part of an envelope - retrieve the current details
            guid_index = next((index for (index, d) in enumerate(
                _news_envelopes) if d["guid"] == guid), None)
            envelop = _news_envelopes[guid_index]
            if envelop and envelop["data"]["mrn_src"] == mrn_src and frag_num == envelop["data"]["frag_num"] + 1:
                print("process multiple fragments for guid %s" %
                      envelop["guid"])

                #print("fragment before merge = %d" % len(envelop["data"]["fragment"]))

                # Merge incoming data to existing news envelop and getting FRAGMENT and TOT_SIZE data to local variables
                fragment = envelop["data"]["fragment"] = envelop["data"]["fragment"] + fragment
                envelop["data"]["frag_num"] = frag_num
                tot_size = envelop["data"]["tot_size"]
                print("TOT_SIZE = %d" % tot_size)
                print("Current FRAGMENT length = %d" % len(fragment))

                # The multiple fragments news are not completed, waiting.
                if tot_size != len(fragment):
                    return None
                # The multiple fragments news are completed, delete assoiclate GUID envelop
                elif tot_size == len(fragment):
                    del _news_envelopes[guid_index]
            else:
                print("Error: Cannot find fragment for GUID %s with matching FRAG_NUM or MRN_SRC %s" % (
                    guid, mrn_src))
                return None
        else:  # FRAG_NUM = 1 The first fragment
            tot_size = int(fields_data["TOT_SIZE"])
            print("FRAGMENT length = %d" % len(fragment))
            # The fragment news is not completed, waiting and add this news data to envelop object.
            if tot_size != len(fragment):
                print("Add new fragments to news envelop for guid %s" % guid)
                _news_envelopes.append({  # the envelop object is a Python dictionary with GUID as a key and other fields are data
                    "guid": guid,
                    "data": {
                        "fragment": fragment,
                        "mrn_src": mrn_src,
                        "frag_num": frag_num,
                        "tot_size": tot_size
                    }
                })
                return None

        # News Fragment(s) completed, decompress and print data as JSON to console
        if tot_size == len(fragment):
            print("decompress News FRAGMENT(s) for GUID  %s" % guid)
            decompressed_data = zlib.decompress(fragment, zlib.MAX_WBITS | 32)
            
            json_news = json.loads(decompressed_data)
            _news_messages.append(json_news)
            print("News = %s" % json_news)

    except KeyError as keyerror:
        print('KeyError exception: ', keyerror)
    except IndexError as indexerror:
        print('IndexError exception: ', indexerror)
    except binascii.Error as b64error:
        print('base64 decoding exception:', b64error)
    except zlib.error as error:
        print('zlib decompressing exception: ', error)
    # Some console environments like Windows may encounter this unicode display as a limitation of OS
    except UnicodeEncodeError as encodeerror:
        print("UnicodeEncodeError exception. Cannot decode unicode character for %s in this enviroment: " %
              guid, encodeerror)
    except Exception as e:
        print('exception: ', sys.exc_info()[0])

# %% [markdown]
# ### JSON-OMM Process functions

# %%
def process_message(ws, message_json):
    """ Parse at high level and output JSON of message """
    message_type = message_json['Type']

    if message_type == "Refresh":
        if "Domain" in message_json:
            message_domain = message_json["Domain"]
            if message_domain == "Login":
                process_login_response(ws, message_json)
            elif message_domain:
                processRefresh(ws, message_json)
    elif message_type == "Update":
        if "Domain" in message_json and message_json["Domain"] == mrn_domain:
            processMRNUpdate(ws, message_json)
    elif message_type == "Status":
        processStatus(ws, message_json)
    elif message_type == "Ping":
        pong_json = {'Type': 'Pong'}
        ws.send(json.dumps(pong_json))
        print("SENT:")
        print(json.dumps(pong_json, sort_keys=True,
                         indent=2, separators=(',', ':')))


def process_login_response(ws, message_json):
    """ Send item request """
    send_mrn_request(ws)


def send_login_request(ws):
    """ Generate a login request from command line data (or defaults) and send """
    login_json = {
        'ID': 1,
        "Domain": 'Login',
        'Key': {
            'Name': '',
            'Elements': {
                'ApplicationId': '',
                'Position': ''
            }
        }
    }

    login_json['Key']['Name'] = user
    login_json['Key']['Elements']['ApplicationId'] = app_id
    login_json['Key']['Elements']['Position'] = position

    ws.send(json.dumps(login_json))
    print("SENT:")
    print(json.dumps(login_json, sort_keys=True, indent=2, separators=(',', ':')))

# %% [markdown]
# ### WebSocket Process functions

# %%
def on_message(ws, message):
    """ Called when message received, parse message into JSON for processing """
    print("RECEIVED: ")
    message_json = json.loads(message)
    print(json.dumps(message_json, sort_keys=True, indent=2, separators=(',', ':')))

    for singleMsg in message_json:
        process_message(ws, singleMsg)
        
def on_error(ws, error):
    """ Called when websocket error has occurred """
    print(error)
    
def on_close(ws):
    """ Called when websocket is closed """
    global web_socket_open
    print("WebSocket Closed")
    web_socket_open = False
    
def on_open(ws):
    """ Called when handshake is complete and websocket is open, send login """

    print("WebSocket successfully connected!")
    global web_socket_open
    web_socket_open = True
    send_login_request(ws)

if __name__ == "__main__":
    # Start websocket handshake
    ws_address = "ws://{}:{}/WebSocket".format(hostname, port)
    print("Connecting to WebSocket " + ws_address + " ...")
    web_socket_app = websocket.WebSocketApp(ws_address, header=['User-Agent: Python'],
                                            on_message=on_message,
                                            on_error=on_error,
                                            on_close=on_close,
                                            subprotocols=['tr_json2'])
    web_socket_app.on_open = on_open

    # Event loop
    #wst = threading.Thread(target=web_socket_app.run_forever)
    wst = threading.Thread(target=web_socket_app.run_forever, kwargs={'sslopt': {'check_hostname': False}})
    wst.start()

    time.sleep(30)
    web_socket_app.close()
# Out:
# Connecting to WebSocket ws://172.20.33.30:15000/WebSocket ...
# WebSocket successfully connected!
# SENT:
# {
#   "Domain":"Login",
#   "ID":1,
#   "Key":{
#     "Elements":{
#       "ApplicationId":"256",
#       "Position":"10.42.85.159"
#     },
#     "Name":"root"
#   }
# }
# RECEIVED:
# [
#   {
#     "Domain":"Login",
#     "Elements":{
#       "MaxMsgSize":61430,
#       "PingTimeout":30
#     },
#     "ID":1,
#     "Key":{
#       "Elements":{
#         "AllowSuspectData":1,
#         "ApplicationId":"256",
#         "ApplicationName":"ADS",
#         "Position":"10.42.85.159",
#         "ProvidePermissionExpressions":1,
#         "ProvidePermissionProfile":0,
#         "SingleOpen":1,
#         "SupportBatchRequests":7,
#         "SupportEnhancedSymbolList":1,
#         "SupportOMMPost":1,
#         "SupportOptimizedPauseResume":1,
#         "SupportPauseResume":1,
#         "SupportStandby":1,
#         "SupportViewRequests":1
#       },
#       "Name":"root"
#     },
#     "State":{
#       "Data":"Ok",
#       "Stream":"Open",
#       "Text":"Login accepted by host apis30."
#     },
#     "Type":"Refresh"
#   }
# ]
# SENT:
# {
#   "Domain":"NewsTextAnalytics",
#   "ID":2,
#   "Key":{
#     "Name":"MRN_STORY"
#   }
# }
# RECEIVED:
# [
#   {
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-22",
#       "CONTEXT_ID":3752,
#       "DDS_DSO_ID":4232,
#       "FRAGMENT":null,
#       "FRAG_NUM":1,
#       "GUID":null,
#       "MDUTM_NS":null,
#       "MDU_DATE":null,
#       "MDU_V_MIN":null,
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "PROD_PERM":10001,
#       "RDN_EXCHD2":"MRN",
#       "RECORDTYPE":30,
#       "SPS_SP_RIC":".[SPSML2L1",
#       "TIMACT_MS":57465837,
#       "TOT_SIZE":0
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEAAc",
#     "Qos":{
#       "Rate":"TickByTick",
#       "Timeliness":"Realtime"
#     },
#     "SeqNumber":12974,
#     "State":{
#       "Data":"Ok",
#       "Stream":"Open",
#       "Text":"All is well"
#     },
#     "Type":"Refresh"
#   },
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"EMb1KjZDa_2002262Je3uTjOcmNbJG7PEirObUNskkTO4qvn+HGd8E",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32982500,
#       "TOT_SIZE":1238
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBhbEjYc",
#     "SeqNumber":12990,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# RECEIVED: Refresh Message
# Name = PROD_PERM: Value = 10001
# Name = ACTIV_DATE: Value = 2020-02-22
# Name = RECORDTYPE: Value = 30
# Name = RDN_EXCHD2: Value = MRN
# Name = TIMACT_MS: Value = 57465837
# Name = GUID: Value = None
# Name = CONTEXT_ID: Value = 3752
# Name = DDS_DSO_ID: Value = 4232
# Name = SPS_SP_RIC: Value = .[SPSML2L1
# Name = MRN_V_MAJ: Value = 2
# Name = MRN_TYPE: Value = STORY
# Name = MDU_V_MIN: Value = None
# Name = MDU_DATE: Value = None
# Name = MRN_V_MIN: Value = 10
# Name = MRN_SRC: Value = HK1_PRD_A
# Name = MDUTM_NS: Value = None
# Name = FRAG_NUM: Value = 1
# Name = TOT_SIZE: Value = 0
# Name = FRAGMENT: Value = None
# FRAGMENT length = 1238
# decompress News FRAGMENT(s) for GUID  EMb1KjZDa_2002262Je3uTjOcmNbJG7PEirObUNskkTO4qvn+HGd8E
# News = {'altId': 'nEMb1KjZDa', 'audiences': ['NP:DNP', 'NP:PX'], 'body': ' KOMISJA NADZORU FINANSOWEGO  \n\n \n\n  Raport bieżący nr 8 / 2020  \n\n  \n\n Data sporządzenia:  2020-02-26          \n\n Skrócona nazwa emitenta          \n\n GETBACK S.A.  \n\n Temat           \n\n Uprawomocnienie postanowienia Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu Wydział\n\nVIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r. o\n\nzatwierdzeniu Układu  \n\n Podstawa prawna         \n\n Art. 17 ust. 1 MAR - informacje poufne.\n\n  \n\n Treść raportu:          \n\n Zarząd GetBack S.A. w restrukturyzacji (Emitent) informuje, iż powziął informację o wydaniu w\n\ndniu 24 lutego 2020 r. przez Sąd Rejonowy dla Wrocławia-Fabrycznej we Wrocławiu w sprawie o sygn.\n\nakt VIII Gz 1/20, VIII GRp 4/18 postanowienia o oddaleniu zażalenia wierzyciela (Postanowienie) na\n\npostanowienie z dnia 30 grudnia 2019 r. o odrzuceniu zażalenia wierzyciela na postanowienie o\n\nzatwierdzeniu układu z dnia 6 czerwca 2019 r., o którym Emitent informował raportem bieżącym nr\n\n1/2020 z dnia 15 stycznia 2020 r. \n\nPostanowienie to nie podlega zaskarżeniu, stało się zatem prawomocne, skuteczne i wykonalne z\n\ndniem 24 lutego 2020 roku. Zażalenie było ostatnim rozpoznawanym przez Sąd zażaleniem\n\nwierzyciela w postępowaniu o zatwierdzenie układu Emitenta. \n\n \n\nPowyższe oznacza, iż postanowienie Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu\n\nWydział VIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r.\n\no zatwierdzeniu Układu uprawomocniło się.\n\n \n\nPodpisy osób reprezentujących Emitenta \n\n  \n\n', 'firstCreated': '2020-02-26T09:09:42.404Z', 'headline': 'GETBACK SPÓŁKA AKCYJNA W RESTRUKTURYZACJI - Uprawomocnienie postanowienia Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu Wydział VIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r. o zatwierdzeniu Układu', 'id': 'EMb1KjZDa_2002262Je3uTjOcmNbJG7PEirObUNskkTO4qvn+HGd8E', 'instancesOf': [], 'language': 'pl', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:EMIT', 'pubStatus': 'stat:usable', 'subjects': ['B:125', 'B:126', 'B:127', 'B:131', 'B:1627', 'B:261', 'B:262', 'G:1', 'G:5Y', 'G:A', 'G:B', 'G:B2', 'M:1QD', 'M:1WN', 'M:32', 'M:3H', 'M:Z', 'R:GBK.WA', 'N2:BISV', 'N2:BISV08', 'N2:BSVC', 'N2:CEEU', 'N2:CMPNY', 'N2:COMFN', 'N2:COMFN1', 'N2:EEU', 'N2:EMRG', 'N2:EUROP', 'N2:EUROPE', 'N2:FINS', 'N2:FINS08', 'N2:LPL', 'N2:NEWR', 'N2:PL', 'N2:REG', 'N2:SRVCS', 'P:5043324169'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:42.404Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"AWP8CFT3W_2002262u3xFn5ECgD+niT/e1JTl7mPpvSAZdiS5mxS0k",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32984209,
#       "TOT_SIZE":408
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBJM",
#     "SeqNumber":13006,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 408
# decompress News FRAGMENT(s) for GUID  AWP8CFT3W_2002262u3xFn5ECgD+niT/e1JTl7mPpvSAZdiS5mxS0k
# News = {'altId': 'nAWP8CFT3W', 'audiences': ['NP:AWP'], 'body': '\n\n', 'firstCreated': '2020-02-26T09:09:44.115Z', 'headline': '***Volatilitätsindex VSMI +18% auf höchsten Stand seit Anfang 2019', 'id': 'AWP8CFT3W_2002262u3xFn5ECgD+niT/e1JTl7mPpvSAZdiS5mxS0k', 'instancesOf': [], 'language': 'de', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:AWP', 'pubStatus': 'stat:usable', 'subjects': ['A:1', 'A:C', 'G:3', 'G:30', 'G:A', 'G:B', 'M:1QD', 'N2:CEEU', 'N2:CH', 'N2:EUROP', 'N2:EUROPE', 'N2:HOT', 'N2:LDE', 'N2:STX', 'N2:WEU'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:44.115Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"PGEQWkSLa_2002265qhxtb5gGQxcEOI1LeEjaRNOKYMUsJhBf2XUwO",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32984556,
#       "TOT_SIZE":1206
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13022,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 1206
# decompress News FRAGMENT(s) for GUID  PGEQWkSLa_2002265qhxtb5gGQxcEOI1LeEjaRNOKYMUsJhBf2XUwO
# News = {'altId': 'nPGEQWkSLa', 'audiences': ['NP:CRFEG'], 'body': 'For best results when printing this announcement, please click on link below:\nhttp://pdf.reuters.com/htmlnews/htmlnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nPGEQWkSLa\n\n\nThe UK system opened strongly undersupplied today on the combination of\nstronger demand and lower supply nominations. Nomination for LNG sendout\ndropped to 56mcm/d compared to 82mcm/d yesterday. Drop in Vesterled amid\noutage at Kollsnes and UKCS production outages at St. Fergus NSMP and Teesside\nCATs( Culzean) are important bullish factors for WD. However, we expect strong\nsurge in LNG sendout tomorrow which should \xa0provide a bearish signal for DA.\n\nStrong winds speeds which have prevented cargoes berthing at Milford Haven\nlast week are easing now . Several cargoes are lined up outside South Hook and\nDragon now. Sendout are likely to surge towards terminal’s capacity as soon\nas cargoes can berth.\n\n\n\nConclusion: \xa0Bearish \xa024.7p/th to 23.7 p/th\n\n\n\nBULLISH\n\nUndersupplied UK system this morning\n\nVestereled flows are down today and can adjust further lower on DA \xa0as outage\nat injection outage at Oseberg ends.\n\n\n\nBEARISH\n\nThe ongoing UKCS production outages should end tomorrow\n\nLNG sendout might surges tomorrow as wind speeds outside the Milford Haven are\neasing.\n\n\n\nNEUTRAL/OTHER\n\nLDZ and Gas for power consumption forecast are rougly unchanged on DA.\n\n\n\n\n\nCopyright 2002-2020, Thomson Reuters. All rights reserved.', 'firstCreated': '2020-02-26T09:09:44.457Z', 'headline': 'CRF: European Gas  NBP DA Outlook - Bearish', 'id': 'PGEQWkSLa_2002265qhxtb5gGQxcEOI1LeEjaRNOKYMUsJhBf2XUwO', 'instancesOf': [], 'language': 'en', 'messageType': 5, 'mimeType': 'text/plain', 'provider': 'NS:CRF', 'pubStatus': 'stat:usable', 'subjects': ['A:4', 'G:3', 'G:7J', 'G:A', 'M:1', 'M:1QD', 'M:A9', 'M:DB', 'M:DY', 'U:2R', 'U:C', 'U:R', 'N2:CDTY', 'N2:COM', 'N2:EUROP', 'N2:EUROPE', 'N2:GB', 'N2:LEN', 'N2:NGS', 'N2:NRG', 'N2:WEU'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:44.457Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"NDL652zt__2002262K1NP+2VftfGAe6sXFt8yoilatWSIfnTGaJsYJ",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32985440,
#       "TOT_SIZE":3008
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13038,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 2600
# Add new fragments to news envelop for guid NDL652zt__2002262K1NP+2VftfGAe6sXFt8yoilatWSIfnTGaJsYJ
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":2,
#       "GUID":"NDL652zt__2002262K1NP+2VftfGAe6sXFt8yoilatWSIfnTGaJsYJ",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13054,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid NDL652zt__2002262K1NP+2VftfGAe6sXFt8yoilatWSIfnTGaJsYJ
# TOT_SIZE = 3008
# Current FRAGMENT length = 3008
# decompress News FRAGMENT(s) for GUID  NDL652zt__2002262K1NP+2VftfGAe6sXFt8yoilatWSIfnTGaJsYJ
# News = {'altId': 'nNDL652zt', 'audiences': ['NP:PUBTA', 'NP:PUBTF'], 'body': "\nGBP\n\nSterling managed to find its footing against the US dollar yesterday and pared\nback some of its losses from last week, although this morning has bought a\nfresh patch of US dollar strength. In addition to the worsening global\ncoronavirus outbreaks, and UK-EU trade talks, the upcoming Budget next month\nis in focus for markets. This morning UK papers have begun reporting various\nbits of information, as anticipation builds. The Institute for Fiscal Studies\nsaid that the Government risked breaking election pledges to balance fiscal\nspending, and urged Chancellor Rishi Sunak to raise taxes to pay for spending.\nThe Financial Times, in the meantime, cited an unnamed Treasury official in\nreporting that big decisions on tax, spending, and borrowing would be delayed\nuntil the Autumn Statement. Instead, the Chancellor would focus on delivering\nmanifesto pledges on spending - such as a cut in corporation tax. The net\neffect of the budget is likely to be a positive fiscal impulse, the size and\nduration of which remains uncertain for now. This morning's data included the\nBritish Retail Consortium's shop price index, which fell 0.6% in February\ncompared to a year ago.\n\nEUR\n\nThe euro saw fresh highs against the dollar for the fourth consecutive day\nyesterday as US equities continued to sell off, although any calls for a large\nrally seem premature based on recent eurozone data. The eurozone continues to\nsee slower growth than the US, as well as higher sensitivity to slowing\nChinese demand, and the risk of supply chain disruption. European equities are\nstill falling after the worst two-day market decline seen in years and did not\nmanage to find momentum in yesterday morning's recovery as coronavirus cases\ncontinued to surge. Multiple first cases were discovered in Croatia and\nSwitzerland and further increases in case numbers were reported throughout the\nrest of Europe. European Central Bank Governing Council member Francois\nVilleroy de Galhau commented on the surge yesterday, stating that the outbreak\nis 'mainly a negative supply-side shock' and that 'we shouldn't overstate the\nadequacy of a monetary policy response', as it would have 'negative but\ntemporary consequences'. He added that the Bank of France was likely to revise\nFrench growth forecast of 1.1% downward in the next month. The euro seemed\nunimpressed and found no further support in Villeroy's comments. Aside from\nthe unchanged French consumer confidence and the still to be released Austrian\npurchasing managers' index, the eurozone calendar is virtually blank today.\nTomorrow, eurozone business climate and economic sentiment index of February\nwill be released at 10:00 GMT.\n\nUSD\n\nThe greenback took on some water yesterday as Monday's aggressive pricing of\ncoronavirus risk marginally unwound. The theme of dollar strength is back with\na vengeance today, however, as the CDC (centre for disease control and\nprevention) warned Americans to brace for an outbreak of the coronavirus. The\nstatement sent US 10-year yields to hit a record low overnight of 1.3055% as\ninvestors flocked for safety in the low yield environment. Despite the dollar\ntrading mixed yesterday, the theme in US equity markets was more clear cut.\nThe S&P 500 and Dow Jones Index both fell over 3%, capping the worst two days\nin the respective markets since 2015. In politics, the Democratic debate saw\nthe front-runner, Bernie Saunders, get a chunk taken out of him before the\nnext primary by all other candidates. Labelled divisive and lacking details,\nall candidates took aim at Saunders in the South Carolina debate, although no\none candidate came out on top.\n\nCAD\n\nThe loonie is struggling to retrace much of the coronavirus impact as oil\nmarkets offer little support. The Canadian dollar is set to log marginal\nlosses over the course of the month as things stand, with little stimulus to\nrev ...
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"Nen7Ncj4S_2002262uMu2mgppJLaWIY6WXVNiNQjMHvOzmhhNHcot7",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32985834,
#       "TOT_SIZE":1905
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13070,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 1905
# decompress News FRAGMENT(s) for GUID  Nen7Ncj4S_2002262uMu2mgppJLaWIY6WXVNiNQjMHvOzmhhNHcot7
# News = {'altId': 'nNen7Ncj4S', 'audiences': ['NP:NEN'], 'body': '\nBy Chong Koh Ping and Anna Isaac \n     Global stocks continued a course of steep selloffs Wednesday as concerns over the\neconomic cost of the new coronavirus gathered pace. \n     Regional indexes fell across Europe and Asia. The pan-continental Stoxx Europe 600\ndropped 2.1%, with Germany\'s DAX index leading losses with a fall of 2.2%. Both the DAX\nand Japan\'s Nikkei 225, which shed 0.8%, reached their lowest levels since October.\nAustralia\'s S&P/ASX 200 dropped 2.3% and Korea\'s Kospi retreated 1.3%. \n     U.S. futures tied to the Dow Jones Industrial Average were down nearly 1% early\nWednesday. The Dow fell nearly 900 points on Tuesday to end at its lowest level since\nOctober after U.S. health officials said they expect a wider spread of the coronavirus\nand are preparing for a potential pandemic. \n     The yield on the U.S. 10-year Treasury traded at 1.327% Wednesday. On Tuesday it\nfell as low as 1.310% on an intraday basis and settled at 1.328%, a new all-time low. \n     "The market is pricing in a significant slowdown in global growth and corporate\nearnings," said Ong Zi Yang, senior macro analyst at FSMOne.com in Singapore. "It is\nhard to quantify the economic impact now but there will definitely be a slowdown." \n     Deaths and confirmed cases of the coronavirus have continued to climb outside China\n-- notably in Italy, Iran, Japan and South Korea. Concerns among investors that the\nvirus will spread further, disrupting the global economy, has triggered two sharp\nconsecutive stock selloffs this week. \n     Federal Reserve Bank of Dallas President Robert Kaplan said Tuesday that events\nwere still too fluid around the coronavirus outbreak for the U.S. central bank to cut\nshort-term interest rates. \n     Many European and Asian benchmarks, including those in Germany, Japan, and South\nKorea are now solidly in negative territory for the year. The DAX is down 3.5% for the\nyear-to-date while Hong Kong\'s Hang Seng and the Kospi in Seoul have both declined more\nthan 5% so far in 2020, according to FactSet. \n     "This is a classic case of risk aversion," said Kelvin Tay, regional chief\ninvestment officer at UBS Global Wealth Management in Singapore, who added that markets\nwere likely to remain volatile. \n     Mr. Tay pointed to rallies in gold and U.S. government bonds, and said it was also\ndifficult for Asian markets to perform well when regional currencies were weak. \n     Elsewhere in Asia, the Hang Seng Index in Hong Kong and the Shanghai Composite both\nretreated about 0.8%. \n     In currencies, the Australian dollar fell to its lowest level against the U.S.\ndollar since March 2009. Meanwhile the ICE U.S. dollar index was up 0.1% Wednesday, with\nthe dollar up nearly 3% against other major currencies in 2020. \n     Gold hit a seven-year high this week. On Wednesday, spot gold stood 0.2% lower at\nnearly $1,650 an ounce. \n     Write to Anna Isaac at anna.isaac@wsj.com', 'firstCreated': '2020-02-26T09:09:45.807Z', 'headline': 'NIKKEI Coronavirus Concerns Fuel Fresh Selloff in Global Stocks', 'id': 'Nen7Ncj4S_2002262uMu2mgppJLaWIY6WXVNiNQjMHvOzmhhNHcot7', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:NEN', 'pubStatus': 'stat:usable', 'subjects': ['E:5', 'E:9', 'G:41', 'G:6', 'G:K', 'G:S', 'M:1QD', 'N2:ASIA', 'N2:ASXPAC', 'N2:EASIA', 'N2:ECI', 'N2:ECON', 'N2:JP', 'N2:LEN', 'N2:MCE'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:45.807Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"RTV7FX9Ll_2002265UnvtTAM1E0meSVksLTmC2psQ3sZvH7tcgdfUZ",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32985992,
#       "TOT_SIZE":612
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13086,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 612
# decompress News FRAGMENT(s) for GUID  RTV7FX9Ll_2002265UnvtTAM1E0meSVksLTmC2psQ3sZvH7tcgdfUZ
# News = {'altId': 'nRTV7FX9Ll', 'audiences': ['NP:RCNBC'], 'body': "\nClick the following link to watch video: https://share.insider.thomsonreuters.com/link?entryId=0_roczc1qm&referenceId=7000123916_990&pageId=ReutersNews\nSource: CNBC\n\nDescription: Groupe PSA Chairman Carlos Tavares discusses the company's merger\nwith Italian automaker Fiat Chrysler.\nShort Link: https://tmsnrt.rs/2w8zQEU\n\nVideo Transcript:\n\nVerified transcript not available\n", 'firstCreated': '2020-02-26T09:09:02.091Z', 'headline': "Reuters Insider - Fiat Chrysler deal is 'not a merger in crisis mode,' Groupe PSA chairman says", 'id': 'RTV7FX9Ll_2002265UnvtTAM1E0meSVksLTmC2psQ3sZvH7tcgdfUZ', 'instancesOf': [], 'language': 'en', 'messageType': 5, 'mimeType': 'text/plain', 'provider': 'NS:CNBC', 'pubStatus': 'stat:usable', 'subjects': ['M:1Q1', 'M:1QD', 'N2:LEN', 'N2:VID'], 'takeSequence': 3, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:45.878Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"IFXzZ9Hxa_2002262dWHBqY3yKwctO1eWtO9Uw3lMo0wUCKZp/4sjB",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32986199,
#       "TOT_SIZE":841
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13102,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 841
# decompress News FRAGMENT(s) for GUID  IFXzZ9Hxa_2002262dWHBqY3yKwctO1eWtO9Uw3lMo0wUCKZp/4sjB
# News = {'altId': 'nIFXzZ9Hxa', 'audiences': ['NP:IFX'], 'body': '\nUN presents draft agreement on Libya stabilization to Russia - Bogdanov\n\n\tMOSCOW. Feb 26 (Interfax) - Special Representative and Head of the United Nations Support Mission in Libya (UNSMIL) Ghassan Salame has drafted a Libya stabilization agreement and presented it to Russia, Russian Deputy Foreign Minister Mikhail Bogdanov said.\n\n\t"Ghassan Salame has called me several times over recent days and chaired a conference in Geneva within the framework of the 5 + 5 Joint Military Committee, which involved supporters of al-Sarraj [head of the Libyan Government of National Accord recognized by the UN Fayez al-Sarraj] on one hand and supporters of Haftar [Libyan National Army Commander Khalifa Haftar] on the other hand," Bogdanov said at the Russian Public Chamber on Wednesday.\n\n\t"He has put forward and sent us the text of the draft agreement on stabilization and strengthening of the ceasefire, but certain problems remain," Bogdanov said.\n\n\n\nTe ek\n\n\n\n(Our editorial staff can be reached at eng.editors@interfax.ru) \n\n', 'firstCreated': '2020-02-26T09:09:46.107Z', 'headline': 'UN presents draft agreement on Libya stabilization to Russia - Bogdanov', 'id': 'IFXzZ9Hxa_2002262dWHBqY3yKwctO1eWtO9Uw3lMo0wUCKZp/4sjB', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:IFX', 'pubStatus': 'stat:usable', 'subjects': ['M:1QD', 'N2:LEN'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:46.107Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"RTV7wc3zy_2002262XqEeSDkXiqgfkBKx1PwyOECrGG3sRTF1gLkUQ",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32986322,
#       "TOT_SIZE":641
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBU8",
#     "SeqNumber":13118,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 641
# decompress News FRAGMENT(s) for GUID  RTV7wc3zy_2002262XqEeSDkXiqgfkBKx1PwyOECrGG3sRTF1gLkUQ
# News = {'altId': 'nRTV7wc3zy', 'audiences': ['NP:RCNBC'], 'body': '\nClick the following link to watch video: https://share.insider.thomsonreuters.com/link?entryId=0_i6pjwfnb&referenceId=7000123910_990&pageId=ReutersNews\nSource: CNBC\n\nDescription: David Webb, editor of webb-site.com, discusses how Hong Kong is\nusing stimulus to attempt to counteract the economic impact of the coronavirus\noutbreak.\nShort Link: https://tmsnrt.rs/2wOvzae\n\nVideo Transcript:\n\nVerified transcript not available\n', 'firstCreated': '2020-02-26T09:09:46.221Z', 'headline': "Reuters Insider - Coronavirus will 'certainly' be worse than SARS epidemic, analyst says", 'id': 'RTV7wc3zy_2002262XqEeSDkXiqgfkBKx1PwyOECrGG3sRTF1gLkUQ', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:CNBC', 'pubStatus': 'stat:usable', 'subjects': ['M:1Q1', 'M:1QD', 'N2:LEN', 'N2:VID'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:46.221Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"HKS6vgpp3_2002266cRvrXS+Q0uQflh1jeWbciLZnJhS+U8uBvaFL8",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32988391,
#       "TOT_SIZE":950
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ7Ejks",
#     "SeqNumber":13134,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 950
# decompress News FRAGMENT(s) for GUID  HKS6vgpp3_2002266cRvrXS+Q0uQflh1jeWbciLZnJhS+U8uBvaFL8
# News = {'altId': 'nHKS6vgpp3', 'audiences': ['NP:HKSI'], 'body': '發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL) \n\n\n\n\nExchange T1 category code 70000:"Debt and Structured Products"\n\n\nExchange T2 category code 72600:"Launch Announcement - CBBC"\n\nExchange T2 category code 73600:"Supplemental Listing Document - CBBC"\n\n\nhttp://pdf.reuters.com/pdfnews/pdfnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nHKS9RS8rF\n\n \n\nDouble click on the URL above to view the article. Please note that internet access is required. If you experience problem accessing the internet, please consult your network administrator or technical support\n\n \n\nLatest version of Adobe Acrobat reader is recommended to view PDF files.  The latest version of the reader can be obtained from http://www.adobe.com/products/acrobat/readstep2.html\n\n', 'firstCreated': '2020-02-26T09:07:15.978Z', 'headline': '發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL)', 'id': 'HKS6vgpp3_2002266cRvrXS+Q0uQflh1jeWbciLZnJhS+U8uBvaFL8', 'instancesOf': [], 'language': 'zh', 'messageType': 6, 'mimeType': 'text/plain', 'provider': 'NS:HIIS', 'pubStatus': 'stat:usable', 'subjects': ['A:1', 'A:7', 'G:1', 'G:3H', 'G:6', 'G:B1', 'G:K', 'G:S', 'M:1QD', 'M:32', 'M:3H', 'M:AV', 'M:NU', 'R:53503.HK', 'R:53506.HK', 'N2:ASIA', 'N2:ASXPAC', 'N2:CN', 'N2:DRV', 'N2:EASIA', 'N2:EMRG', 'N2:EQTY', 'N2:HK', 'N2:LZH', 'N2:LZT', 'N2:MTPDF', 'N2:NEWR', 'N2:REG', 'N2:STX'], 'takeSequence': 2, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:48.058Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"HKS43bJcn_20022666VPFqrp2+1w71nvz+3abnxCbAWvTh47VBiFMf",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32988670,
#       "TOT_SIZE":952
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ7EkI8",
#     "SeqNumber":13150,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   },
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32988699,
#       "TOT_SIZE":22200
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13166,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 952
# decompress News FRAGMENT(s) for GUID  HKS43bJcn_20022666VPFqrp2+1w71nvz+3abnxCbAWvTh47VBiFMf
# News = {'altId': 'nHKS43bJcn', 'audiences': ['NP:HKIS'], 'body': '发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL) \n\n\n\n\nExchange T1 category code 70000:"Debt and Structured Products"\n\n\nExchange T2 category code 72600:"Launch Announcement - CBBC"\n\nExchange T2 category code 73600:"Supplemental Listing Document - CBBC"\n\n\nhttp://pdf.reuters.com/pdfnews/pdfnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nHKS9RS8rF\n\n \n\nDouble click on the URL above to view the article. Please note that internet access is required. If you experience problem accessing the internet, please consult your network administrator or technical support\n\n \n\nLatest version of Adobe Acrobat reader is recommended to view PDF files.  The latest version of the reader can be obtained from http://www.adobe.com/products/acrobat/readstep2.html\n\n', 'firstCreated': '2020-02-26T09:07:15.994Z', 'headline': '发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL)', 'id': 'HKS43bJcn_20022666VPFqrp2+1w71nvz+3abnxCbAWvTh47VBiFMf', 'instancesOf': [], 'language': 'zh', 'messageType': 6, 'mimeType': 'text/plain', 'provider': 'NS:HIIS', 'pubStatus': 'stat:usable', 'subjects': ['A:1', 'A:7', 'G:1', 'G:3H', 'G:6', 'G:B1', 'G:K', 'G:S', 'M:1QD', 'M:32', 'M:3H', 'M:AV', 'M:NU', 'R:53503.HK', 'R:53506.HK', 'N2:ASIA', 'N2:ASXPAC', 'N2:CN', 'N2:DRV', 'N2:EASIA', 'N2:EMRG', 'N2:EQTY', 'N2:HK', 'N2:LZH', 'N2:LZS', 'N2:MTPDF', 'N2:NEWR', 'N2:REG', 'N2:STX'], 'takeSequence': 2, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:48.081Z'}
# FRAGMENT length = 2600
# Add new fragments to news envelop for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":2,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13182,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 5250
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":3,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13198,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 7900
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":4,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13214,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 10550
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":5,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13230,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 13200
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":6,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13246,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 15850
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":7,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13262,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 18500
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":8,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13278,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 21150
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "FRAGMENT":"...",
#       "FRAG_NUM":9,
#       "GUID":"HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR",
#       "MRN_SRC":"HK1_PRD_A"
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBQ8",
#     "SeqNumber":13294,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# process multiple fragments for guid HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# TOT_SIZE = 22200
# Current FRAGMENT length = 22200
# decompress News FRAGMENT(s) for GUID  HKS9RS8rF_2002262Pa1ZjxXsAwRDVN4rDGMchrAW29fQ3v3cOqAMR
# News = {'altId': 'nHKS9RS8rF', 'audiences': ['NP:HKSI'], 'body': "                                                       2020年2月26日\n香港交易及結算所有限公司（「香港交易所」）、香港聯合交易所有限公司（「聯交所」）及香港中央結算有限公司對本文件的內\n容概不負責，對其準確性或完整性亦不發表任何聲明，並明確表示概不會就因本文件全部或任何部分內容而產生或因依賴該等內容\n而引致的任何損失承擔任何責任。\n\n本文件的資料乃遵照香港聯合交易所有限公司的證券上市規則（「規則」）而刊載，旨在提供有關我們的資料；我們願就本文件的\n資料承擔全部責任。我們在作出一切合理查詢後，確認就其所知及所信，本文件所載資料在各重要方面均準確完備，沒有誤導或欺\n詐成分，且並無遺漏任何事項，足以令本文件或其所載任何陳述產生誤導。\n\n本文件僅供參考，並不構成購入、購買或認購牛熊證的邀請或要約。\n\n牛熊證屬於性質複雜的產品。投資者在應對有關牛熊證時務請謹慎行事。投資者務須注意，牛熊證的價格可急升亦可急跌，牛熊證\n持有人或會損失所有投資。因此，有意購買者應確保其了解牛熊證的性質，並於投資牛熊證之前仔細閱讀基本上市文件（定義見下\n文）及本文件內列明的風險因素；如有需要，應尋求專業意見。\n\n牛熊證構成我們（作為發行人）而非任何其他人士的一般無抵押合約責任，倘若我們清盤，各牛熊證與我們的所有其他無抵押責任\n（法律規定優先的責任除外）具有同等地位。如閣下購買牛熊證，閣下是倚賴我們的信譽，而根據牛熊證，閣下對發行掛鈎股份的\n公司或任何其他人士並無任何權利。倘若我們無力償債或未能履行我們於牛熊證項下的責任，則閣下可能無法收回有關牛熊證的全\n部或部份應收款項（如有）。\n\n\n\n\n                        無抵押結構性產品\n\n\n\n                  單一股份可贖回牛／熊證的推出公佈\n                         及\n                       補充上市文件\n\n\n\n\n                    發行人: CREDIT SUISSE AG\n                      (於瑞士註冊成立之有限責任公司)\n\n          保薦人/經辦人: CREDIT SUISSE (HONG KONG) LIMITED\n\n\n\n\n                                                                    1\n                                                     主要條款\n牛熊證\n                     53503             53506\n證券代號\n流通量提供者經紀編號           9720              9700\n發行額                  80,000,000 份牛熊證   80,000,000 份牛熊證\n形式／類型                歐式現金結算R類          歐式現金結算R類\n類別                   牛證                牛證\n公司                   阿里巴巴集團控股有限        阿里巴巴集團控股有限\n                     公司                公司\n股份                   公司的現有已發行普通        公司的現有已發行普通\n                     股(證券代號: 9988)     股(證券代號: 9988)\n買賣單位                 10,000 份牛熊證       10,000 份牛熊證\n每份牛熊證的發行價            0.250港元           0.250港元\n每份牛熊證於推出日的資          0.0628港元          0.2299港元\n金成本1\n                     資金成本於牛熊證期內將波動不定\n行使價                  187.880 港元 204.590港元\n贖回價                  189.880 港元 206.590港元\n到期時就每手買賣單位應          倘並無發生強制贖回事件:\n付的現金結算款（如有）          \xa0\n                     如屬一系列牛證:\n\n                                   權利 x （收市價 - 行使價） x 一手買賣單位\n\n                                           每份權利之牛熊證數目\n                     如屬一系列熊證:\n\n                                   權利 x （行使價 - 收市價） x 一手買賣單位\n\n                                           每份權利之牛熊證數目\n收市價 \xa0 2\n                     掛鈎股份於估值日的正式收市價（由聯交所每日報價列表得出）。\n(適用於各系列)\n權利                   1 股股份             1 股股份\n每份權利之牛熊證數目           100 份牛熊證          100 份牛熊證\n牛熊證所涉股份的最高數          800,000 股股份       800,000 股股份\n目\n推出日\xa0                 2020年2月25日\n(適用於各系列)\n發行日\xa0                 2020年3月2日\n(適用於各系列)\n上市日\xa0                 2020年3月3日\n(適用於各系列)\n觀察開始日\xa0               2020年3月3日\n(適用於各系列)\n估值日3\xa0                緊接到期日前的交易日（即聯交所預定於其日常交易時段開市交易的日子）。\n(適用於各系列)\n到期日4                 2020年8月28日        2020年7月30日\n結算日\xa0                 (i)強制贖回事件估值期結束；或(ii)(a)到期日；及(b)根據細則釐定收市價當日（以較後者為準）後第三個中央結算系統結算日\n(適用於各系列)             （視情況而定）。\n結算貨幣                 港元           港元\n實際槓桿比率5              8.26x        8.26x\n槓桿比率5                8.26x             8.26x\n溢價5                  3.04%             11.13%\n\n\n\n\n1     資金成本按下列公式計算：\n      資金成本       =                 權利 x （行使價 x 資金比率 x n / 365）\n                                         每份權利之牛熊證數目\n      其中，\n       (i) 「n」是到期前尚餘日數；開始時，「n」是推出日（包括該日）至緊接到期日前的交易日（包括該日）的日數；及\n       (ii) 資金比率將於牛熊證期內波動不定，詳見本文件「主要風險因素」一節。於推出日，資金比率為6.5948% （就證券代號53503而言） 及 26.2920% （就證券代\n            號53506而言）。\n2     該收市價可作出必要的任何調整，以反映產品細則第5條所列的任何事件（如資本化、供股、分派或類似事件）。\n3     在發生市場中斷事件的情況下可能予以押後。詳見產品細則 1。\n4     倘該日為星期六、星期日或香港公眾假期，則為緊隨並非星期六、星期日或香港公眾假期的日子。\n5     有關數據或會於牛熊證的有效期內波動，亦未必可與其他牛熊證發行機構提供的類似資料作比較。每間發行機構可能採用不同的計價模式。\n\n                                                                                            2\n                                                重要資料\n       牛熊證為涉及衍生工具的上市結構性產品。除非閣下完全了解及願意承擔牛熊證所涉的風險，否則切勿投資牛熊證。\n\n\n閣下投資牛熊證前應閱覽甚麼文件?                                  牛熊證並無評級。發行人的信貸評級及信貸評級展望或會按各評\n           ...
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"AZN004JMS_2002262J0Rbwg9Qi7PDpDyGAUwdwdiPTXa1YEprdeks/",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32989581,
#       "TOT_SIZE":506
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBIbECY7Eiic",
#     "SeqNumber":13310,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 506
# decompress News FRAGMENT(s) for GUID  AZN004JMS_2002262J0Rbwg9Qi7PDpDyGAUwdwdiPTXa1YEprdeks/
# News = {'altId': 'nAZN004JMS', 'audiences': ['NP:ASXH', 'NP:E'], 'body': 'Australia Stock Exchange release from ANTIPODES <APL.AX>: Net Tangible Asset Backing', 'firstCreated': '2020-02-26T09:09:49.574Z', 'headline': 'Australia Stock Exchange release from ANTIPODES <APL.AX>: Net Tangible Asset Backing', 'id': 'AZN004JMS_2002262J0Rbwg9Qi7PDpDyGAUwdwdiPTXa1YEprdeks/', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/x-plain-fixed', 'provider': 'NS:RTRS', 'pubStatus': 'stat:usable', 'subjects': ['B:125', 'B:126', 'B:130', 'B:1640', 'B:208', 'B:261', 'B:262', 'B:263', 'G:2H', 'G:5', 'G:K', 'M:1QD', 'M:1WN', 'M:210', 'M:ML', 'M:Z', 'R:APL.AX', 'N2:AGA', 'N2:ASIA', 'N2:AU', 'N2:AUNZ', 'N2:BISV', 'N2:BISV08', 'N2:CMPNY', 'N2:FINS', 'N2:FINS08', 'N2:INVBIS', 'N2:INVM', 'N2:INVMAN', 'N2:INVS08', 'N2:LEN', 'N2:NLGCON', 'N2:SRVCS', 'P:5051775816'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:49.574Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"L2N2AQ04O_2002261CkMn/Zzyem+uGr4uQL5cAGBM4/F/iEL/2qMiV",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32989607,
#       "TOT_SIZE":419
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBIbECSLEgObEjR8",
#     "SeqNumber":13326,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 419
# decompress News FRAGMENT(s) for GUID  L2N2AQ04O_2002261CkMn/Zzyem+uGr4uQL5cAGBM4/F/iEL/2qMiV
# News = {'altId': 'nL2N2AQ04O', 'audiences': ['NP:AEN'], 'body': '', 'firstCreated': '2020-02-26T09:09:49.000Z', 'headline': 'FUTUROS ACCIONES EEUU OPERAN EN TERRITORIO NEGATIVO, CAEN 0,5%', 'id': 'L2N2AQ04O_2002261CkMn/Zzyem+uGr4uQL5cAGBM4/F/iEL/2qMiV', 'instancesOf': [], 'language': 'es', 'messageType': 1, 'mimeType': 'text/plain', 'provider': 'NS:RTRS', 'pubStatus': 'stat:usable', 'subjects': ['A:1', 'G:1', 'G:6J', 'M:3F', 'M:BQ', 'G:4', 'G:9', 'R:.DJI', 'R:.IXIC', 'R:.SPX', 'M:1QD', 'N2:LES', 'N2:STX', 'N2:EMRG', 'N2:US', 'N2:MKTREP', 'N2:HOY', 'N2:AMERS', 'N2:NAMER'], 'takeSequence': 1, 'urgency': 1, 'versionCreated': '2020-02-26T09:09:49.000Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32989646,
#       "TOT_SIZE":441
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBM7EiUc",
#     "SeqNumber":13342,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   },
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32989650,
#       "TOT_SIZE":441
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBM7EiUc",
#     "SeqNumber":13358,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 441
# decompress News FRAGMENT(s) for GUID  Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u
# News = {'altId': 'nCse1JDp', 'audiences': ['NP:OMXN'], 'body': "Start of Volatility Halt Auction Period: Order book 'SYILATKL' in market 'CPH Inv Funds UCITS ETF' at 10:09:49.5230x0A", 'firstCreated': '2020-02-26T09:09:49.555Z', 'headline': "Start of Volatility Halt Auction Period: Order book 'SYILATKL' in market 'CPH In...", 'id': 'Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:CSE', 'pubStatus': 'stat:usable', 'subjects': ['G:19', 'G:2', 'G:3', 'G:A', 'G:M', 'M:1QD', 'N2:DK', 'N2:EUROP', 'N2:EUROPE', 'N2:LEN', 'N2:NORD', 'N2:SCANDV', 'N2:WEU'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:49.555Z'}
# FRAGMENT length = 441
# decompress News FRAGMENT(s) for GUID  Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u
# News = {'altId': 'nCse1JDp', 'audiences': ['NP:OMXN'], 'body': "Start of Volatility Halt Auction Period: Order book 'SYILATKL' in market 'CPH Inv Funds UCITS ETF' at 10:09:49.5230x0A", 'firstCreated': '2020-02-26T09:09:49.559Z', 'headline': "Start of Volatility Halt Auction Period: Order book 'SYILATKL' in market 'CPH In...", 'id': 'Cse1JDp___2002262JiYTfP8GtRwDI0k3+DvUWDvFoEQvdZPeKEW4u', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:CSE', 'pubStatus': 'stat:usable', 'subjects': ['G:19', 'G:2', 'G:3', 'G:A', 'G:M', 'M:1QD', 'N2:DK', 'N2:EUROP', 'N2:EUROPE', 'N2:LEN', 'N2:NORD', 'N2:SCANDV', 'N2:WEU'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:09:49.559Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"GUR1zYzxD_2002262c8X0dYKHC3iToJ4aRN4adqNI0vyovtvk7edtz",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":32989774,
#       "TOT_SIZE":1665
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yECQLEiMM",
#     "SeqNumber":13374,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 1665
# decompress News FRAGMENT(s) for GUID  GUR1zYzxD_2002262c8X0dYKHC3iToJ4aRN4adqNI0vyovtvk7edtz
# ...
#     "SeqNumber":14110,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 1706
# decompress News FRAGMENT(s) for GUID  GUR9T2qsv_20022624pfQAsvyhoR+zWxaZRXiL29IiGYq72tr/uyCX
# News = {'altId': 'nGUR9T2qsv', 'audiences': ['NP:GUR'], 'body': '\nClick here to see our chart: \n\nhttps://charts.tradingcentral.com/charts/demantdkk200226100616.gif\n\nOur pivot point stands at 218.4.\n\nOur preference: the downside prevails as long as 218.4 is resistance.\n\nAlternative scenario: above 218.4, look for 227.7 and 233.2.\n\nComment: the RSI is below 50. The MACD is negative and below its signal line. The configuration is negative. Moreover, the share stands below its 20 and 50 day MA (respectively at 225.16 and 218.44). Finally, Demant is trading below its lower daily Bollinger band (standing at 209.8).\n\nSupports and resistances:\n\n233.2 **\n\n227.7 *\n\n218.4 **\n\n214.6\n\n204.2 (DKK-last)\n\n193.4\n\n188.1 **\n\n182.8 *\n\n177.4 **\n\n---\n\nTRADING CENTRAL is a commentary service specialising in technical analysis.\n\nFor sales enquiries please call your Reuters account manager or TRADING Central\n\nby phone:  New York (1) 212 847 2387, London (+44) 203 440 7615, Paris (+33) 1 5528 8040 or Hong Kong +852 2522 3988\n\nor e-mail: sales@tradingcentral.com.\n\nFor general news functionality queries please contact the Reuters customer\n\nsupport helpdesk <PHONE/HELP>\n\nCopyright 1999-2020 - GURU by TRADING CENTRAL SA\n\nThe information contained in this publication is not intended as an offer or solicitation for the purchase or sale of any financial instrument. Any opinion offered herein reflects TRADING CENTRAL current judgment and may change without notice. Users acknowledge and agree to the fact that, by its very nature, any investment in shares, stock options and similar and assimilated products is characterised by a certain degree of uncertainty and that, consequently, any investment of this nature involves risks for which the user is solely responsible and liable\n\nHead of Research at TRADING CENTRAL: Rémy GAUSSENS\n\nTRADING CENTRAL is governed by the Code of Conduct of ANACOFI-CIF, an association approved by the Autorité des Marchés Financiers and registered with ORIAS under number 17005458.\n\nWritten on 02-26-2020 at 10:09 UTC+1\n\nPrice reference: 204.20 last known on 02-26-2020 at 10:09 UTC+1\n\nInvestment horizon: ST\n\nTRADING CENTRAL recommends reading the legal and regulatory information as well as the warnings concerning the information provided accessible from the following link : \u200bhttps://global.tradingcentral.com/www/pdf/terms_of_use_web_sites_en.pdf\n\n', 'firstCreated': '2020-02-26T09:10:10.547Z', 'headline': 'Demant ST: below its lower Bollinger band', 'id': 'GUR9T2qsv_20022624pfQAsvyhoR+zWxaZRXiL29IiGYq72tr/uyCX', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:GURU', 'pubStatus': 'stat:usable', 'subjects': ['B:148', 'B:149', 'B:150', 'B:152', 'B:1707', 'G:19', 'G:2', 'G:3', 'G:A', 'G:M', 'M:1QD', 'M:Z', 'R:DEMANT.CO', 'N2:CMPNY', 'N2:DK', 'N2:EUROP', 'N2:EUROPE', 'N2:HECA', 'N2:HLTHSE', 'N2:HPRD', 'N2:LEN', 'N2:MEDQ', 'N2:MEDQ1', 'N2:NORD', 'N2:SCANDV', 'N2:WEU', 'P:4295866001'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:10:10.547Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"GUR6dFjTC_2002262v5hdpHiyH+68tBS2XASkl5Vk0bbR27JUenFDo",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":33010664,
#       "TOT_SIZE":1811
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yECQLEiMM",
#     "SeqNumber":14126,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 1811
# decompress News FRAGMENT(s) for GUID  GUR6dFjTC_2002262v5hdpHiyH+68tBS2XASkl5Vk0bbR27JUenFDo
# News = {'altId': 'nGUR6dFjTC', 'audiences': ['NP:GUR'], 'body': '\nClick here to see our chart: \n\nhttps://charts.tradingcentral.com/charts/demantdkk200226100616.gif\n\n218.4 est notre point pivot.\n\nNotre préférence : baissier sous 218.4.\n\nScénario alternatif : le débordement de 218.4, validera une hausse sur 227.7 et 233.2.\n\nCommentaire : le RSI est inférieur à sa zone de neutralité des 50. Le MACD est négatif et en-dessous de sa ligne de signal. La configuration est baissière. De plus, les cours sont sous leurs moyennes mobiles 20 et 50, situées actuellement sur 225.16 et 218.442. Enfin, les cours se trouvent actuellement sous leur bande basse de Bollinger (située à 209.7968).\n\nSupports et résistances court terme :\n\n233.2 **\n\n227.7 *\n\n218.4 **\n\n214.6\n\n204.2 (dernier - DKK)\n\n193.4\n\n188.1 **\n\n182.8 *\n\n177.4 **\n\n---\n\nTRADING CENTRAL is a commentary service specialising in technical analysis.\n\nFor sales enquiries please call your Reuters account manager or TRADING Central\n\nby phone:  New York (1) 212 847 2387, London (+44) 203 440 7615, Paris (+33) 1 5528 8040 or Hong Kong +852 2522 3988\n\nor e-mail: sales@tradingcentral.com.\n\nFor general news functionality queries please contact the Reuters customer\n\nsupport helpdesk <PHONE/HELP>\n\nCopyright 1999-2020 - GURU by TRADING CENTRAL SA\n\nThe information contained in this publication is not intended as an offer or solicitation for the purchase or sale of any financial instrument. Any opinion offered herein reflects TRADING CENTRAL current judgment and may change without notice. Users acknowledge and agree to the fact that, by its very nature, any investment in shares, stock options and similar and assimilated products is characterised by a certain degree of uncertainty and that, consequently, any investment of this nature involves risks for which the user is solely responsible and liable\n\nResponsable de la recherche de TRADING CENTRAL : Rémy GAUSSENS\n\nTRADING CENTRAL est régie par le code de bonne conduite de l’ANACOFI-CIF, association agréée par l’Autorité des Marchés Financiers et enregistrée à l’ORIAS sous le numéro 17005458.\n\nRédigé le 26-02-2020 à 10:09 UTC+1\n\nRéférence des prix: 204.20 dernier(s) connu(s) le 26-02-2020 à 10:09 UTC+1\n\nHorizon temporel: ST\n\nTRADING CENTRAL recommande de lire les informations légales et réglementaires ainsi que les avertissements concernant les informations fournies accessibles depuis le lien suivant : https://global.tradingcentral.com/www/pdf/terms_of_use_web_sites_fr.pdf\n\n', 'firstCreated': '2020-02-26T09:10:10.570Z', 'headline': 'Demant CT : sous sa ligne basse de Bollinger', 'id': 'GUR6dFjTC_2002262v5hdpHiyH+68tBS2XASkl5Vk0bbR27JUenFDo', 'instancesOf': [], 'language': 'fr', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:GURU', 'pubStatus': 'stat:usable', 'subjects': ['B:148', 'B:149', 'B:150', 'B:152', 'B:1707', 'G:19', 'G:2', 'G:3', 'G:A', 'G:M', 'M:1QD', 'M:Z', 'R:DEMANT.CO', 'N2:CMPNY', 'N2:DK', 'N2:EUROP', 'N2:EUROPE', 'N2:HECA', 'N2:HLTHSE', 'N2:HPRD', 'N2:LFR', 'N2:MEDQ', 'N2:MEDQ1', 'N2:NORD', 'N2:SCANDV', 'N2:WEU', 'P:4295866001'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:10:10.570Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"FWN2AQ0F4_2002262vi5S8CX6vObHyN9VnhoE42GyaHUmkzFqL3HxI",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":33010719,
#       "TOT_SIZE":902
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBIbECYbECY7ECgrECg7ECiLEClrEDELEgALEgA7EgBLEgBbEgB7EgOLEgWbEiALEiWbEiibEilbEjGbEjMrEjNLEjNrEkSM",
#     "SeqNumber":14142,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 902
# decompress News FRAGMENT(s) for GUID  FWN2AQ0F4_2002262vi5S8CX6vObHyN9VnhoE42GyaHUmkzFqL3HxI
# News = {'altId': 'nFWN2AQ0F4', 'audiences': ['NP:DA', 'NP:NBN', 'NP:E', 'NP:ELE', 'NP:FN', 'NP:NW', 'NP:O', 'NP:SW', 'NP:EMK', 'NP:PSC', 'NP:RNP', 'NP:DNP', 'NP:PCO', 'NP:PEN'], 'body': '    Feb 26 (Reuters) - Vestas JV MHI Vestas:\n    * MHI VESTAS OFFSHORE WIND INKS FIRM ORDERS FOR TAIWAN\nPROJECTS\n    * MHI VESTAS AND CIP HAVE FINALISED COMMERCIAL AGREEMENTS\nFOR\nCHANGFANG AND XIDAO PROJECTS IN TAIWAN WITH A COMBINED CAPACITY\nOF 589 MW.\n    * PROJECTS WILL BE INSTALLED IN 2023.\n\nSource text: https://bit.ly/2VpJa26\nFurther company coverage: [VWS.CO]\n\n (Gdansk Newsroom)\n ((gdansk.newsroom@thomsonreuters.com; +48 58 778 51 10;))', 'firstCreated': '2020-02-26T09:10:10.000Z', 'headline': 'BRIEF-Vestas JV MHI Vestas Finalises Agreements For Changfang And Xidao Projects In Taiwan', 'id': 'FWN2AQ0F4_2002262vi5S8CX6vObHyN9VnhoE42GyaHUmkzFqL3HxI', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:RTRS', 'pubStatus': 'stat:usable', 'subjects': ['M:Z', 'G:19', 'G:BR', 'B:219', 'B:2', 'G:A', 'M:1NZ', 'G:M', 'U:C', 'B:191', 'B:192', 'U:N', 'G:3', 'U:BS', 'B:1031', 'E:44', 'G:7U', 'E:1', 'E:40', 'G:2', 'G:1', 'G:6', 'G:K', 'G:S', 'A:4', 'U:EV', 'U:G', 'R:VWS.CO', 'P:4295866012', 'MCCL:OEC', 'MCC:OEC', 'M:1QD', 'N2:CMPNY', 'N2:DK', 'N2:EMEAE', 'N2:ENER', 'N2:ENFF', 'N2:EUROP', 'N2:GDY1', 'N2:NORD', 'N2:NRG', 'N2:RENE', 'N2:RENQ', 'N2:RNW', 'N2:WEU', 'N2:WINPWR', 'N2:WNDSYS', 'N2:ORDR', 'N2:TW', 'N2:BACT', 'N2:CPROD', 'N2:SCANDV', 'N2:EMRG', 'N2:EASIA', 'N2:ASIA', 'N2:ASXPAC', 'N2:COM', 'N2:RNWPWR', 'N2:PWR', 'N2:LEN'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:10:10.000Z'}
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"BQN2MGjQ__20022625c+Z5e53Zf74Gc3AaQ5LDjpHD7XJUwtFNYKDW",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":33010844,
#       "TOT_SIZE":2157
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yECJ7EkCM",
#     "SeqNumber":14158,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 2157
# decompress News FRAGMENT(s) for GUID  BQN2MGjQ__20022625c+Z5e53Zf74Gc3AaQ5LDjpHD7XJUwtFNYKDW
# News = {'altId': 'nBQN2MGjQ', 'audiences': ['NP:BEQN'], 'body': 'For best results when printing this announcement, please click on link below:\nhttp://pdf.reuters.com/htmlnews/htmlnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nBQN2MGjQ\n\n============\n\n   REAL HOLDINGS FÖRETRÄDESEMISSION TÄCKT AV VILLKORADE TECKNINGSFÖRBINDELSER\n   TILL CA 92,6 PROCENT\n\n   Den 30 januari 2020 kallade styrelsen i Real Holding i Sverige AB (publ)\n   ("Real Holding" eller "Bolaget") till extra bolagsstämma att hållas den 2\n   mars 2020 för att bland annat besluta om en 35 MSEK företrädesemission.\n   Styrelsen kan idag meddela att emissionen till ca 92,6 procent täcks genom\n   villkorade teckningsförbindelser om ca 32,4 MSEK.\n\n   Teckningsförbindelserna avser teckning både med och utan företräde i\n   emissionen. Teckningsförbindelserna utan företräde kan enbart bli aktuella\n   att ta i anspråk om emissionen inte blir fulltecknad av Bolagets\n   befintliga aktieägare, vilka har företrädesrätt att teckna aktierna i\n   emissionen. För teckningsförbindelserna lämnas ingen ersättning.\n\n   Styrelsen har även föreslagit att den extra bolagstämman den 2 mars 2020\n   bl.a. ska besluta om att godkänna en närståendetransaktion avseende\n   Bolagets tilltänkta förvärv av samtliga aktier i fastighetsbolaget\n   Forsfast AB. För mer information, se kallelsen till den extra\n   bolagsstämman som offentliggjordes den 30 januari 2020. Nu aktuella\n   teckningsförbindsler är lämnade av säljarna av Forsfast AB, däribland\n   bolag ägda av Real Holdings styrelseledamöter Michael Derk och Fredrik\n   Högbom. Teckningsförbindelserna är villkorade av att Real Holding\n   tillträder aktierna i Forsfast AB och att betalning för tilldelade aktier\n   sker genom kvittning av reverser som avses att ställas ut av Real Holding\n   till säljarna som dellikvid för aktierna i Forsfast AB.\n   Teckningsförbindelserna som är lämnade av bolagen ägda av Real Holdings\n   styrelseledamöter Michael Derk och Fredrik Högbom uppgår totalt till ca\n   20,7 MSEK.\n\n   Partner Fondkommission är finansiell rådgivare i samband med\n   Företrädesemissionen.\n\n   För ytterligare information: [1]www.realholding.se\n\n   Denna information är sådan information som Real Holding i Sverige AB\n   (publ) är skyldigt att offentliggöra enligt EU:s\n   marknadsmissbruksförordning. Informationen lämnades, genom nedanstående\n   kontaktpersoners försorg, för offentliggörande den 26 februari 2020 kl.\n   10,10 CET.\n\n   Bengt Engström, styrelsens ordförande\n   Telefon +46 72 500 9444\n   E-post: [2]bengtengstrom35@gmail.com\n\n   Michael Derk, styrelseledamot\n   Telefon + 46 73 387 1802\n   E-post: [3]michael@derk.se\n\n   Kent Söderberg, VD\n   Telefon + 46 70 522 86 46\n   E-post: [4]kent.soderberg@realfastigheter.se\n\n   Följande dokument kan hämtas från beQuoted\n   [5]Real Holding Pressrelease 2020-02-26.pdf\n\n   Om Real Holding i Sverige AB (publ)\n\n   Real Holdings affärsidé är att förvärva och förvalta kommersiella\n   fastigheter och samhällsfastigheter i tillväxtorter med diversifierat\n   näringsliv inom segmenten tillverkning, lättindustri, lager och logistik.\n   Genom aktiv och långsiktig förvaltning med en riskjusterad belåning skapas\n   ett stort förädlingsvärde. Största ägare i bolaget är Bengt Linden AB,\n   Gremio Fastigheter AB och Kredrik Holding AB. Real Holdings aktier handlas\n   på NGM Nordic SME under kortnamnet REAL B.\n\nReferences\n\n   Visible links\n   1. http://www.realholding.se/\n   2. mailto:bengtengstrom35@gmail.com\n   3. mailto:michael@derk.se\n   4. mailto:kent.soderberg@realfastigheter.se\n   5. http://www.bequoted.com/beQPress/download.asp?Id=28261\n\n\n============', 'firstCreated': '2020-02-26T09:10:10.748Z', 'headline': 'Real Holdings företrädesemission täckt av villkorade teckningsförbindelser till ca 92,6 procent', 'id': 'BQN2MGjQ__20022625c+Z5e53Zf74Gc3AaQ5LDjpHD7XJUwtFNYKDW', 'instancesOf': [], 'language': 'sv', 'messag ...
# RECEIVED:
# [
#   {
#     "DoNotCache":true,
#     "DoNotConflate":true,
#     "DoNotRipple":true,
#     "Domain":"NewsTextAnalytics",
#     "Fields":{
#       "ACTIV_DATE":"2020-02-26",
#       "FRAGMENT":"...",
#       "FRAG_NUM":1,
#       "GUID":"BER6PSgV7_2002262bn0irK+FKLPhMnIEwC0vQlU4wMNeSkdGpJ0V2",
#       "MRN_SRC":"HK1_PRD_A",
#       "MRN_TYPE":"STORY",
#       "MRN_V_MAJ":"2",
#       "MRN_V_MIN":"10",
#       "TIMACT_MS":33012115,
#       "TOT_SIZE":411
#     },
#     "ID":2,
#     "Key":{
#       "Name":"MRN_STORY",
#       "Service":"API_RDF"
#     },
#     "PermData":"Ax+yEBdLEjJM",
#     "SeqNumber":14174,
#     "Type":"Update",
#     "UpdateType":"Unspecified"
#   }
# ]
# FRAGMENT length = 411
# decompress News FRAGMENT(s) for GUID  BER6PSgV7_2002262bn0irK+FKLPhMnIEwC0vQlU4wMNeSkdGpJ0V2
# News = {'altId': 'nBER6PSgV7', 'audiences': ['NP:BER'], 'body': '', 'firstCreated': '2020-02-26T09:10:12.092Z', 'headline': 'Mahathir says national interests are of paramount importance in efforts to set up a new administration', 'id': 'BER6PSgV7_2002262bn0irK+FKLPhMnIEwC0vQlU4wMNeSkdGpJ0V2', 'instancesOf': [], 'language': 'en', 'messageType': 2, 'mimeType': 'text/plain', 'provider': 'NS:BER', 'pubStatus': 'stat:usable', 'subjects': ['G:1', 'G:2EK', 'G:8S', 'G:CI', 'G:K', 'G:S', 'M:1QD', 'N2:ASEAN', 'N2:ASIA', 'N2:ASXPAC', 'N2:EMRG', 'N2:LEN', 'N2:MY', 'N2:SEASIA'], 'takeSequence': 1, 'urgency': 3, 'versionCreated': '2020-02-26T09:10:12.092Z'}
# WebSocket Closed

# %% [markdown]
# ### Real-time News Data Model
# The news data appears as JSON in UTF-8 after decompression and assembly of the individual messages.
# The Real-time News feed contains the headline, story body text, and associated metadata about the story as a simple group of named values.
#
# Example JSON fields are following:
# - ```firstCreated```: UTC timestamp for the first version of the story. Millisecond precision.
# - ```headline```: The headline text of the news item.
# - ```id```: Uniquely identifies the news item. This is the same value as the GUID in the OMM envelope.
# - ```body```: The full body text of the news item (Story Body).
#
# For more detail regarding MRN data model please visit [MRN Data Models and Refinitiv Real-Time Implementation Guide](https://developers.refinitiv.com/elektron/elektron-sdk-java/docs?content=8736&type=documentation_item) page. If you want to compare MRN and the legacy N2_UBMS news data model, please visit [Machine Readable News (MRN) & N2_UBMS Comparison and Migration Guide](https://developers.refinitiv.com/article/machine-readable-news-mrn-n2_ubms-comparison-and-migration-guide).

# %%
print("first 10 headlines\n")
for news in _news_messages[:10]:
    if news["headline"]:
        print(news["headline"])
# Out:
# first 10 headlines
#
# GETBACK SPÓŁKA AKCYJNA W RESTRUKTURYZACJI - Uprawomocnienie postanowienia Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu Wydział VIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r. o zatwierdzeniu Układu
# ***Volatilitätsindex VSMI +18% auf höchsten Stand seit Anfang 2019
# CRF: European Gas  NBP DA Outlook - Bearish
# Monex Europe Limited - Markets convulse as coronavirus outbreak teeters on the brink of becoming a pandemic
# NIKKEI Coronavirus Concerns Fuel Fresh Selloff in Global Stocks
# Reuters Insider - Fiat Chrysler deal is 'not a merger in crisis mode,' Groupe PSA chairman says
# UN presents draft agreement on Libya stabilization to Russia - Bogdanov
# Reuters Insider - Coronavirus will 'certainly' be worse than SARS epidemic, analyst says
# 發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL)
# 发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL)

# %%
print("first 10 stories\n")
for news in _news_messages[:10]:
    if news["body"]:
        print(news["body"])
# Out:
# first 10 stories
#
#  KOMISJA NADZORU FINANSOWEGO
#
#
#
#   Raport bieżący nr 8 / 2020
#
#
#
#  Data sporządzenia:  2020-02-26
#
#  Skrócona nazwa emitenta
#
#  GETBACK S.A.
#
#  Temat
#
#  Uprawomocnienie postanowienia Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu Wydział
#
# VIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r. o
#
# zatwierdzeniu Układu
#
#  Podstawa prawna
#
#  Art. 17 ust. 1 MAR - informacje poufne.
#
#
#
#  Treść raportu:
#
#  Zarząd GetBack S.A. w restrukturyzacji (Emitent) informuje, iż powziął informację o wydaniu w
#
# dniu 24 lutego 2020 r. przez Sąd Rejonowy dla Wrocławia-Fabrycznej we Wrocławiu w sprawie o sygn.
#
# akt VIII Gz 1/20, VIII GRp 4/18 postanowienia o oddaleniu zażalenia wierzyciela (Postanowienie) na
#
# postanowienie z dnia 30 grudnia 2019 r. o odrzuceniu zażalenia wierzyciela na postanowienie o
#
# zatwierdzeniu układu z dnia 6 czerwca 2019 r., o którym Emitent informował raportem bieżącym nr
#
# 1/2020 z dnia 15 stycznia 2020 r.
#
# Postanowienie to nie podlega zaskarżeniu, stało się zatem prawomocne, skuteczne i wykonalne z
#
# dniem 24 lutego 2020 roku. Zażalenie było ostatnim rozpoznawanym przez Sąd zażaleniem
#
# wierzyciela w postępowaniu o zatwierdzenie układu Emitenta.
#
#
#
# Powyższe oznacza, iż postanowienie Sądu Rejonowego dla Wrocławia-Fabrycznej we Wrocławiu
#
# Wydział VIII Gospodarczy do spraw Upadłościowych i Restrukturyzacyjnych z dnia 6 czerwca 2019 r.
#
# o zatwierdzeniu Układu uprawomocniło się.
#
#
#
# Podpisy osób reprezentujących Emitenta
#
#
#
#
#
#
#
# For best results when printing this announcement, please click on link below:
# http://pdf.reuters.com/htmlnews/htmlnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nPGEQWkSLa
#
#
# The UK system opened strongly undersupplied today on the combination of
# stronger demand and lower supply nominations. Nomination for LNG sendout
# dropped to 56mcm/d compared to 82mcm/d yesterday. Drop in Vesterled amid
# outage at Kollsnes and UKCS production outages at St. Fergus NSMP and Teesside
# CATs( Culzean) are important bullish factors for WD. However, we expect strong
# surge in LNG sendout tomorrow which should  provide a bearish signal for DA.
#
# Strong winds speeds which have prevented cargoes berthing at Milford Haven
# last week are easing now . Several cargoes are lined up outside South Hook and
# Dragon now. Sendout are likely to surge towards terminal’s capacity as soon
# as cargoes can berth.
#
#
#
# Conclusion:  Bearish  24.7p/th to 23.7 p/th
#
#
#
# BULLISH
#
# Undersupplied UK system this morning
#
# Vestereled flows are down today and can adjust further lower on DA  as outage
# at injection outage at Oseberg ends.
#
#
#
# BEARISH
#
# The ongoing UKCS production outages should end tomorrow
#
# LNG sendout might surges tomorrow as wind speeds outside the Milford Haven are
# easing.
#
#
#
# NEUTRAL/OTHER
#
# LDZ and Gas for power consumption forecast are rougly unchanged on DA.
#
#
#
#
#
# Copyright 2002-2020, Thomson Reuters. All rights reserved.
#
# GBP
#
# Sterling managed to find its footing against the US dollar yesterday and pared
# back some of its losses from last week, although this morning has bought a
# fresh patch of US dollar strength. In addition to the worsening global
# coronavirus outbreaks, and UK-EU trade talks, the upcoming Budget next month
# is in focus for markets. This morning UK papers have begun reporting various
# bits of information, as anticipation builds. The Institute for Fiscal Studies
# said that the Government risked breaking election pledges to balance fiscal
# spending, and urged Chancellor Rishi Sunak to raise taxes to pay for spending.
# The Financial Times, in the meantime, cited an unnamed Treasury official in
# reporting that big decisions on tax, spending, and borrowing would be delayed
# until the Autumn Statement. Instead, the Chancellor would focus on delivering
# manifesto pledges on spending - such as a cut in corporation tax. The net
# effect of the budget is likely to be a positive fiscal impulse, the size and
# duration of which remains uncertain for now. This morning's data included the
# British Retail Consortium's shop price index, which fell 0.6% in February
# compared to a year ago.
#
# EUR
#
# The euro saw fresh highs against the dollar for the fourth consecutive day
# yesterday as US equities continued to sell off, although any calls for a large
# rally seem premature based on recent eurozone data. The eurozone continues to
# see slower growth than the US, as well as higher sensitivity to slowing
# Chinese demand, and the risk of supply chain disruption. European equities are
# still falling after the worst two-day market decline seen in years and did not
# manage to find momentum in yesterday morning's recovery as coronavirus cases
# continued to surge. Multiple first cases were discovered in Croatia and
# Switzerland and further increases in case numbers were reported throughout the
# rest of Europe. European Central Bank Governing Council member Francois
# Villeroy de Galhau commented on the surge yesterday, stating that the outbreak
# is 'mainly a negative supply-side shock' and that 'we shouldn't overstate the
# adequacy of a monetary policy response', as it would have 'negative but
# temporary consequences'. He added that the Bank of France was likely to revise
# French growth forecast of 1.1% downward in the next month. The euro seemed
# unimpressed and found no further support in Villeroy's comments. Aside from
# the unchanged French consumer confidence and the still to be released Austrian
# purchasing managers' index, the eurozone calendar is virtually blank today.
# Tomorrow, eurozone business climate and economic sentiment index of February
# will be released at 10:00 GMT.
#
# USD
#
# The greenback took on some water yesterday as Monday's aggressive pricing of
# coronavirus risk marginally unwound. The theme of dollar strength is back with
# a vengeance today, however, as the CDC (centre for disease control and
# prevention) warned Americans to brace for an outbreak of the coronavirus. The
# statement sent US 10-year yields to hit a record low overnight of 1.3055% as
# investors flocked for safety in the low yield environment. Despite the dollar
# trading mixed yesterday, the theme in US equity markets was more clear cut.
# The S&P 500 and Dow Jones Index both fell over 3%, capping the worst two days
# in the respective markets since 2015. In politics, the Democratic debate saw
# the front-runner, Bernie Saunders, get a chunk taken out of him before the
# next primary by all other candidates. Labelled divisive and lacking details,
# all candidates took aim at Saunders in the South Carolina debate, although no
# one candidate came out on top.
#
# CAD
#
# The loonie is struggling to retrace much of the coronavirus impact as oil
# markets offer little support. The Canadian dollar is set to log marginal
# losses over the course of the month as things stand, with little stimulus to
# reverse such a move coming from crude pricing. The price of WTI fell below $50
# last night for the first time since the emergency OPEC+ meeting in Vienna. The
# loonie remains better supported than other G10 counterparts with open current
# accounts as yield differentials buffer the storm somewhat, but with little in
# the data calendar today, risk sentiment will continue to drive sentiment in
# USDCAD. At 15:30 GMT, the Department of Energy inventory report is released
# which has been showing increasing declines due to rising export data.
#
#
# Attachments
# *           Original document
# (https://www.monexeurope.com/news-analysis/news/markets-convulse-as-coronavirus-outbreak-teeters-on-the-brink-of-becoming-a-pandemic/)
# Disclaimer
#
# Monex Europe Limited published this content on 26 February 2020 and is solely
# responsible for the information contained therein. Distributed by Public,
# unedited and unaltered, on 26 February 2020 09:09:44 UTC
#
#
#
# (C) Copyright 2020 - Monex Europe Limited
#
# By Chong Koh Ping and Anna Isaac
#      Global stocks continued a course of steep selloffs Wednesday as concerns over the
# economic cost of the new coronavirus gathered pace.
#      Regional indexes fell across Europe and Asia. The pan-continental Stoxx Europe 600
# dropped 2.1%, with Germany's DAX index leading losses with a fall of 2.2%. Both the DAX
# and Japan's Nikkei 225, which shed 0.8%, reached their lowest levels since October.
# Australia's S&P/ASX 200 dropped 2.3% and Korea's Kospi retreated 1.3%.
#      U.S. futures tied to the Dow Jones Industrial Average were down nearly 1% early
# Wednesday. The Dow fell nearly 900 points on Tuesday to end at its lowest level since
# October after U.S. health officials said they expect a wider spread of the coronavirus
# and are preparing for a potential pandemic.
#      The yield on the U.S. 10-year Treasury traded at 1.327% Wednesday. On Tuesday it
# fell as low as 1.310% on an intraday basis and settled at 1.328%, a new all-time low.
#      "The market is pricing in a significant slowdown in global growth and corporate
# earnings," said Ong Zi Yang, senior macro analyst at FSMOne.com in Singapore. "It is
# hard to quantify the economic impact now but there will definitely be a slowdown."
#      Deaths and confirmed cases of the coronavirus have continued to climb outside China
# -- notably in Italy, Iran, Japan and South Korea. Concerns among investors that the
# virus will spread further, disrupting the global economy, has triggered two sharp
# consecutive stock selloffs this week.
#      Federal Reserve Bank of Dallas President Robert Kaplan said Tuesday that events
# were still too fluid around the coronavirus outbreak for the U.S. central bank to cut
# short-term interest rates.
#      Many European and Asian benchmarks, including those in Germany, Japan, and South
# Korea are now solidly in negative territory for the year. The DAX is down 3.5% for the
# year-to-date while Hong Kong's Hang Seng and the Kospi in Seoul have both declined more
# than 5% so far in 2020, according to FactSet.
#      "This is a classic case of risk aversion," said Kelvin Tay, regional chief
# investment officer at UBS Global Wealth Management in Singapore, who added that markets
# were likely to remain volatile.
#      Mr. Tay pointed to rallies in gold and U.S. government bonds, and said it was also
# difficult for Asian markets to perform well when regional currencies were weak.
#      Elsewhere in Asia, the Hang Seng Index in Hong Kong and the Shanghai Composite both
# retreated about 0.8%.
#      In currencies, the Australian dollar fell to its lowest level against the U.S.
# dollar since March 2009. Meanwhile the ICE U.S. dollar index was up 0.1% Wednesday, with
# the dollar up nearly 3% against other major currencies in 2020.
#      Gold hit a seven-year high this week. On Wednesday, spot gold stood 0.2% lower at
# nearly $1,650 an ounce.
#      Write to Anna Isaac at anna.isaac@wsj.com
#
# Click the following link to watch video: https://share.insider.thomsonreuters.com/link?entryId=0_roczc1qm&referenceId=7000123916_990&pageId=ReutersNews
# Source: CNBC
#
# Description: Groupe PSA Chairman Carlos Tavares discusses the company's merger
# with Italian automaker Fiat Chrysler.
# Short Link: https://tmsnrt.rs/2w8zQEU
#
# Video Transcript:
#
# Verified transcript not available
#
#
# UN presents draft agreement on Libya stabilization to Russia - Bogdanov
#
# 	MOSCOW. Feb 26 (Interfax) - Special Representative and Head of the United Nations Support Mission in Libya (UNSMIL) Ghassan Salame has drafted a Libya stabilization agreement and presented it to Russia, Russian Deputy Foreign Minister Mikhail Bogdanov said.
#
# 	"Ghassan Salame has called me several times over recent days and chaired a conference in Geneva within the framework of the 5 + 5 Joint Military Committee, which involved supporters of al-Sarraj [head of the Libyan Government of National Accord recognized by the UN Fayez al-Sarraj] on one hand and supporters of Haftar [Libyan National Army Commander Khalifa Haftar] on the other hand," Bogdanov said at the Russian Public Chamber on Wednesday.
#
# 	"He has put forward and sent us the text of the draft agreement on stabilization and strengthening of the ceasefire, but certain problems remain," Bogdanov said.
#
#
#
# Te ek
#
#
#
# (Our editorial staff can be reached at eng.editors@interfax.ru)
#
#
#
# Click the following link to watch video: https://share.insider.thomsonreuters.com/link?entryId=0_i6pjwfnb&referenceId=7000123910_990&pageId=ReutersNews
# Source: CNBC
#
# Description: David Webb, editor of webb-site.com, discusses how Hong Kong is
# using stimulus to attempt to counteract the economic impact of the coronavirus
# outbreak.
# Short Link: https://tmsnrt.rs/2wOvzae
#
# Video Transcript:
#
# Verified transcript not available
#
# 發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL)
#
#
#
#
# Exchange T1 category code 70000:"Debt and Structured Products"
#
#
# Exchange T2 category code 72600:"Launch Announcement - CBBC"
#
# Exchange T2 category code 73600:"Supplemental Listing Document - CBBC"
#
#
# http://pdf.reuters.com/pdfnews/pdfnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nHKS9RS8rF
#
#
#
# Double click on the URL above to view the article. Please note that internet access is required. If you experience problem accessing the internet, please consult your network administrator or technical support
#
#
#
# Latest version of Adobe Acrobat reader is recommended to view PDF files.  The latest version of the reader can be obtained from http://www.adobe.com/products/acrobat/readstep2.html
#
#
# 发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL)
#
#
#
#
# Exchange T1 category code 70000:"Debt and Structured Products"
#
#
# Exchange T2 category code 72600:"Launch Announcement - CBBC"
#
# Exchange T2 category code 73600:"Supplemental Listing Document - CBBC"
#
#
# http://pdf.reuters.com/pdfnews/pdfnews.asp?i=43059c3bf0e37541&u=urn:newsml:reuters.com:20200226:nHKS9RS8rF
#
#
#
# Double click on the URL above to view the article. Please note that internet access is required. If you experience problem accessing the internet, please consult your network administrator or technical support
#
#
#
# Latest version of Adobe Acrobat reader is recommended to view PDF files.  The latest version of the reader can be obtained from http://www.adobe.com/products/acrobat/readstep2.html

# %%
# #uncomment if you do not have requests and websocket-client (version 0.49 and above) installed\n
# #Install pandas and numpy packages in a current Jupyter kernal\n

# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install numpy

# %%
import pandas as pd

# %%
df_headlines = pd.DataFrame(_news_messages, columns = ["firstCreated","messageType","provider","language","headline"])

# %%
messageType = {
    0: "Unknow",
    1: "Alert",
    2: "First take",
    3: "Subsequent take",
    4: "Correction",
    5: "Corrected",
    6: "Update",
    7: "Deletion",
    8: "Drop due to expiry"
}

# %%
df_headlines["messageType"] = [messageType[value] for value in df_headlines["messageType"] if value in messageType ]

# %%
df_headlines
# Out:
#                 firstCreated messageType provider language  \
# 0   2020-02-26T09:09:42.404Z  First take  NS:EMIT       pl
# 1   2020-02-26T09:09:44.115Z  First take   NS:AWP       de
# 2   2020-02-26T09:09:44.457Z   Corrected   NS:CRF       en
# 3   2020-02-26T09:09:44.000Z  First take  NS:PUBT       en
# 4   2020-02-26T09:09:45.807Z  First take   NS:NEN       en
# 5   2020-02-26T09:09:02.091Z   Corrected  NS:CNBC       en
# 6   2020-02-26T09:09:46.107Z  First take   NS:IFX       en
# 7   2020-02-26T09:09:46.221Z  First take  NS:CNBC       en
# 8   2020-02-26T09:07:15.978Z      Update  NS:HIIS       zh
# 9   2020-02-26T09:07:15.994Z      Update  NS:HIIS       zh
# 10  2020-02-26T09:09:48.011Z  First take  NS:HIIS       zh
# 11  2020-02-26T09:09:49.574Z  First take  NS:RTRS       en
# 12  2020-02-26T09:09:49.000Z       Alert  NS:RTRS       es
# 13  2020-02-26T09:09:49.555Z  First take   NS:CSE       en
# 14  2020-02-26T09:09:49.559Z  First take   NS:CSE       en
# 15  2020-02-26T09:09:49.681Z  First take  NS:GURU       en
# 16  2020-02-26T09:09:49.706Z  First take  NS:GURU       fr
# 17  2020-02-26T09:09:50.658Z  First take   NS:ASX       en
# 18  2017-10-30T00:53:26.000Z      Update  NS:RTRS       en
# 19  2020-02-26T09:09:51.632Z  First take  NS:KYDO       ja
# 20  2020-02-26T09:09:56.002Z       Alert  NS:RTRS       ja
# 21  2020-02-26T09:09:56.000Z  First take  NS:RTRS       en
# 22  2020-02-26T09:09:59.453Z  First take  NS:BMYS       en
# 23  2020-02-26T09:09:59.483Z  First take  NS:BMYS       en
# 24  2020-02-26T09:09:59.554Z  First take  NS:BMYS       en
# 25  2020-02-26T09:09:59.581Z  First take  NS:BMYS       en
# 26  2020-02-26T09:09:59.607Z  First take  NS:BMYS       en
# 27  2020-02-26T09:07:29.408Z  First take  NS:BMYS       en
# 28  2020-02-26T09:10:00.000Z       Alert  NS:RTRS       en
# 29  2020-02-26T09:10:00.000Z       Alert  NS:RTRS       en
# 30  2020-02-26T08:43:25.000Z      Update  NS:RTRS       zh
# 31  2020-02-26T08:43:25.000Z      Update  NS:RTRS       zh
# 32  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 33  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 34  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 35  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 36  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 37  2020-02-26T08:10:00.000Z  First take   NS:LSE       en
# 38  2020-02-26T09:09:39.991Z  First take   NS:DJN       en
# 39  2020-02-26T09:10:06.179Z  First take   NS:MTD       ko
# 40  2020-02-26T09:10:06.990Z  First take   NS:APA       de
# 41  2020-02-26T09:07:16.514Z      Update  NS:HIIS       en
# 42  2020-02-26T09:10:07.003Z  First take  NS:HIIS       en
# 43  2020-02-26T09:10:07.875Z  First take  NS:PLTS       en
# 44  2020-02-26T09:10:07.949Z  First take  NS:PLTS       en
# 45  2020-02-26T09:10:08.041Z  First take  NS:PLTS       en
# 46  2020-02-26T09:10:08.126Z  First take  NS:PLTS       en
# 47  2020-02-26T09:10:10.547Z  First take  NS:GURU       en
# 48  2020-02-26T09:10:10.570Z  First take  NS:GURU       fr
# 49  2020-02-26T09:10:10.000Z  First take  NS:RTRS       en
# 50  2020-02-26T09:10:10.748Z  First take   NS:BEQ       sv
# 51  2020-02-26T09:10:12.092Z  First take   NS:BER       en
#
#                                              headline
# 0   GETBACK SPÓŁKA AKCYJNA W RESTRUKTURYZACJI - Up...
# 1   ***Volatilitätsindex VSMI +18% auf höchsten St...
# 2         CRF: European Gas  NBP DA Outlook - Bearish
# 3   Monex Europe Limited - Markets convulse as cor...
# 4   NIKKEI Coronavirus Concerns Fuel Fresh Selloff...
# 5   Reuters Insider - Fiat Chrysler deal is 'not a...
# 6   UN presents draft agreement on Libya stabiliza...
# 7   Reuters Insider - Coronavirus will 'certainly'...
# 8       發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL)
# 9       发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL)
# 10                發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件
# 11  Australia Stock Exchange release from ANTIPODE...
# 12  FUTUROS ACCIONES EEUU OPERAN EN TERRITORIO NEG...
# 13  Start of Volatility Halt Auction Period: Order...
# 14  Start of Volatility Halt Auction Period: Order...
# 15       Beazley Group ST: under pressure below 583.5
# 16  Beazley Group CT : baissier tant que 583.5 est...
# 17                  Net Tangible Asset Backing-APL.AX
# 18                     *TOP NEWS* European Companies
# 19                              換気や消毒の徹底を　専門家が家庭向け予防策
# 20                                        米株先物が0.5％下落
# 21       BRIEF-YOC FY Operating Profit At EUR 0.5 Mln
# 22  Changes In Boardroom Announcement - Change in ...
# 23  Notice Of Shares Buy Back - Notice of SBB by a...
# 24  TRANSACTIONS (CHAPTER 10 OF LISTING REQUIREMEN...
# 25  Changes In Boardroom Announcement - Change in ...
# 26  Change in Nomination Committee(HAP SENG CONSOL...
# 27  Changes In Substantial Shareholder's Interest ...
# 28  STARBUCKS <SBUX.N> SAYS IT WILL START SELLING ...
# 29  STARBUCKS <SBUX.N> SAYS BEYOND MEAT BREAKFAST ...
# 30                       意大利金融：信用違約互換跳升，因擔心新冠病毒疫情打擊經濟
# 31                       意大利金融：信用违约互换跳升，因担心新冠病毒疫情打击经济
# 32  REG - Oil and Gas Devt Co  - Financial Results...
# 33  REG - Oil and Gas Devt Co  - Financial Results...
# 34  REG - Oil and Gas Devt Co  - Financial Results...
# 35  REG - Oil and Gas Devt Co  - Financial Results...
# 36  REG - Oil and Gas Devt Co  - Financial Results...
# 37  REG - Oil and Gas Devt Co  - Financial Results...
# 38  DJ Coronavirus Concerns Fuel Fresh Selloff in ...
# 39                [속보]文대통령 "마스크 수출제한 조치로 공급물량 충분히 확보"
# 40         Atrium steigerte Nettogewinn 2019 deutlich
# 41  Launch Announcement and Supplemental Listing D...
# 42  Launch Announcement and Supplemental Listing D...
# 43  PLATTS: 997--New York 76: Platts Bunker 380 cs...
# 44  PLATTS: 8--New York 76: Platts Bunker 380 cst ...
# 45  PLATTS: 190--New York 1567: Platts Bunker 380 ...
# 46  PLATTS: 2--New York 76: Platts Bunker 380 cst ...
# 47          Demant ST: below its lower Bollinger band
# 48       Demant CT : sous sa ligne basse de Bollinger
# 49  BRIEF-Vestas JV MHI Vestas Finalises Agreement...
# 50  Real Holdings företrädesemission täckt av vill...
# 51  Mahathir says national interests are of paramo...

# %%
df_story = pd.DataFrame(_news_messages, columns = ["headline","body"])

# %%
df_story
# Out:
#                                              headline  \
# 0   GETBACK SPÓŁKA AKCYJNA W RESTRUKTURYZACJI - Up...
# 1   ***Volatilitätsindex VSMI +18% auf höchsten St...
# 2         CRF: European Gas  NBP DA Outlook - Bearish
# 3   Monex Europe Limited - Markets convulse as cor...
# 4   NIKKEI Coronavirus Concerns Fuel Fresh Selloff...
# 5   Reuters Insider - Fiat Chrysler deal is 'not a...
# 6   UN presents draft agreement on Libya stabiliza...
# 7   Reuters Insider - Coronavirus will 'certainly'...
# 8       發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL)
# 9       发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL)
# 10                發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件
# 11  Australia Stock Exchange release from ANTIPODE...
# 12  FUTUROS ACCIONES EEUU OPERAN EN TERRITORIO NEG...
# 13  Start of Volatility Halt Auction Period: Order...
# 14  Start of Volatility Halt Auction Period: Order...
# 15       Beazley Group ST: under pressure below 583.5
# 16  Beazley Group CT : baissier tant que 583.5 est...
# 17                  Net Tangible Asset Backing-APL.AX
# 18                     *TOP NEWS* European Companies
# 19                              換気や消毒の徹底を　専門家が家庭向け予防策
# 20                                        米株先物が0.5％下落
# 21       BRIEF-YOC FY Operating Profit At EUR 0.5 Mln
# 22  Changes In Boardroom Announcement - Change in ...
# 23  Notice Of Shares Buy Back - Notice of SBB by a...
# 24  TRANSACTIONS (CHAPTER 10 OF LISTING REQUIREMEN...
# 25  Changes In Boardroom Announcement - Change in ...
# 26  Change in Nomination Committee(HAP SENG CONSOL...
# 27  Changes In Substantial Shareholder's Interest ...
# 28  STARBUCKS <SBUX.N> SAYS IT WILL START SELLING ...
# 29  STARBUCKS <SBUX.N> SAYS BEYOND MEAT BREAKFAST ...
# 30                       意大利金融：信用違約互換跳升，因擔心新冠病毒疫情打擊經濟
# 31                       意大利金融：信用违约互换跳升，因担心新冠病毒疫情打击经济
# 32  REG - Oil and Gas Devt Co  - Financial Results...
# 33  REG - Oil and Gas Devt Co  - Financial Results...
# 34  REG - Oil and Gas Devt Co  - Financial Results...
# 35  REG - Oil and Gas Devt Co  - Financial Results...
# 36  REG - Oil and Gas Devt Co  - Financial Results...
# 37  REG - Oil and Gas Devt Co  - Financial Results...
# 38  DJ Coronavirus Concerns Fuel Fresh Selloff in ...
# 39                [속보]文대통령 "마스크 수출제한 조치로 공급물량 충분히 확보"
# 40         Atrium steigerte Nettogewinn 2019 deutlich
# 41  Launch Announcement and Supplemental Listing D...
# 42  Launch Announcement and Supplemental Listing D...
# 43  PLATTS: 997--New York 76: Platts Bunker 380 cs...
# 44  PLATTS: 8--New York 76: Platts Bunker 380 cst ...
# 45  PLATTS: 190--New York 1567: Platts Bunker 380 ...
# 46  PLATTS: 2--New York 76: Platts Bunker 380 cst ...
# 47          Demant ST: below its lower Bollinger band
# 48       Demant CT : sous sa ligne basse de Bollinger
# 49  BRIEF-Vestas JV MHI Vestas Finalises Agreement...
# 50  Real Holdings företrädesemission täckt av vill...
# 51  Mahathir says national interests are of paramo...
#
#                                                  body
# 0    KOMISJA NADZORU FINANSOWEGO  \n\n \n\n  Rapor...
# 1                                                \n\n
# 2   For best results when printing this announceme...
# 3   \nGBP\n\nSterling managed to find its footing ...
# 4   \nBy Chong Koh Ping and Anna Isaac \n     Glob...
# 5   \nClick the following link to watch video: htt...
# 6   \nUN presents draft agreement on Libya stabili...
# 7   \nClick the following link to watch video: htt...
# 8   發行的可贖回牛熊證代號53503, 53506之推出公佈及補充上市文件(with URL) ...
# 9   发行的可赎回牛熊证代号53503, 53506之推出公布及补充上市文件(with URL) ...
# 10                                                ...
# 11  Australia Stock Exchange release from ANTIPODE...
# 12
# 13  Start of Volatility Halt Auction Period: Order...
# 14  Start of Volatility Halt Auction Period: Order...
# 15  \nClick here to see our chart: \n\nhttps://cha...
# 16  \nClick here to see our chart: \n\nhttps://cha...
# 17  26 February 2020\n\n\nBy Electronic Lodgement\...
# 18  > Profits jump at Peugeot maker PSA ahead of F...
# 19  \n　東北医科薬科大は２６日、新型コロナウイルスの感染予防として、家庭でできる具体策をまとめ...
# 20
# 21      Feb 26 (Reuters) - YOC AG <YOCG.DE>:\n    ...
# 22  Company Name                                  ...
# 23  Company Name                                  ...
# 24  TRANSACTIONS (CHAPTER 10 OF LISTING REQUIREMEN...
# 25  Company Name                                  ...
# 26  Change in Nomination Committee\r\nDirector Nam...
# 27  Company Name                                  ...
# 28
# 29
# 30      路透倫敦2月26日 - 意大利政府及該國一些銀行業者所發債券的保險成本周三跳漲，因市...
# 31      路透伦敦2月26日 - 意大利政府及该国一些银行业者所发债券的保险成本周三跳涨，因市...
# 32  For best results when printing this announceme...
# 33  For best results when printing this announceme...
# 34  For best results when printing this announceme...
# 35  For best results when printing this announceme...
# 36  For best results when printing this announceme...
# 37  For best results when printing this announceme...
# 38  \n\nBy Chong Koh Ping and Anna Isaac \n\nGloba...
# 39  For best results when printing this announceme...
# 40  Utl.: Nettomieterlöse leicht gefallen - Divide...
# 41  Launch Announcement and Supplemental Listing D...
# 42                                                ...
# 43  26Feb20/ 0910 AM EDT/0910 GMT\n--0910 GMT: Pla...
# 44  26Feb20/ 0910 AM EDT/0910 GMT\n--0910 GMT: Pla...
# 45  26Feb20/ 0910 AM EDT/0910 GMT\n--0910 GMT: Pla...
# 46  26Feb20/ 0910 AM EDT/0910 GMT\n--0910 GMT: Pla...
# 47  \nClick here to see our chart: \n\nhttps://cha...
# 48  \nClick here to see our chart: \n\nhttps://cha...
# 49      Feb 26 (Reuters) - Vestas JV MHI Vestas:\n...
# 50  For best results when printing this announceme...
# 51

# %% [markdown]
# ## References
#
# * [Refinitiv Real-Time SDK Family page](https://developers.refinitiv.com/elektron) on the [Refinitiv Developer Community](https://developers.refinitiv.com/) web site.
# * [Refinitiv WebSocket API page](https://developers.refinitiv.com/en/api-catalog/elektron/refinitiv-websocket-api).
# * [Developer Webinar Recording: Introduction to WebSocket API](https://www.youtube.com/watch?v=CDKWMsIQfaw).
# * [Introduction to Machine Readable News with WebSocket API](https://developers.refinitiv.com/article/introduction-machine-readable-news-elektron-websocket-api-refinitiv).
# * [Machine Readable News (MRN) & N2_UBMS Comparison and Migration Guide](https://developers.refinitiv.com/article/machine-readable-news-mrn-n2_ubms-comparison-and-migration-guide).
# * [Introduction to Machine Readable News (MRN) with Enterprise Message API (EMA)](https://developers.refinitiv.com/article/introduction-machine-readable-news-mrn-elektron-message-api-ema).
# * [MRN Data Models and Refinitiv Real-Time Implementation Guide](https://developers.refinitiv.com/elektron/elektron-sdk-java/docs?content=8736&type=documentation_item).
# * [Refinitiv-API-Samples/Example.WebSocketAPI.Javascript.NewsMonitor](https://github.com/Refinitiv-API-Samples/Example.WebSocketAPI.Javascript.NewsMonitor).
#
# For any question related to this example or WebSocket API, please use the Developer Community [Q&A Forum](https://community.developers.refinitiv.com/spaces/152/websocket-api.html).
