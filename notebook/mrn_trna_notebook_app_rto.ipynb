# %% [markdown]
# # How to get MRN News Analytics via WebSocket API with Python - RTO Connection
#
# **Last Update**: Nov 2025
#
# ## Prerequisite
#
# This article/notebook supports all [Machine Readable News Analytics (TRNA)](https://www.lseg.com/en/data-analytics/financial-news-service/machine-readable-news) data data consumption from The Real-Time with the WebSocket API. However, the data model description is focusing on the News Analytics (TRNA) data processing only.
#
# I highly recommend you check the  [WebSocket API Tutorials](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api/tutorials) page if you are not familiar with WebSocket API. The Tutorials page provides a step-by-step guide (connect, log in, request data, parse data, etc) for developers who are interested in developing a WebSocket application to consume real-time data from  Real-Time.
#
# If you are focusing on the Real-Time News, please check the following GitHub repositories
# - [LSEG-API-Samples/Example.WebSocketAPI.Python.MRN](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.Python.MRN).
# - [LSEG-API-Samples/Example.WebSocketAPI.Python.MRN.RTO](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.Python.MRN.RTO)
#
# The notebook file provides a step-by-step guide (connect, log in, request data, parse data, etc) for developers who are interested in developing a WebSocket application to consume real-time data from  Real-Time - Optimized (RTO) using the Version 1 Authentication (Machine-ID). You can find how to migrate your Version 1 Authentication application to the Version 2 Authentication (Service ID) from the [Real-Time WebSocket API: The Real-Time Optimized Version 2 Authentication Migration Guide](https://developers.lseg.com/en/article-catalog/article/webSocket-api-rto-v2-authentication-migration-guide) and [Migrating the WebSocket Machine Readable News Application to Version 2 Authentication](https://developers.lseg.com/en/article-catalog/article/migrating-the-websocket-machine-readable-news-to-rto-v2) articles.
#
# If you are using the deployed  Real-Time Distribution System (RTDS), please check the [mrn_trna_notebook_app.ipynb](./mrn_trna_notebook_app.ipynb) notebook file.
#
# Please contact your LSEG's representative to help you to access the RTO account, and services. You can find more detail regarding the RTO access credentials set up from the *Getting Started for Machine ID* section of the [Getting Start with Data Platform article](https://developers.lseg.com/en/article-catalog/article/getting-start-with-refinitiv-data-platform) article.
#
# ## News Analytics and Machine Readable News Overview
#
# [Machine Readable News Analytics (TRNA)](https://www.lseg.com/en/data-analytics/financial-news-service/machine-readable-news) provides real-time numerical insight into the events on multiple news sources, in a format that can be directly consumed by algorithmic trading systems. TRNA enables algorithms to exploit the power of news to seize opportunities, capitalize on market inefficiencies, and manage event risk.
#
# TRNA is published via the Real-Time Platform as part of Machine Readable News (MRN) data model. MRN is an advanced service for automating the consumption and systematic analysis of news. It delivers deep historical news archives, ultra-low latency structured news, and news analytics directly to your applications.
#
# ### MRN Data behavior
#
# RN is published over the Real-Time platform using an Open Message Model (OMM) envelope in News Text Analytics domain messages. The Real-time News content set is made available over MRN_STORY RIC. The content data is contained in a FRAGMENT field that has been compressed and potentially fragmented across multiple messages, to reduce bandwidth and message size.
#
# A FRAGMENT field has a different data type based on a connection type:
#
# - RSSL connection (RTSDK [C++](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/rt-sdk-cc)/[C#](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/rt-sdk-csharp)/[Java](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/rt-sdk-java)): BUFFER type
# - WebSocket connection: Base64 ASCII string
#
# The data goes through the following series of transformations:
#
# 1. The core content data is a UTF-8 JSON string
# 2. This JSON string is compressed using gzip
# 3. The compressed JSON is split into several fragments (BUFFER or Base64 ASCII string) which each fit into a single update message
# 4. The data fragments are added to an update message as the FRAGMENT field value in a FieldList envelope
#
#
# <img src="images/trna_process.png"/>
#
# Therefore, to parse the core content data, the application will need to reverse this process. The WebSocket application also needs to convert a received Base64 string in a FRAGMENT field to bytes data before further process this field. This application uses Python [base64](https://docs.python.org/3/library/base64.html) and [zlib](https://docs.python.org/3/library/zlib.html) modules to decode Base64 string and decompress JSON string.

# %% [markdown]
# ### MRN Data model
#
# Five fields, as well as the RIC itself, are necessary to determine whether the entire item has been received in its various fragments and how to concatenate the fragments to reconstruct the item:
# * MRN_SRC: identifier of the scoring/processing system that published the FRAGMENT
# * GUID: a globally unique identifier for the data item. All messages for this data item will have the same GUID values.
# * FRAGMENT: compressed data item fragment, itself
# * TOT_SIZE: total size in bytes of the fragmented data
# * FRAG_NUM: sequence number of fragments within a data item. This is set to 1 for the first fragment of each item published and is incremented for each subsequent fragment for the same item.
#
# A single MRN data item publication is uniquely identified by the combination of RIC, MRN_SRC, and GUID.
#
# #### Fragmentation
# For a given RIC-MRN_SRC-GUID combination, when a data item requires only a single message, then TOT_SIZE will equal the number of bytes in the FRAGMENT, and FRAG_NUM will be 1.
#
# When multiple messages are required, then the data item can be deemed as fully received once the sum of the number of bytes of each FRAGMENT equals TOT_SUM. The consumer will also observe that all FRAG_NUM range from 1 to the number of the fragment, with no intermediate integers, skipped. In other words, a data item transmitted over three messages will contain FRAG_NUM values of 1, 2, and 3.
#
# #### Compression
# The FRAGMENT field is compressed with gzip compression, thus requiring the consumer to decompress to reveal the JSON plain-text data in that FID.
#
# When an MRN data item is sent in multiple messages, all the messages must be received and their FRAGMENTs concatenated before being decompressed. In other words, the FRAGMENTs should not be decompressed independently of each other.
#
# The decompressed output is encoded in UTF-8 and formatted as JSON.

# %% [markdown]
# If you are not familiar with MRN concept, please visit the following resources which will give you a full explanation of the MRN data model and implementation logic:
#
# * [Webinar Recording: Introduction to Machine Readable News](https://developers.lseg.com/news#news-accordion-nid-12045)
# * [Introduction to Machine Readable News (MRN) with Enterprise Message API (EMA)](https://developers.lseg.com/en/article-catalog/article/introduction-machine-readable-news-mrn-elektron-message-api-ema).
# * [MRN Data Models and Refinitiv Real-Time SDK Implementation Guide](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/rt-sdk-java/documentation#mrn-data-models-and-elektron-implementation-guide).
# * [Introduction to Machine Readable News with WebSocket API](https://developers.lseg.com/en/article-catalog/article/introduction-machine-readable-news-elektron-websocket-api-refinitiv).
# * [How to get MRN News Analytics Data via WebSocket API](https://developers.lseg.com/en/article-catalog/article/how-to-get-mrn-news-analytics-data-via-elektron-websocket-api).

# %%
# #uncomment if you do not have requests, websocket-client (version 1.2.1), and python-dotenv installed\n
# #Install requests, websocket-client, and python-dotenv packages in a current Jupyter kernal\n

import sys

# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install websocket-client
# !{sys.executable} -m pip install python-dotenv

# %%
import time
import getopt
import socket
import json
import websocket
import threading
from threading import Thread, Event
import base64
import zlib
import requests
import os
from dotenv import load_dotenv
import datetime

# %load_ext dotenv

# Use find_dotenv to locate the file
# %dotenv

# %% [markdown]
# You should save a text file with **filename** `.env` or OS Environment Variables having the following configurations:
#
# ```
# # RTO Credentials
# RTO_USERNAME=Machine-ID
# RTO_PASSWORD=RTO-Password
# RTO_CLIENTID=App-Key
#
# # RDP-RTO Core Configurations
# RDP_BASE_URL=https://api.refinitiv.com
# RDP_AUTH_URL=/auth/oauth2/v1/token
# RDP_DISCOVERY_URL=/streaming/pricing/v1/
# ```

# %% [markdown]
# ### <a id="whatis_rdp"></a>What is Delivery (RDP) APIs?
#
# The [Delivery Platform APIs](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis) (aka Data Platform or RDP) provide various LSEG data and content for developers via easy to use Web-based API.
#
# RDP APIs give developers seamless and holistic access to all of the LSEG content such as Historical Pricing, Environmental Social and Governance (ESG), News, Research, etc and commingled with their content, enriching, integrating, and distributing the data through a single interface, delivered wherever they need it.
#
# The RTO utilizes RDP APIs authentication and service discovery services. For more detail regarding Delivery Platform, please see the following APIs resources:
# - [Quick Start](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/quick-start) page.
# - [Tutorials](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/tutorials) page.
# - [RDP APIs: Introduction to the Request-Response API](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/tutorials#introduction-to-the-request-response-api) page.
# - [RDP APIs: Authorization - All about tokens](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/tutorials#authorization-all-about-tokens) page.
#
# ### <a id="whatis_rto"></a>What is the Real-Time - Optimized?
#
# As part of the Delivery Platform, [the Real-Time - Optimized (RTO)](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api/quick-start#connecting-to-refinitiv-real-time-optimized) (formerly known as ERT in Cloud) gives you access to best in class Real-Time market data delivered in the cloud.  Real-Time - Optimized is a new delivery mechanism for RDP, using the AWS (Amazon Web Services) cloud. Once a connection to RDP is established using Real-Time - Optimized, data can be retrieved using [Websocket API for Pricing Streaming and Real-Time Services](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api) aka WebSocket API.
#
# For more detail regarding Refinitiv Real-Time - Optimized, please see the following APIs resources:
#
# - [WebSocket API RTO Quick Start (Authentication V1)](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-apiquick-start#connecting-to-refinitiv-real-time-optimized) page.
# - [WebSocket API RTO Quick Start (Authentication V2)](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api/quick-start#connecting-to-real-time-optimized-v2) page.
# - [WebSocket API Tutorials](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api/tutorials#connect-to-refinitiv-real-time-optimized) page.
# - [How to Setup Amazon EC2 Instance for the Real-Time Optimized (RTO)](https://developers.lseg.com/en/article-catalog/article/how-to-setup-amazon-ec2-instance-for-rto) article.

# %% [markdown]
# #### RDP and RTO Endpoints
#
# The RTO application needs to get authentication information from the RDP Auth Service. The application can get the Refinitiv Real-Time service endpoints dynamically from the RDP Service Discovery service.

# %%
base_url = os.getenv('RDP_BASE_URL')
auth_url = base_url +  os.getenv('RDP_AUTH_URL');
discovery_url = base_url +  os.getenv('RDP_DISCOVERY_URL');

# %% [markdown]
# #### RTO Credentials
#
# The Refinitiv Real-Time - Optimized (RTO) needs the following access credentials:
# - Machine-ID
# - RTO Password
# - ClientID (aka AppKey)

# %%
user= os.getenv('RTO_USERNAME') 
clientid= os.getenv('RTO_CLIENTID') 
password= os.getenv('RTO_PASSWORD') 

# RTO variables
sts_token = ''
refresh_token = ''
original_expire_time = '0'
expire_time = '0'
client_secret = ''
scope = 'trapi.streaming.pricing.read'
region = 'us-east-1'
service = 'ELEKTRON_DD'

# %%
# Refinitiv Real-Time Advanced Distribution Server connection variables
hostList = []
port = '15000'
app_id = '256'
position = socket.gethostbyname(socket.gethostname())
login_id = 1

# %%
# WebSocket connections Variables

web_socket_app = None
web_socket_open = False
_news_envelopes = []

# keeps decompress news JSON messaage
_trna_messages = []

# %% [markdown]
# ### RDP Token retrival
#
# In order to connect to RTO, you need to retrieve token from the Token API first. This part of the code will take care of then token retrieval for you.

# %%
def get_sts_token(current_refresh_token, url=None):
    """
        Retrieves an authentication token.
        :param current_refresh_token: Refresh token retrieved from a previous authentication, used to retrieve a
        subsequent access token. If not provided (i.e. on the initial authentication), the password is used.
    """

    if url is None:
        url = auth_url

    if not current_refresh_token:  # First time through, send password
        data = {'username': user, 'password': password, 'client_id': clientid, 'grant_type': 'password', 'takeExclusiveSignOnControl': True,
                'scope': scope}
        print('Sending authentication request with password to {} ...'.format(url))
        #print(data)
    else:  # Use the given refresh token
        data = {'username': user, 'client_id': clientid, 'refresh_token': current_refresh_token, 'grant_type': 'refresh_token'}
        print("Sending authentication request with refresh token to {} ... ".format(url))
    if client_secret != '':
        data['client_secret'] = client_secret;
        
    try:
        # Request with auth for https protocol    
        r = requests.post(url,
                          headers={'Accept': 'application/json'},
                          data=data,
                          auth=(clientid, client_secret),
                          verify=True,
                          allow_redirects=False)

    except requests.exceptions.RequestException as e:
        print('Refinitiv Data Platform authentication exception failure:', e)
        return None, None, None

    if r.status_code == 200:
        auth_json = r.json()
        print('Refinitiv Data Platform Authentication succeeded. RECEIVED:')
        print(json.dumps(auth_json, sort_keys=True, indent=2, separators=(',', ':')))

        return auth_json['access_token'], auth_json['refresh_token'], auth_json['expires_in']
    elif r.status_code == 301 or r.status_code == 302 or r.status_code == 307 or r.status_code == 308:
        # Perform URL redirect
        print('Refinitiv Data Platform authentication HTTP code:', r.status_code, r.reason)
        new_host = r.headers['Location']
        if new_host is not None:
            print('Perform URL redirect to ', new_host)
            return get_sts_token(current_refresh_token, new_host)
        return None, None, None
    elif r.status_code == 400 or r.status_code == 401:
        # Retry with username and password
        print('Refinitiv Data Platform authentication HTTP code:', r.status_code, r.reason)
        if current_refresh_token:
            # Refresh token may have expired. Try using our password.
            print('Retry with username and password')
            return get_sts_token(None)
        return None, None, None
    elif r.status_code == 403 or r.status_code == 451:
        # Stop retrying with the request
        print('Refinitiv Data Platform authentication HTTP code:', r.status_code, r.reason)
        print('Stop retrying with the request')
        return None, None, None
    else:
        # Retry the request to Refinitiv Data Platform 
        print('Refinitiv Data Platform authentication HTTP code:', r.status_code, r.reason)
        print('Retry the request to Refinitiv Data Platform')
        return get_sts_token(current_refresh_token)

# %% [markdown]
# #### RDP Service Discovery
#
# Once authentication is successful, you can request the list of RTO WebSocket endpoints from the RDP Service Discovery.

# %%
def query_service_discovery(url=None):

    if url is None:
        url = discovery_url

    print("Sending Refinitiv Data Platform service discovery request to " + url)

    try:
        r = requests.get(url, headers={"Authorization": "Bearer " + sts_token}, params={"transport": "websocket"}, allow_redirects=False)

    except requests.exceptions.RequestException as e:
        print('Refinitiv Data Platform service discovery exception failure:', e)
        return False

    if r.status_code == 200:
        # Authentication was successful. Deserialize the response.
        response_json = r.json()
        print("Refinitiv Data Platform Service discovery succeeded. RECEIVED:")
        print(json.dumps(response_json, sort_keys=True, indent=2, separators=(',', ':')))

        for index in range(len(response_json['services'])):
            if not response_json['services'][index]['location'][0].startswith(region):
                continue

            if len(response_json['services'][index]['location']) == 1:
                hostList.append(response_json['services'][index]['endpoint'] + ":" +str(response_json['services'][index]['port']))


        if len(hostList) == 0:
            print("The region:", region, "is not present in list of endpoints")
            sys.exit(1)

        return True

    elif r.status_code == 301 or r.status_code == 302 or r.status_code == 303 or r.status_code == 307 or r.status_code == 308:
        # Perform URL redirect
        print('Refinitiv Data Platform service discovery HTTP code:', r.status_code, r.reason)
        new_host = r.headers['Location']
        if new_host is not None:
            print('Perform URL redirect to ', new_host)
            return query_service_discovery(new_host)
        return False
    elif r.status_code == 403 or r.status_code == 451:
        # Stop trying with the request
        print('Refinitiv Data Platform service discovery HTTP code:', r.status_code, r.reason)
        print('Stop trying with the request')
        return False
    else:
        # Retry the service discovery request
        print('Refinitiv Data Platform service discovery HTTP code:', r.status_code, r.reason)
        print('Retry the service discovery request')
        return query_service_discovery()

# %% [markdown]
# ### MRN Process Code
#
# The MRN data can be subscribed with the *NewsTextAnalytics* domain and MRN-specific RIC name as following:
# - *MRN_TRNA*: News Analytics: Company and C&E assets
# - *MRN_TRNA_DOC*: News Analytics: Macroeconomic News & events
# - *MRN_STORY*: Real-time News
# - *MRN_TRSI*: News Sentiment Indices

# %%
# MRN variables

mrn_domain = 'NewsTextAnalytics'
mrn_item = 'MRN_TRNA'

def send_mrn_request(ws):
    """ Create and send MRN request """
    mrn_req_json = {
        'ID': 2,
        "Domain": mrn_domain,
        'Key': {
            'Name': mrn_item,
            'Service': service
        }
    }

    ws.send(json.dumps(mrn_req_json))
    print("SENT:")
    print(json.dumps(mrn_req_json, sort_keys=True, indent=2, separators=(',', ':')))

# %% [markdown]
# ### Initial Refresh Message
# The Initial Refresh response does not contain any NTA data, all the fields related to news item and fragment are empty or 0. It contains only the relevant feed related or other static Fields.
#
# The application can just print out each incoming field data in a console for informational purpose or just ignore it.

# %%
# Process FieldList, Refresh and Status messages.

def decodeFieldList(fieldList_dict):
    for key, value in fieldList_dict.items():
        print("Name = %s: Value = %s" % (key, value))

def processRefresh(ws, message_json):

    print("RECEIVED: Refresh Message")
    decodeFieldList(message_json["Fields"])

def processStatus(ws, message_json):  # process incoming status message
    print("RECEIVED: Status Message")
    print(json.dumps(message_json, sort_keys=True, indent=2, separators=(',', ':')))

# %% [markdown]
# ### MRN News Update messages Process Code
#
# The updates contain only fields related to the item and the fragment. They do not contain any of the static or per-feed fields. The updates are not cached or conflated.
#
# #### First Update
# The first update contains all the fields related to the item and the first fragment, subsequent updates only contain the fields relating to the fragment they contain. The FRAG_NUM FID is set to 1 for the first Update of each item and is incremented in each subsequent Update for that item. This allows you to you to detect a missing fragment (and ensure correct order of the fragments for re-assembly).
#
#
# #### Subsequent Update and Multi Fragment Items
# The subsequent update contains the fields necessary to identify the MRN data item, the order of this fragment among all the fragments for this item, and the fragment itself. The other point to note is that (for a Multi fragment item), Update messages with FRAG_NUM >1 will have fewer FIDs as the metadata is included in the first Update message (FRAG_NUM=1) for that item
#
# #### News Fragments simple handle logic
#
#
# <img src="images/mrn_flow_reconstruct.png"/>

# %%
def processMRNUpdate(ws, message_json):  # process incoming News Update messages

    fields_data = message_json["Fields"]
    # Dump the FieldList first (for informational purposes)
    # decodeFieldList(message_json["Fields"])

    # declare variables
    tot_size = 0
    guid = None

    try:
        # Get data for all requried fields
        fragment = base64.b64decode(fields_data["FRAGMENT"])
        frag_num = int(fields_data["FRAG_NUM"])
        guid = fields_data["GUID"]
        mrn_src = fields_data["MRN_SRC"]

        #print("GUID  = %s" % guid)
        #print("FRAG_NUM = %d" % frag_num)
        #print("MRN_SRC = %s" % mrn_src)

        if frag_num > 1:  # We are now processing more than one part of an envelope - retrieve the current details
            guid_index = next((index for (index, d) in enumerate(
                _news_envelopes) if d["guid"] == guid), None)
            envelop = _news_envelopes[guid_index]
            if envelop and envelop["data"]["mrn_src"] == mrn_src and frag_num == envelop["data"]["frag_num"] + 1:
                print("process multiple fragments for guid %s" %
                      envelop["guid"])

                #print("fragment before merge = %d" % len(envelop["data"]["fragment"]))

                # Merge incoming data to existing news envelop and getting FRAGMENT and TOT_SIZE data to local variables
                fragment = envelop["data"]["fragment"] = envelop["data"]["fragment"] + fragment
                envelop["data"]["frag_num"] = frag_num
                tot_size = envelop["data"]["tot_size"]
                print("TOT_SIZE = %d" % tot_size)
                print("Current FRAGMENT length = %d" % len(fragment))

                # The multiple fragments news are not completed, waiting.
                if tot_size != len(fragment):
                    return None
                # The multiple fragments news are completed, delete assoiclate GUID envelop
                elif tot_size == len(fragment):
                    del _news_envelopes[guid_index]
            else:
                print("Error: Cannot find fragment for GUID %s with matching FRAG_NUM or MRN_SRC %s" % (
                    guid, mrn_src))
                return None
        else:  # FRAG_NUM = 1 The first fragment
            tot_size = int(fields_data["TOT_SIZE"])
            print("FRAGMENT length = %d" % len(fragment))
            # The fragment news is not completed, waiting and add this news data to envelop object.
            if tot_size != len(fragment):
                print("Add new fragments to news envelop for guid %s" % guid)
                _news_envelopes.append({  # the envelop object is a Python dictionary with GUID as a key and other fields are data
                    "guid": guid,
                    "data": {
                        "fragment": fragment,
                        "mrn_src": mrn_src,
                        "frag_num": frag_num,
                        "tot_size": tot_size
                    }
                })
                return None

        # News Fragment(s) completed, decompress and print data as JSON to console
        if tot_size == len(fragment):
            print("decompress News FRAGMENT(s) for GUID  %s" % guid)
            decompressed_data = zlib.decompress(fragment, zlib.MAX_WBITS | 32)
            
            json_news = json.loads(decompressed_data)
            _trna_messages.append(json_news)
            print("News = %s" % json_news)

    except KeyError as keyerror:
        print('KeyError exception: ', keyerror)
    except IndexError as indexerror:
        print('IndexError exception: ', indexerror)
    except binascii.Error as b64error:
        print('base64 decoding exception:', b64error)
    except zlib.error as error:
        print('zlib decompressing exception: ', error)
    # Some console environments like Windows may encounter this unicode display as a limitation of OS
    except UnicodeEncodeError as encodeerror:
        print("UnicodeEncodeError exception. Cannot decode unicode character for %s in this enviroment: " %
              guid, encodeerror)
    except Exception as e:
        print('exception: ', sys.exc_info()[0])

# %% [markdown]
# ### JSON-OMM Process functions

# %%
def process_message(ws, message_json):
    """ Parse at high level and output JSON of message """
    message_type = message_json['Type']

    if message_type == "Refresh":
        if "Domain" in message_json:
            message_domain = message_json["Domain"]
            if message_domain == "Login":
                process_login_response(ws, message_json)
            elif message_domain:
                processRefresh(ws, message_json)
    elif message_type == "Update":
        if "Domain" in message_json and message_json["Domain"] == mrn_domain:
            processMRNUpdate(ws, message_json)
    elif message_type == "Status":
        processStatus(ws, message_json)
    elif message_type == "Ping":
        pong_json = {'Type': 'Pong'}
        ws.send(json.dumps(pong_json))
        print("SENT:")
        print(json.dumps(pong_json, sort_keys=True,
                         indent=2, separators=(',', ':')))


def process_login_response(ws, message_json):
    """ Send item request """
    send_mrn_request(ws)


def send_login_request(ws ,auth_token, is_refresh_token):
    """ Generate a login request from command line data (or defaults) and send """
    login_json = {
        'ID': 1,
        "Domain": 'Login',
        'Key': {
            'NameType': 'AuthnToken',
            'Elements': {
                'ApplicationId': '',
                'Position': '',
                'AuthenticationToken': ''
            }
        }
    }

    login_json['Key']['Name'] = user
    login_json['Key']['Elements']['ApplicationId'] = app_id
    login_json['Key']['Elements']['Position'] = position
    login_json['Key']['Elements']['AuthenticationToken'] = auth_token
    
    if is_refresh_token:
        login_json['Refresh'] = False

    ws.send(json.dumps(login_json))
    print("SENT:")
    print(json.dumps(login_json, sort_keys=True, indent=2, separators=(',', ':')))

def send_refresh_token(ws):
    print('Refreshing the access token')
    send_login_request(ws, sts_token, True)

def ws_disconnect(ws):
    print('Closing the WebSocket connection')
    if web_socket_open:
        ws.close()

# %% [markdown]
# ### WebSocket Process functions
#
# The code runs for 25~ minutes before stop the connection. You can change it to run forever by changing from the ```while time.time() < t_end:``` statement to ```while True:``` statment.

# %%
def on_message(ws, message):
    """ Called when message received, parse message into JSON for processing """
    print("RECEIVED: ")
    message_json = json.loads(message)
    # Uncomment to print RAW JSON message from the server
    #print(json.dumps(message_json, sort_keys=True, indent=2, separators=(',', ':')))

    for singleMsg in message_json:
        process_message(ws, singleMsg)
        
def on_error(ws, error):
    """ Called when websocket error has occurred """
    print(error)
    
def on_close(ws, close_status_code, close_msg):
    """ Called when websocket is closed """
    global web_socket_open
    print("WebSocket Closed")
    web_socket_open = False
    
def on_open(ws):
    """ Called when handshake is complete and websocket is open, send login """

    print("WebSocket successfully connected!")
    global web_socket_open
    web_socket_open = True
    send_login_request(ws,sts_token, refresh_token)
    

## Main Function 

if __name__ == "__main__":
    # RTO - RDP Login
    #print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
    sts_token, refresh_token, expire_time = get_sts_token(None)
    if not sts_token:
        exit

    original_expire_time = expire_time

    # Query VIPs from Refinitiv Data Platform service discovery
    if not query_service_discovery():
        print('Failed to retrieve endpoints from Refinitiv Data Platform Service Discovery. Exiting...')
        exit
    #print(hostList[0])
    # Start websocket handshake
    ws_address = "wss://{}/WebSocket".format(hostList[0])
    print("Connecting to WebSocket " + ws_address + " ...")
    web_socket_app = websocket.WebSocketApp(ws_address, header=['User-Agent: Python'],
                                            on_message=on_message,
                                            on_error=on_error,
                                            on_close=on_close,
                                            subprotocols=['tr_json2'])
    web_socket_app.on_open = on_open
    
    #web_socket_app.keep_running = False

    # Event loop
    #wst = threading.Thread(target=web_socket_app.run_forever)
    wst = threading.Thread(target=web_socket_app.run_forever, kwargs={'sslopt': {'check_hostname': False}})
    wst.start()

    #time.sleep(90)
    #web_socket_app.close()
    t_end = time.time() + (60 * 10) # Running for 25~ Minutes
    try:
        #while True: # Change to this line for running forever
        while time.time() < t_end: # Running for 25~ Minutes
            #  Continue using current token until 90% of initial time before it expires.
            time.sleep(int(float(expire_time) * 0.90))

            sts_token, refresh_token, expire_time = get_sts_token(refresh_token)
            if not sts_token:
                exit

            if int(expire_time) != int(original_expire_time):
               print('expire time changed from {} sec to {} sec; retry with password'.format(str(original_expire_time), str(expire_time)))
               sts_token, refresh_token, expire_time = get_sts_token(None)
               if not sts_token:
                   exit 
               original_expire_time = expire_time

            # Update token.
            send_refresh_token(web_socket_app)
        else: # End time
            print('Close connection')
            ws_disconnect(web_socket_app)
            #print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

    except KeyboardInterrupt:
        pass
# Out:
# Sending authentication request with password to https://api.refinitiv.com/auth/oauth2/v1/token ...
# Refinitiv Data Platform Authentication succeeded. RECEIVED:
# {
#   "access_token":"eyJhbGciOiJSUzI1NiIsImtpZCI6ImJlcGpHV0dkOW44WU9VQ1NwX3M3SXlRMmlKMFkzeWRFaHo1VDJJVlNqWTgiLCJ0eXAiOiJhdCtqd3QifQ.....Fvs9BQGIV5arLQt5zi2JPjMSIXhUOEBINXtInyeAkERXpZvt-ZP7OZ0GbWrUNGysMiWmJRmUHrte5ObrWCPIanIroqTi-LMHonnYMiwxdUSPTTZn0kuUqMfsyg8nmtMGc3OmOVYY3ECz__YAFICLRDneDXN6edKbpQOgTR1W13FzLfyw2FYNunPfzq-VC9u5RRrfoYCvyi-0CmyoBsoDUz0S2bfhgFQVd0o_03rz6qe6AqElE9-fiZPHagK_hUIV93WtykdiDgX4mYSRS0dvRBjrRuTmirrM1Ky2Lkhgn7Vop9MvG0zpSkLctgtY5gTZzPrYWGqF1S2-tPzeMouwKg",
#   "expires_in":"600",
#   "refresh_token":"b8f14f19-3ced-42f7-87f1-54ae5df617d0",
#   "scope":"trapi.streaming.pricing.read",
#   "token_type":"Bearer"
# }
# Sending Refinitiv Data Platform service discovery request to https://api.refinitiv.com/streaming/pricing/v1/
# Refinitiv Data Platform Service discovery succeeded. RECEIVED:
# {
#   "services":[
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-northeast-1-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-northeast-1a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-northeast-1-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-northeast-1a",
#         "ap-northeast-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-northeast-1-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-northeast-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-southeast-1-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-southeast-1a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-southeast-1-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-southeast-1a",
#         "ap-southeast-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"ap-southeast-1-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "ap-southeast-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-central-1-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-central-1a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-central-1-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-central-1a",
#         "eu-central-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-central-1-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-central-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-west-1-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-west-1a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-west-1-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-west-1a",
#         "eu-west-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"eu-west-1-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "eu-west-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-1-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-1a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-1-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-1a",
#         "us-east-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-1-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-1b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-2-aws-1-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-2a"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-2-aws-3-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-2a",
#         "us-east-2b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     },
#     {
#       "dataFormat":[
#         "tr_json2"
#       ],
#       "endpoint":"us-east-2-aws-2-lrg.optimized-pricing-api.refinitiv.net",
#       "location":[
#         "us-east-2b"
#       ],
#       "port":443,
#       "provider":"aws",
#       "transport":"websocket"
#     }
#   ]
# }
# Connecting to WebSocket wss://us-east-1-aws-1-lrg.optimized-pricing-api.refinitiv.net:443/WebSocket ...
# WebSocket successfully connected!
# SENT:
# {
#   "Domain":"Login",
#   "ID":1,
#   "Key":{
#     "Elements":{
#       "ApplicationId":"256",
#       "AuthenticationToken":"eyJhbGciOiJSUzI1NiIsImtpZCI6ImJlcGpHV0dkOW44WU9VQ1NwX3M3SXlRMmlKMFkzeWRFaHo1VDJJVlNqWTgiLCJ0eXAiOiJhdCtqd3QifQ.....Fvs9BQGIV5arLQt5zi2JPjMSIXhUOEBINXtInyeAkERXpZvt-ZP7OZ0GbWrUNGysMiWmJRmUHrte5ObrWCPIanIroqTi-LMHonnYMiwxdUSPTTZn0kuUqMfsyg8nmtMGc3OmOVYY3ECz__YAFICLRDneDXN6edKbpQOgTR1W13FzLfyw2FYNunPfzq-VC9u5RRrfoYCvyi-0CmyoBsoDUz0S2bfhgFQVd0o_03rz6qe6AqElE9-fiZPHagK_hUIV93WtykdiDgX4mYSRS0dvRBjrRuTmirrM1Ky2Lkhgn7Vop9MvG0zpSkLctgtY5gTZzPrYWGqF1S2-tPzeMouwKg",
#       "Position":"192.168.68.118"
#     },
#     "Name":"GE-A-01103867-3-1368",
#     "NameType":"AuthnToken"
#   },
#   "Refresh":false
# }
# RECEIVED:
# SENT:
# {
#   "Domain":"NewsTextAnalytics",
#   "ID":2,
#   "Key":{
#     "Name":"MRN_TRNA",
#     "Service":"ELEKTRON_DD"
#   }
# }
# RECEIVED:
# RECEIVED: Refresh Message
# Name = PROD_PERM: Value = 10002
# Name = ACTIV_DATE: Value = 1970-01-01
# Name = RECORDTYPE: Value = 30
# Name = RDN_EXCHD2: Value = MRN
# Name = TIMACT_MS: Value = 0
# Name = GUID: Value = None
# Name = CONTEXT_ID: Value = 3929
# Name = DDS_DSO_ID: Value = 12424
# Name = SPS_SP_RIC: Value = .[SPSMANL1
# Name = MRN_V_MAJ: Value = None
# Name = MRN_TYPE: Value = None
# Name = MRN_V_MIN: Value = None
# Name = MRN_SRC: Value = na_ent0-prod-5-9-18-euw1
# Name = FRAG_NUM: Value = 0
# Name = TOT_SIZE: Value = 0
# Name = FRAGMENT: Value = None
# RECEIVED:
# FRAGMENT length = 942
# decompress News FRAGMENT(s) for GUID  tr:BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4296689152', 'R:MRCU.BO', 'R:MRCU.INx'], 'assetId': '4296689152', 'assetName': 'Mercury Laboratories Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.00782282, 'sentimentNeutral': 0.447781, 'sentimentPositive': 0.544396, 'sentimentWordCount': 82, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 1, 'window': '24H'}, {'itemCount': 1, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}]}], 'newsItem': {'bodySize': 357, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 83}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Mercury Laboratories Ltd - 538964 - Board Meeting Intimation for Approval Of The Unaudited Financial Results For The Quarter And Half Year Ended On September 30, 2025 Scheduled To Be Held On November 11, 2025', 'language': 'en', 'metadata': {'altId': 'nBSE4YTRrJ', 'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'], 'feedTimestamp': '2025-11-05T04:51:03.815Z', 'firstCreated': '2025-11-05T04:51:03.803Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:BSE', 'sourceId': 'BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K', 'sourceTimestamp': '2025-11-05T04:51:03.803Z', 'subjects': ['B:148', 'B:156', 'B:1730', 'B:277', 'G:1', 'G:5B', 'G:CH', 'G:K', 'G:S', 'M:1QD', 'M:2CM', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:MRCU.BO', 'N2:ASIA', 'N2:ASXPAC', 'N2:CMPNY', 'N2:DRUPRO', 'N2:EMRG', 'N2:HECA', 'N2:IN', 'N2:LEN', 'N2:MTPDF', 'N2:NEWR', 'N2:PHAR', 'N2:PHMR', 'N2:PUBL', 'N2:REG', 'N2:SASIA', 'P:4296689152'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 1019
# decompress News FRAGMENT(s) for GUID  tr:L6N3WH07S_2511052h/Bz4R/n75XUNGD3gC5Xu9AG6fRzjJHf9Y04P
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295904129', 'R:HOG.N'], 'assetId': '4295904129', 'assetName': 'Harley-Davidson Inc', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.118706, 'sentimentNeutral': 0.757679, 'sentimentPositive': 0.123614, 'sentimentWordCount': 61, 'volumeCounts': [{'itemCount': 2, 'window': '12H'}, {'itemCount': 10, 'window': '24H'}, {'itemCount': 10, 'window': '3D'}, {'itemCount': 10, 'window': '5D'}, {'itemCount': 10, 'window': '7D'}]}], 'newsItem': {'bodySize': 320, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': 'BRIEF', 'marketCommentary': False, 'sentenceCount': 12, 'wordCount': 204}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:L6N3WH07S_2511052h/Bz4R/n75XUNGD3gC5Xu9AG6fRzjJHf9Y04P', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'BRIEF-ハーレーダビッドソン、２０２５年に実施された新規・増加分の関税コストは第３四半期に２７００万ドル', 'language': 'ja', 'metadata': {'altId': 'nL6N3WH07S', 'audiences': ['NP:RINBX'], 'feedTimestamp': '2025-11-05T04:51:06.959Z', 'firstCreated': '2025-11-05T04:51:06.000Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'L6N3WH07S_2511052h/Bz4R/n75XUNGD3gC5Xu9AG6fRzjJHf9Y04P', 'sourceTimestamp': '2025-11-05T04:51:06.000Z', 'subjects': ['B:1293', 'B:255', 'B:71', 'B:72', 'E:1', 'E:G', 'G:4', 'G:6J', 'G:9', 'M:1A', 'M:1QD', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:2I7', 'M:BX', 'M:CR', 'M:NY', 'M:Z', 'N2:AMERS', 'N2:AUTO', 'N2:BACT', 'N2:BLR', 'N2:BOJJ', 'N2:BRIEF', 'N2:CARM', 'N2:CMPNY', 'N2:CYCS', 'N2:JLN', 'N2:LJA', 'N2:MOTBIK', 'N2:NAMER', 'N2:PUBL', 'N2:RES', 'N2:TRN', 'N2:US', 'P:4295904129', 'R:HOG.N'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 898
# decompress News FRAGMENT(s) for GUID  tr:BSEbqtgxY_2511052J9sVE433TZ+SH/WYCeYqOtxA/vvDpPDanZS90
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295873142', 'R:CEAT.BO', 'R:CEAT.NS'], 'assetId': '4295873142', 'assetName': 'CEAT Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.200723, 'sentimentNeutral': 0.60161, 'sentimentPositive': 0.197667, 'sentimentWordCount': 34, 'volumeCounts': [{'itemCount': 1, 'window': '12H'}, {'itemCount': 1, 'window': '24H'}, {'itemCount': 1, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}]}], 'newsItem': {'bodySize': 204, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 35}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:BSEbqtgxY_2511052J9sVE433TZ+SH/WYCeYqOtxA/vvDpPDanZS90', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Ceat Ltd - 500878 - CEAT Limited Has Informed The Exchange About The Further Investment In Tyresnmore Online Private Limited', 'language': 'en', 'metadata': {'altId': 'nBSEbqtgxY', 'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'], 'feedTimestamp': '2025-11-05T04:51:08.646Z', 'firstCreated': '2025-11-05T04:51:08.632Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:BSE', 'sourceId': 'BSEbqtgxY_2511052J9sVE433TZ+SH/WYCeYqOtxA/vvDpPDanZS90', 'sourceTimestamp': '2025-11-05T04:51:08.632Z', 'subjects': ['B:1308', 'B:255', 'B:71', 'B:74', 'G:1', 'G:5B', 'G:CH', 'G:K', 'G:S', 'M:1QD', 'M:1WJ', 'M:1WK', 'M:2CM', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:CEAT.NS', 'N2:ASIA', 'N2:ASXPAC', 'N2:AUTO', 'N2:CMPNY', 'N2:CONPR', 'N2:CONPS', 'N2:CYCS', 'N2:EMRG', 'N2:IN', 'N2:LEN', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:RUBB', 'N2:SASIA', 'N2:TIRETB', 'P:4295873142'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 1025
# decompress News FRAGMENT(s) for GUID  tr:BSE2VPx8F_25110523DJ2fHF4gzqiUIGPmeAMLgIbmqXV2UKxJ3JjI
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295873896', 'R:NISP.BO', 'R:NISP.INx', 'R:NISP.NS'], 'assetId': '4295873896', 'assetName': 'Nitin Spinners Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:BSE5XJNn4_2511042V0iNv1uUtPBBmJTd5runggjvoLpGl07DdR0rq'}, {'idPosition': 1, 'linkedId': 'tr:BSE84jyGV_2511042cNdWSmmg9GNojlDI2q7k32KS6lwHIXfz6jto1'}, {'idPosition': 2, 'linkedId': 'tr:BSE4VXBPj_2511042bh/WzooC4EDi70ymTzBX1S2E+jTPUV2dSEaSf'}], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 3, 'window': '24H'}, {'itemCount': 3, 'window': '3D'}, {'itemCount': 3, 'window': '5D'}, {'itemCount': 3, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.0228907, 'sentimentNeutral': 0.927307, 'sentimentPositive': 0.0498024, 'sentimentWordCount': 16, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 7, 'window': '24H'}, {'itemCount': 7, 'window': '3D'}, {'itemCount': 7, 'window': '5D'}, {'itemCount': 7, 'window': '7D'}]}], 'newsItem': {'bodySize': 248, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 40}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:BSE2VPx8F_25110523DJ2fHF4gzqiUIGPmeAMLgIbmqXV2UKxJ3JjI', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Nitin Spinners Ltd - 532698 - Announcement under Regulation 30 (LODR)-Newspaper Publication', 'language': 'en', 'metadata': {'altId': 'nBSE2VPx8F', 'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'], 'feedTimestamp': '2025-11-05T04:51:11.189Z', 'firstCreated': '2025-11-05T04:51:11.177Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:BSE', 'sourceId': 'BSE2VPx8F_25110523DJ2fHF4gzqiUIGPmeAMLgIbmqXV2UKxJ3JjI', 'sourceTimestamp': '2025-11-05T04:51:11.177Z', 'subjects': ['B:1313', 'B:255', 'B:256', 'B:82', 'B:83', 'G:1', 'G:5B', 'G:CH', 'G:K', 'G:S', 'M:1QD', 'M:1WJ', 'M:1WK', 'M:2CM', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:NISP.NS', 'N2:APPA', 'N2:ASIA', 'N2:ASXPAC', 'N2:CMPNY', 'N2:CONPR', 'N2:CONPS', 'N2:CYCP', 'N2:CYCS', 'N2:EMRG', 'N2:IN', 'N2:LEN', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:SASIA', 'N2:TXTL', 'N2:TXTL1', 'P:4295873896'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 1308
# decompress News FRAGMENT(s) for GUID  tr:BSE3wxBwL_2511052C1lq7Ny+MxrMItTAKqHEICypNBpQ7kMKZoFAQ
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5038079459', 'R:FUSN.INx', 'R:FUSN.NS'], 'assetId': '5038079459', 'assetName': 'Fusion Finance Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:BSE6tYGFL_2511042FPG/fE/f7GwHkQd4PExNmBe9nkxodJ1ipekKr'}, {'idPosition': 1, 'linkedId': 'tr:BSE7JjFNf_25110428f0OMlsh45QPsei+Ed4fkF+GCeFdQBh4KLpDI'}, {'idPosition': 2, 'linkedId': 'tr:BSE5FJNvc_2511042a2fvOuFtaiuSmUFwXWoFuxhX3Zo7GOlJUnkzv'}, {'idPosition': 3, 'linkedId': 'tr:BSE3GfgRF_2511042hbFVmNicm2hdAflEu9jGL3m6+H2+aiL61fLGC'}, {'idPosition': 4, 'linkedId': 'tr:BSE2w086M_2511042HEaTEBMkTxEpdKmx3HSCgs7w3eCSr+M/YW5Nv'}, {'idPosition': 6, 'linkedId': 'tr:BSE8Lytz1_2511042JnMks3zSdYif6ZCsItCMMsbYW0OeRd5hqwUSA'}, {'idPosition': 7, 'linkedId': 'tr:BSE7sPhSy_2511042J82fMt7Z00nndA2vt0V8fzVJM9XBZvsYEIfMY'}, {'idPosition': 8, 'linkedId': 'tr:BSEbpprlL_2511042maE74C+defO7ME4wHQ12UClEy4gsrpBkBo/GR'}, {'idPosition': 9, 'linkedId': 'tr:FWN3WG179_2511041x/SxriDgQS9TYMjt1PZCNWuFOu2me5+zhI1zM'}, {'idPosition': 10, 'linkedId': 'tr:BSE51g7Jc_2510312cRsDFASrRt+DGG76dd4nCMwuSzvckuDU1IOke'}], 'noveltyCounts': [{'itemCount': 2, 'window': '12H'}, {'itemCount': 10, 'window': '24H'}, {'itemCount': 10, 'window': '3D'}, {'itemCount': 11, 'window': '5D'}, {'itemCount': 11, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.149269, 'sentimentNeutral': 0.61654, 'sentimentPositive': 0.234192, 'sentimentWordCount': 9, 'volumeCounts': [{'itemCount': 2, 'window': '12H'}, {'itemCount': 17, 'window': '24H'}, {'itemCount': 17, 'window': '3D'}, {'itemCount': 19, 'window': '5D'}, {'itemCount': 20, 'window': '7D'}]}], 'newsItem': {'bodySize': 230, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 32}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:BSE3wxBwL_2511052C1lq7Ny+MxrMItTAKqHEICypNBpQ7kMKZoFAQ', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'FUSION FINANCE Ltd - 890214 - Statement Of Deviation', 'language': 'en', 'metadata': {'altId': 'nBSE3wxBwL', 'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'], 'feedTimestamp': '2025-11-05T04:51:30.585Z', 'firstCreated': '2025-11-05T04:51:30.569Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:BSE', 'sourceId': 'BSE3wxBwL_2511052C1lq7Ny+MxrMItTAKqHEICypNBpQ7kMKZoFAQ', 'sourceTimestamp': '2025-11-05T04:51:30.569Z', 'subjects': ['B:127', 'B:129', 'B:1626', 'B:261', 'B:262', 'G:1', 'G:5B', 'G:CH', 'G:K', 'G:S', 'M:1QD', 'M:1WN', 'M:2CM', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:FUSN.NS', 'N2:ASIA', 'N2:ASXPAC', 'N2:BISV', 'N2:BSVC', 'N2:CMPNY', 'N2:COFS', 'N2:EMRG', 'N2:FINS', 'N2:IN', 'N2:LEN', 'N2:MICFIN', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:SASIA', 'N2:SRVCS', 'P:5038079459'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 1298
# decompress News FRAGMENT(s) for GUID  tr:BSEccGR7D_2511052Ma6udoEquXT+WCjrKL12fCyxPQHnGLKUKdvqP
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5038079459', 'R:FUSN.INx', 'R:FUSN.NS'], 'assetId': '5038079459', 'assetName': 'Fusion Finance Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:BSE3wxBwL_2511052C1lq7Ny+MxrMItTAKqHEICypNBpQ7kMKZoFAQ'}, {'idPosition': 1, 'linkedId': 'tr:BSE6tYGFL_2511042FPG/fE/f7GwHkQd4PExNmBe9nkxodJ1ipekKr'}, {'idPosition': 2, 'linkedId': 'tr:BSE7JjFNf_25110428f0OMlsh45QPsei+Ed4fkF+GCeFdQBh4KLpDI'}, {'idPosition': 3, 'linkedId': 'tr:BSE5FJNvc_2511042a2fvOuFtaiuSmUFwXWoFuxhX3Zo7GOlJUnkzv'}, {'idPosition': 4, 'linkedId': 'tr:BSE3SHWJ2_2511042y1w/CEWCB7EVtW6bInsAhSYGVzp/ffx7XfY7+'}, {'idPosition': 13, 'linkedId': 'tr:BSE4ghvc7_2511042QCGb8wgYEz/ZXy9XzzQAMFui35UDyZpnIR4cH'}, {'idPosition': 14, 'linkedId': 'tr:BSE7wPq2h_251104279oRIIyF2OiyPaHnso8U1hZu/7beck+vgk1Il'}, {'idPosition': 15, 'linkedId': 'tr:FWN3WG179_2511041x/SxriDgQS9TYMjt1PZCNWuFOu2me5+zhI1zM'}, {'idPosition': 16, 'linkedId': 'tr:BSE89b0nF_2511042ry7VNwkKG/Wxp6nt95uNTZJiIZlIPne2hJcTC'}, {'idPosition': 17, 'linkedId': 'tr:BSE48YzHH_2510312xO9sx908ULHw2KTMn9UUedOAdc1tMO1GqOaQX'}], 'noveltyCounts': [{'itemCount': 3, 'window': '12H'}, {'itemCount': 17, 'window': '24H'}, {'itemCount': 17, 'window': '3D'}, {'itemCount': 18, 'window': '5D'}, {'itemCount': 18, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.149269, 'sentimentNeutral': 0.61654, 'sentimentPositive': 0.234192, 'sentimentWordCount': 9, 'volumeCounts': [{'itemCount': 3, 'window': '12H'}, {'itemCount': 18, 'window': '24H'}, {'itemCount': 18, 'window': '3D'}, {'itemCount': 20, 'window': '5D'}, {'itemCount': 21, 'window': '7D'}]}], 'newsItem': {'bodySize': 230, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 32}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:BSEccGR7D_2511052Ma6udoEquXT+WCjrKL12fCyxPQHnGLKUKdvqP', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Fusion Finance Ltd - 543652 - Statement Of Deviation', 'language': 'en', 'metadata': {'altId': 'nBSEccGR7D', 'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'], 'feedTimestamp': '2025-11-05T04:51:30.596Z', 'firstCreated': '2025-11-05T04:51:30.584Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:BSE', 'sourceId': 'BSEccGR7D_2511052Ma6udoEquXT+WCjrKL12fCyxPQHnGLKUKdvqP', 'sourceTimestamp': '2025-11-05T04:51:30.584Z', 'subjects': ['B:127', 'B:129', 'B:1626', 'B:261', 'B:262', 'G:1', 'G:5B', 'G:CH', 'G:K', 'G:S', 'M:1QD', 'M:1WN', 'M:2CM', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:FUSN.NS', 'N2:ASIA', 'N2:ASXPAC', 'N2:BISV', 'N2:BSVC', 'N2:CMPNY', 'N2:COFS', 'N2:EMRG', 'N2:FINS', 'N2:IN', 'N2:LEN', 'N2:MICFIN', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:SASIA', 'N2:SRVCS', 'P:5038079459'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 937
# decompress News FRAGMENT(s) for GUID  tr:FWN3WH00D_2511051x1G7gGhQYwDO+VqIu0w3KQr6ZVO7yd1t5NoeN
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5045880046', 'R:LITE.O', 'R:LITE.OQ'], 'assetId': '5045880046', 'assetName': 'Lumentum Holdings Inc', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WC2ZR_2510311Hu1HGSUMwP8cpypQCFLCnn4gDIeGf70UWwemP'}], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}], 'priceTargetIndicator': 'INCREASE', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.00732302, 'sentimentNeutral': 0.442096, 'sentimentPositive': 0.550581, 'sentimentWordCount': 14, 'volumeCounts': [{'itemCount': 13, 'window': '12H'}, {'itemCount': 13, 'window': '24H'}, {'itemCount': 13, 'window': '3D'}, {'itemCount': 15, 'window': '5D'}, {'itemCount': 15, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 1, 'wordCount': 14}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WH00D_2511051x1G7gGhQYwDO+VqIu0w3KQr6ZVO7yd1t5NoeN', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'LUMENTUM HOLDINGS INC <LITE.O>: JEFFERIES RAISES TARGET PRICE TO $250 FROM $140  ', 'language': 'en', 'metadata': {'altId': 'nFWN3WH00D', 'audiences': ['NP:E', 'NP:PRL', 'NP:U'], 'feedTimestamp': '2025-11-05T04:51:35.241Z', 'firstCreated': '2025-11-05T04:51:35.234Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WH00D_2511051x1G7gGhQYwDO+VqIu0w3KQr6ZVO7yd1t5NoeN', 'sourceTimestamp': '2025-11-05T04:51:35.234Z', 'subjects': ['B:1750', 'B:278', 'B:279', 'B:281', 'E:L', 'G:4', 'G:6J', 'G:9', 'M:1P2', 'M:1QD', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:NY', 'M:Z', 'R:LITE.O', 'N2:AMERS', 'N2:BLR', 'N2:CMPNY', 'N2:COMS', 'N2:COMS1', 'N2:LEN', 'N2:NAMER', 'N2:PUBL', 'N2:RCH', 'N2:TECH', 'N2:TEEQ', 'N2:TMT', 'N2:US', 'P:5045880046'], 'urgency': 1}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 963
# decompress News FRAGMENT(s) for GUID  tr:Kj5LHj____2511052lpWc2b6DwVcLapOmGT8eJbxk/YXdwcbKQvBvo
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295879813', 'R:9434.T'], 'assetId': '4295879813', 'assetName': 'SoftBank Corp', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 2, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:Kj1QIj____2511012B5lJ6PLa/PmnUklilKUeTR4Ro59fO6fyWnOd/'}], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.0474737, 'sentimentNeutral': 0.244226, 'sentimentPositive': 0.7083, 'sentimentWordCount': 66, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 1, 'window': '24H'}, {'itemCount': 7, 'window': '3D'}, {'itemCount': 10, 'window': '5D'}, {'itemCount': 42, 'window': '7D'}]}], 'newsItem': {'bodySize': 93, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 4, 'wordCount': 66}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:Kj5LHj____2511052lpWc2b6DwVcLapOmGT8eJbxk/YXdwcbKQvBvo', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'モイネロが帰国\u3000球界だより（１）', 'language': 'ja', 'metadata': {'altId': 'nKj5LHj', 'audiences': ['NP:KYDO', 'NP:KYO', 'NP:RJN'], 'feedTimestamp': '2025-11-05T04:52:37.977Z', 'firstCreated': '2025-11-05T04:52:37.868Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:KYDO', 'sourceId': 'Kj5LHj____2511052lpWc2b6DwVcLapOmGT8eJbxk/YXdwcbKQvBvo', 'sourceTimestamp': '2025-11-05T04:52:37.868Z', 'subjects': ['B:177', 'B:179', 'B:1821', 'B:278', 'G:4', 'G:41', 'G:6', 'G:7X', 'G:G', 'G:K', 'G:R', 'G:S', 'M:1P2', 'M:1QC', 'M:1QD', 'M:1WN', 'M:2CX', 'M:2DZ', 'M:5G', 'M:W', 'M:Z', 'R:9434.T', 'N2:AMERS', 'N2:ASIA', 'N2:ASXPAC', 'N2:BASE', 'N2:CARIBN', 'N2:CMPNY', 'N2:CU', 'N2:EASIA', 'N2:GLOFIN', 'N2:JP', 'N2:LATAM', 'N2:LJA', 'N2:PUBL', 'N2:SPO', 'N2:SRVCS', 'N2:TCOM', 'N2:TECH', 'N2:TMT', 'N2:WIRLSS', 'N2:WLES', 'P:4295879813'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 1055
# decompress News FRAGMENT(s) for GUID  tr:FWN3WG1TX_2511051fm7lj+a4eiQS2ixhv6ZP9Zbs5nOgV7vfyI8Ux
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4297918245', 'R:1150.SE'], 'assetId': '4297918245', 'assetName': 'Alinma Bank SJSC', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WF2I4_2511042pHi8rwxVehigy8Qk8oOeWKIAC7vzMF+9ekacc'}, {'idPosition': 1, 'linkedId': 'tr:FWN3WF2I4_25110419AYGUY2St5v7IOHwCTO6WYJXTlVIJeW1JmHBR'}, {'idPosition': 2, 'linkedId': 'tr:FWN3WE011_25110315V12o8O2WlVPaLCcLwKqwVSVC0oH+D5AdMyMG'}], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 3, 'window': '3D'}, {'itemCount': 3, 'window': '5D'}, {'itemCount': 3, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.0248654, 'sentimentNeutral': 0.13283, 'sentimentPositive': 0.842305, 'sentimentWordCount': 9, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 4, 'window': '3D'}, {'itemCount': 4, 'window': '5D'}, {'itemCount': 4, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 2, 'wordCount': 16}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WG1TX_2511051fm7lj+a4eiQS2ixhv6ZP9Zbs5nOgV7vfyI8Ux', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'ALINMA BANK - COMPLETION OF ITS OFFERING OF U.S. DOLLAR- DENOMINATED TIER 2 CERTIFICATES  ', 'language': 'en', 'metadata': {'altId': 'nFWN3WG1TX', 'audiences': ['NP:E', 'NP:GBN', 'NP:GFN'], 'feedTimestamp': '2025-11-05T04:52:49.546Z', 'firstCreated': '2025-11-05T04:52:49.537Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WG1TX_2511051fm7lj+a4eiQS2ixhv6ZP9Zbs5nOgV7vfyI8Ux', 'sourceTimestamp': '2025-11-05T04:52:49.537Z', 'subjects': ['B:127', 'B:128', 'B:1620', 'B:261', 'B:262', 'G:1', 'G:92', 'G:D3', 'G:F', 'G:H', 'G:K', 'G:Q', 'G:S', 'M:1QD', 'M:1WN', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DY', 'M:2DZ', 'M:NY', 'M:Z', 'R:1150.SE', 'N2:ASIA', 'N2:ASXPAC', 'N2:BISV', 'N2:BLR', 'N2:BNKISL', 'N2:BNKS', 'N2:BSVC', 'N2:CMPNY', 'N2:EMEA', 'N2:EMRG', 'N2:FINS', 'N2:LEN', 'N2:MEAST', 'N2:PRIVT', 'N2:PUBL', 'N2:SA', 'N2:SRVCS', 'N2:SWASIA', 'N2:TGLF', 'P:4297918245'], 'urgency': 1}}
# RECEIVED:
# FRAGMENT length = 919
# decompress News FRAGMENT(s) for GUID  tr:ASX5LcSQb_2511052c9cz8DkuOetW61fP22pZsVDEVaPF/9RS11xgR
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295858665', 'R:SKM.AX'], 'assetId': '4295858665', 'assetName': 'Skylark Minerals Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 3, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 0.707107, 'sentimentClass': 1, 'sentimentNegative': 0.121335, 'sentimentNeutral': 0.386739, 'sentimentPositive': 0.491925, 'sentimentWordCount': 273, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}]}, {'assetClass': 'COM', 'assetCodes': ['B:229', 'N2:MTAL'], 'assetId': 'MTAL', 'assetName': 'Non-Ferrous Metals', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 0, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 0, 'sentimentNegative': 0.189721, 'sentimentNeutral': 0.408674, 'sentimentPositive': 0.401604, 'sentimentWordCount': 536, 'volumeCounts': [{'itemCount': 396, 'window': '12H'}, {'itemCount': 979, 'window': '24H'}, {'itemCount': 2236, 'window': '3D'}, {'itemCount': 3236, 'window': '5D'}, {'itemCount': 6076, 'window': '7D'}]}], 'newsItem': {'bodySize': 3105, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 17, 'wordCount': 536}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:ASX5LcSQb_2511052c9cz8DkuOetW61fP22pZsVDEVaPF/9RS11xgR', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Expiry of Quoted Options-SKM.AX', 'language': 'en', 'metadata': {'altId': 'nASX5LcSQb', 'audiences': ['NP:ASX', 'NP:ASXN'], 'feedTimestamp': '2025-11-05T04:52:50.233Z', 'firstCreated': '2025-11-05T04:52:50.182Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:ASX', 'sourceId': 'ASX5LcSQb_2511052c9cz8DkuOetW61fP22pZsVDEVaPF/9RS11xgR', 'sourceTimestamp': '2025-11-05T04:52:50.182Z', 'subjects': ['B:1104', 'B:227', 'B:228', 'B:229', 'B:24', 'G:2H', 'G:5', 'G:K', 'M:1QD', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:B6', 'M:NU', 'M:Z', 'R:SKM.AX', 'N2:ASIA', 'N2:AU', 'N2:AUNZ', 'N2:BMAT', 'N2:CMPNY', 'N2:LEN', 'N2:MEMI', 'N2:MIN', 'N2:MINE', 'N2:MTAL', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:ZNORE', 'P:4295858665'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 1141
# decompress News FRAGMENT(s) for GUID  tr:ASX60P76w_2511052HwYKxSAd2GF0JmBg1tzScwGtJ3R4dI91WXDQz
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295857478', 'R:APE.AX'], 'assetId': '4295857478', 'assetName': 'Eagers Automotive Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 8, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:ASX1m7ZKN_2511052E/dS37EvufP0vaXDtGAnyLrLha80jBFvzosSr'}, {'idPosition': 1, 'linkedId': 'tr:ASX13d66V_2511052h3wjK/b0ekZYPeJHIGKJejTik7RK7ncEcyXwh'}, {'idPosition': 2, 'linkedId': 'tr:ASX8RZJLp_2511052isTc9XM0LGxhAey1+yX0CF0GFgh011tXo01U/'}, {'idPosition': 3, 'linkedId': 'tr:ASX6DnDb4_2511052w4jcbgn4UZNpgWDIPaA8zrw3r0iRB90CpQsHj'}, {'idPosition': 4, 'linkedId': 'tr:ASXpWFdF__2510302QcqtkmeMzCO6/ILUoPAjdBqAuA5VdpRCJCiYw'}], 'noveltyCounts': [{'itemCount': 4, 'window': '12H'}, {'itemCount': 4, 'window': '24H'}, {'itemCount': 4, 'window': '3D'}, {'itemCount': 4, 'window': '5D'}, {'itemCount': 5, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 0.707107, 'sentimentClass': 1, 'sentimentNegative': 0.0348166, 'sentimentNeutral': 0.12224, 'sentimentPositive': 0.842943, 'sentimentWordCount': 152, 'volumeCounts': [{'itemCount': 5, 'window': '12H'}, {'itemCount': 5, 'window': '24H'}, {'itemCount': 6, 'window': '3D'}, {'itemCount': 6, 'window': '5D'}, {'itemCount': 8, 'window': '7D'}]}], 'newsItem': {'bodySize': 5112, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 50, 'wordCount': 572}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:ASX60P76w_2511052HwYKxSAd2GF0JmBg1tzScwGtJ3R4dI91WXDQz', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': "Change of Director's Interest Notice - DUNCAN-APE.AX", 'language': 'en', 'metadata': {'altId': 'nASX60P76w', 'audiences': ['NP:ASX', 'NP:ASXN'], 'feedTimestamp': '2025-11-05T04:53:04.812Z', 'firstCreated': '2025-11-05T04:53:04.762Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:ASX', 'sourceId': 'ASX60P76w_2511052HwYKxSAd2GF0JmBg1tzScwGtJ3R4dI91WXDQz', 'sourceTimestamp': '2025-11-05T04:53:04.762Z', 'subjects': ['B:1474', 'B:202', 'B:203', 'B:234', 'B:235', 'B:236', 'B:255', 'B:39', 'B:98', 'E:1', 'E:5A', 'E:R', 'G:2H', 'G:5', 'G:K', 'M:1NN', 'M:1QD', 'M:1WJ', 'M:1WN', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:NU', 'M:Z', 'R:APE.AX', 'N2:ASIA', 'N2:AU', 'N2:AUNZ', 'N2:BACT', 'N2:CMPNY', 'N2:CONPS', 'N2:CYCS', 'N2:DEAL1', 'N2:INDG', 'N2:INDM', 'N2:INDS', 'N2:INDU', 'N2:LEN', 'N2:MACH', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'N2:SHOP', 'N2:SHOPAL', 'N2:SPCRET', 'N2:SRVCS', 'N2:STK', 'N2:VHRET', 'N2:VHRET1', 'P:4295857478'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 1017
# decompress News FRAGMENT(s) for GUID  tr:FWN3WG1TX_2511051/apigSv8s6PLoVeudKjAt492J23QDPkMaFCbY
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4297918245', 'R:1150.SE'], 'assetId': '4297918245', 'assetName': 'Alinma Bank SJSC', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WG1TX_2511051fm7lj+a4eiQS2ixhv6ZP9Zbs5nOgV7vfyI8Ux'}, {'idPosition': 1, 'linkedId': 'tr:FWN3WF2I4_25110419AYGUY2St5v7IOHwCTO6WYJXTlVIJeW1JmHBR'}, {'idPosition': 2, 'linkedId': 'tr:FWN3WE011_25110315V12o8O2WlVPaLCcLwKqwVSVC0oH+D5AdMyMG'}], 'noveltyCounts': [{'itemCount': 1, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 3, 'window': '3D'}, {'itemCount': 3, 'window': '5D'}, {'itemCount': 3, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.0288515, 'sentimentNeutral': 0.116332, 'sentimentPositive': 0.854816, 'sentimentWordCount': 10, 'volumeCounts': [{'itemCount': 1, 'window': '12H'}, {'itemCount': 3, 'window': '24H'}, {'itemCount': 5, 'window': '3D'}, {'itemCount': 5, 'window': '5D'}, {'itemCount': 5, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 1, 'wordCount': 10}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WG1TX_2511051/apigSv8s6PLoVeudKjAt492J23QDPkMaFCbY', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'ALINMA BANK- VALUE OF THE OFFER $500 MLN', 'language': 'en', 'metadata': {'altId': 'nFWN3WG1TX', 'audiences': ['NP:E', 'NP:GBN', 'NP:GFN'], 'feedTimestamp': '2025-11-05T04:53:19.998Z', 'firstCreated': '2025-11-05T04:52:49.537Z', 'isArchive': False, 'takeSequence': 3}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WG1TX_2511051/apigSv8s6PLoVeudKjAt492J23QDPkMaFCbY', 'sourceTimestamp': '2025-11-05T04:53:19.989Z', 'subjects': ['B:127', 'B:128', 'B:1620', 'B:261', 'B:262', 'G:1', 'G:92', 'G:D3', 'G:F', 'G:H', 'G:K', 'G:Q', 'G:S', 'M:1QD', 'M:1WN', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:NY', 'M:Z', 'R:1150.SE', 'N2:ASIA', 'N2:ASXPAC', 'N2:BISV', 'N2:BLR', 'N2:BNKISL', 'N2:BNKS', 'N2:BSVC', 'N2:CMPNY', 'N2:EMEA', 'N2:EMRG', 'N2:FINS', 'N2:LEN', 'N2:MEAST', 'N2:PUBL', 'N2:SA', 'N2:SRVCS', 'N2:SWASIA', 'N2:TGLF', 'P:4297918245'], 'urgency': 1}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 895
# decompress News FRAGMENT(s) for GUID  tr:FWN3WH031_2511051Pc9rNfcZB39m4kW8s1kPpQhLAuOYjL3SYMwka
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295912308', 'R:TREX.N'], 'assetId': '4295912308', 'assetName': 'Trex Company Inc', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'DECREASE', 'relevance': 1.0, 'sentimentClass': -1, 'sentimentNegative': 0.646359, 'sentimentNeutral': 0.238935, 'sentimentPositive': 0.114706, 'sentimentWordCount': 14, 'volumeCounts': [{'itemCount': 11, 'window': '12H'}, {'itemCount': 11, 'window': '24H'}, {'itemCount': 11, 'window': '3D'}, {'itemCount': 11, 'window': '5D'}, {'itemCount': 14, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 1, 'wordCount': 14}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WH031_2511051Pc9rNfcZB39m4kW8s1kPpQhLAuOYjL3SYMwka', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'TREX COMPANY INC <TREX.N>: D.A.DAVIDSON CUTS TARGET PRICE TO $45 FROM $60  ', 'language': 'en', 'metadata': {'altId': 'nFWN3WH031', 'audiences': ['NP:E', 'NP:PRL', 'NP:U'], 'feedTimestamp': '2025-11-05T04:54:10.422Z', 'firstCreated': '2025-11-05T04:54:10.414Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WH031_2511051Pc9rNfcZB39m4kW8s1kPpQhLAuOYjL3SYMwka', 'sourceTimestamp': '2025-11-05T04:54:10.414Z', 'subjects': ['B:1359', 'B:197', 'B:255', 'B:256', 'B:45', 'E:L', 'G:4', 'G:6J', 'G:9', 'M:1QD', 'M:1WJ', 'M:1WK', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:NY', 'M:Z', 'R:TREX.N', 'N2:AMERS', 'N2:BLR', 'N2:CMPNY', 'N2:CONPR', 'N2:CONPS', 'N2:CONS', 'N2:CONS1', 'N2:CYCP', 'N2:CYCS', 'N2:HSEBLD', 'N2:LEN', 'N2:NAMER', 'N2:PUBL', 'N2:RCH', 'N2:US', 'P:4295912308'], 'urgency': 1}}
# RECEIVED:
# FRAGMENT length = 964
# decompress News FRAGMENT(s) for GUID  tr:ASXc1dQPr_2511052brdhlm7xCzmqZ1HAoAlYpdslMyYgR0cB8ky0d
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5079706433', 'R:ARR.AUX', 'R:ARR.AX'], 'assetId': '5079706433', 'assetName': 'American Rare Earths Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 8, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 0.333333, 'sentimentClass': 0, 'sentimentNegative': 0.0141482, 'sentimentNeutral': 0.810077, 'sentimentPositive': 0.175775, 'sentimentWordCount': 12, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}]}, {'assetClass': 'COM', 'assetCodes': ['B:229', 'N2:MTAL'], 'assetId': 'MTAL', 'assetName': 'Non-Ferrous Metals', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 0, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': -1, 'sentimentNegative': 0.433631, 'sentimentNeutral': 0.282621, 'sentimentPositive': 0.283748, 'sentimentWordCount': 523, 'volumeCounts': [{'itemCount': 397, 'window': '12H'}, {'itemCount': 980, 'window': '24H'}, {'itemCount': 2237, 'window': '3D'}, {'itemCount': 3236, 'window': '5D'}, {'itemCount': 6075, 'window': '7D'}]}], 'newsItem': {'bodySize': 4451, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 34, 'wordCount': 523}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:ASXc1dQPr_2511052brdhlm7xCzmqZ1HAoAlYpdslMyYgR0cB8ky0d', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': "Change of Director's Interest Notice-ARR.AX", 'language': 'en', 'metadata': {'altId': 'nASXc1dQPr', 'audiences': ['NP:ASX', 'NP:ASXN'], 'feedTimestamp': '2025-11-05T04:54:20.641Z', 'firstCreated': '2025-11-05T04:54:20.591Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:ASX', 'sourceId': 'ASXc1dQPr_2511052brdhlm7xCzmqZ1HAoAlYpdslMyYgR0cB8ky0d', 'sourceTimestamp': '2025-11-05T04:54:20.591Z', 'subjects': ['B:1077', 'B:227', 'B:228', 'B:229', 'B:230', 'E:1', 'E:5A', 'E:R', 'G:2H', 'G:5', 'G:K', 'M:1NP', 'M:1QD', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:B6', 'M:NU', 'M:Z', 'R:ARR.AX', 'N2:ASIA', 'N2:AU', 'N2:AUNZ', 'N2:BACT', 'N2:BMAT', 'N2:CMPNY', 'N2:DEAL1', 'N2:INDU', 'N2:LEN', 'N2:MIN', 'N2:MINE', 'N2:MTAL', 'N2:MTPDF', 'N2:NEWR', 'N2:PREC', 'N2:PRECAL', 'N2:PUBL', 'N2:REARTH', 'N2:REG', 'N2:STK', 'P:5079706433'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 1032
# decompress News FRAGMENT(s) for GUID  tr:Kj5LFj____2511052IK67BG11EoQjJUTvXdg3JQJMO3uCelUmZRnRO
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295880516', 'R:8001.T', 'R:ITOCY.PK'], 'assetId': '4295880516', 'assetName': 'Itochu Corp', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.0421708, 'sentimentNeutral': 0.175141, 'sentimentPositive': 0.782688, 'sentimentWordCount': 61, 'volumeCounts': [{'itemCount': 6, 'window': '12H'}, {'itemCount': 8, 'window': '24H'}, {'itemCount': 8, 'window': '3D'}, {'itemCount': 9, 'window': '5D'}, {'itemCount': 11, 'window': '7D'}]}], 'newsItem': {'bodySize': 158, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 6, 'wordCount': 108}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:Kj5LFj____2511052IK67BG11EoQjJUTvXdg3JQJMO3uCelUmZRnRO', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': '米関税１５％であれば流通の中では吸収できる＝伊藤忠商事社長', 'language': 'ja', 'metadata': {'altId': 'nKj5LFj', 'audiences': ['NP:KYDO', 'NP:KYO', 'NP:RJN'], 'feedTimestamp': '2025-11-05T04:54:42.110Z', 'firstCreated': '2025-11-05T04:54:42.095Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:KYDO', 'sourceId': 'Kj5LFj____2511052IK67BG11EoQjJUTvXdg3JQJMO3uCelUmZRnRO', 'sourceTimestamp': '2025-11-05T04:54:42.095Z', 'subjects': ['B:1203', 'B:2', 'B:219', 'B:234', 'B:239', 'B:5', 'B:8', 'E:5', 'G:1', 'G:38', 'G:4', 'G:41', 'G:6', 'G:6J', 'G:9', 'G:A', 'G:AJ', 'G:B', 'G:D3', 'G:E', 'G:K', 'G:S', 'M:1QC', 'M:1QD', 'M:1WJ', 'M:1WK', 'M:1WM', 'M:1WN', 'M:2CX', 'M:2DZ', 'M:E7', 'M:N', 'M:Z', 'R:8001.T', 'N2:AMERS', 'N2:ASIA', 'N2:ASXPAC', 'N2:CEEU', 'N2:CISC', 'N2:CMPNY', 'N2:CONPR', 'N2:CONPS', 'N2:EASIA', 'N2:ECON', 'N2:EMEA', 'N2:EMRG', 'N2:ENER', 'N2:ENFF', 'N2:EUROP', 'N2:EUROPE', 'N2:GEN', 'N2:GLOFIN', 'N2:INDGWH', 'N2:INDS', 'N2:ISER', 'N2:JP', 'N2:LJA', 'N2:MCE', 'N2:NAMER', 'N2:NASIA', 'N2:OILG', 'N2:POL', 'N2:PUBL', 'N2:REFI', 'N2:RU', 'N2:SRVCS', 'N2:US', 'N2:WHLS', 'P:4295880516'], 'urgency': 3}}
# RECEIVED:
# FRAGMENT length = 976
# decompress News FRAGMENT(s) for GUID  tr:FWN3WG23A_25110528mVlXz+ZdsvrsWUOWeVda/cjt0usOPQXLVaZu
# ...
# RECEIVED:
# FRAGMENT length = 954
# decompress News FRAGMENT(s) for GUID  tr:L4N3WH0DU_2511052mh2s//hkxuCBFthxXbKiW9hFlLIyQAe/jTIIb
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295869482', 'R:DB.N', 'R:DBKGn.DE', 'R:DBKGn.F'], 'assetId': '4295869482', 'assetName': 'Deutsche Bank AG', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.0586398, 'sentimentNeutral': 0.220501, 'sentimentPositive': 0.720859, 'sentimentWordCount': 15, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 7, 'window': '3D'}, {'itemCount': 7, 'window': '5D'}, {'itemCount': 61, 'window': '7D'}]}], 'newsItem': {'bodySize': 199, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': 'MEDIA', 'marketCommentary': False, 'sentenceCount': 3, 'wordCount': 44}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:L4N3WH0DU_2511052mh2s//hkxuCBFthxXbKiW9hFlLIyQAe/jTIIb', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'MEDIA-Deutsche explores hedges for data centre exposure as AI lending booms - FT', 'language': 'en', 'metadata': {'altId': 'nL4N3WH0DU', 'audiences': ['NP:E', 'NP:PRL', 'NP:PSC'], 'feedTimestamp': '2025-11-05T05:07:01.886Z', 'firstCreated': '2025-11-05T05:07:01.000Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'L4N3WH0DU_2511052mh2s//hkxuCBFthxXbKiW9hFlLIyQAe/jTIIb', 'sourceTimestamp': '2025-11-05T05:07:01.000Z', 'subjects': ['B:125', 'B:127', 'B:128', 'B:1615', 'B:172', 'B:1869', 'B:261', 'B:262', 'B:278', 'B:290', 'G:3', 'G:3D', 'G:A', 'G:AL', 'G:B', 'G:D3', 'M:1P2', 'M:1QD', 'M:1YE', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:2K', 'M:E7', 'M:NY', 'M:V', 'M:Z', 'N2:ARTI', 'N2:BISV', 'N2:BLR', 'N2:BNKS', 'N2:BNKS1', 'N2:BSVC', 'N2:CEEU', 'N2:CMPNY', 'N2:DE', 'N2:EMEA', 'N2:EUROP', 'N2:EZC', 'N2:FINS', 'N2:FINS08', 'N2:GEN', 'N2:ITSE', 'N2:LEN', 'N2:MLAISV', 'N2:PRESS', 'N2:PUBL', 'N2:SCI', 'N2:SWIT', 'N2:TECH', 'N2:TMT', 'N2:WEU', 'N2:XRNP', 'P:4295869482', 'R:DBKGn.DE'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 915
# decompress News FRAGMENT(s) for GUID  tr:FWN3WH038_2511051F1tiZs1hvpDDhu8cyKExF8DchyQuBEl6XZ+OV
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4296025423', 'R:PTCT.O', 'R:PTCT.OQ'], 'assetId': '4296025423', 'assetName': 'PTC Therapeutics Inc', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WG1M7_2511051BnSFwjtgupWOWIyX7osGxO4rlK9UAATW4DgWk'}], 'noveltyCounts': [{'itemCount': 1, 'window': '12H'}, {'itemCount': 1, 'window': '24H'}, {'itemCount': 1, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}], 'priceTargetIndicator': 'INCREASE', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.00744181, 'sentimentNeutral': 0.443481, 'sentimentPositive': 0.549077, 'sentimentWordCount': 15, 'volumeCounts': [{'itemCount': 11, 'window': '12H'}, {'itemCount': 11, 'window': '24H'}, {'itemCount': 11, 'window': '3D'}, {'itemCount': 13, 'window': '5D'}, {'itemCount': 13, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 1, 'wordCount': 15}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WH038_2511051F1tiZs1hvpDDhu8cyKExF8DchyQuBEl6XZ+OV', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'PTC THERAPEUTICS INC <PTCT.O>: TD COWEN RAISES TARGET PRICE TO $63 FROM $50  ', 'language': 'en', 'metadata': {'altId': 'nFWN3WH038', 'audiences': ['NP:E', 'NP:PRL', 'NP:U'], 'feedTimestamp': '2025-11-05T05:07:18.962Z', 'firstCreated': '2025-11-05T05:07:18.955Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WH038_2511051F1tiZs1hvpDDhu8cyKExF8DchyQuBEl6XZ+OV', 'sourceTimestamp': '2025-11-05T05:07:18.955Z', 'subjects': ['B:148', 'B:156', 'B:1729', 'B:277', 'E:L', 'G:4', 'G:6J', 'G:9', 'M:1QD', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:NY', 'M:Z', 'R:PTCT.O', 'N2:AMERS', 'N2:BLR', 'N2:CMPNY', 'N2:HECA', 'N2:LEN', 'N2:NAMER', 'N2:PHAR', 'N2:PHAR1', 'N2:PHMR', 'N2:PUBL', 'N2:RCH', 'N2:US', 'P:4296025423'], 'urgency': 1}}
# RECEIVED:
# FRAGMENT length = 991
# decompress News FRAGMENT(s) for GUID  tr:FWN3WG23F_2511052OEJYHg/zRDFXPqmE2wUMf3pL8OvQiLgpzzZyU
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:4295882861', 'R:MABK.KW'], 'assetId': '4295882861', 'assetName': 'Mabanee Company KPSC', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WG23F_2511051VBLERdibjlBXNL7nNBOgAye7krq8fHHiJy09k'}, {'idPosition': 1, 'linkedId': 'tr:FWN3WG23F_2511051ud2MFKVdfVWfN+pUrGO5XA2btuvxadweTaX+P'}], 'noveltyCounts': [{'itemCount': 2, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 2, 'window': '3D'}, {'itemCount': 2, 'window': '5D'}, {'itemCount': 2, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.087153, 'sentimentNeutral': 0.318447, 'sentimentPositive': 0.5944, 'sentimentWordCount': 38, 'volumeCounts': [{'itemCount': 2, 'window': '12H'}, {'itemCount': 2, 'window': '24H'}, {'itemCount': 2, 'window': '3D'}, {'itemCount': 2, 'window': '5D'}, {'itemCount': 2, 'window': '7D'}]}], 'newsItem': {'bodySize': 244, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': 'BRIEF', 'marketCommentary': False, 'sentenceCount': 5, 'wordCount': 53}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WG23F_2511052OEJYHg/zRDFXPqmE2wUMf3pL8OvQiLgpzzZyU', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'BRIEF-Mabanee Signs Islamic Sustainable Financial Facility Of KD 25 Mln', 'language': 'en', 'metadata': {'altId': 'nFWN3WG23F', 'audiences': ['NP:E', 'NP:GFN', 'NP:PSC', 'NP:RNP', 'NP:DNP', 'NP:PCO'], 'feedTimestamp': '2025-11-05T05:07:30.543Z', 'firstCreated': '2025-11-05T05:07:30.000Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WG23F_2511052OEJYHg/zRDFXPqmE2wUMf3pL8OvQiLgpzzZyU', 'sourceTimestamp': '2025-11-05T05:07:30.000Z', 'subjects': ['A:2', 'A:E', 'A:U', 'B:141', 'B:143', 'B:1668', 'B:213', 'G:1', 'G:7Q', 'G:D3', 'G:F', 'G:H', 'G:K', 'G:Q', 'G:S', 'M:1QD', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:2I7', 'M:M4', 'M:NY', 'M:Z', 'N2:ASIA', 'N2:ASXPAC', 'N2:BLR', 'N2:BRIEF', 'N2:CDM', 'N2:CMPNY', 'N2:DBT', 'N2:EMEA', 'N2:EMRG', 'N2:ISLF', 'N2:KW', 'N2:LEN', 'N2:LOA', 'N2:MEAST', 'N2:PUBL', 'N2:REAL', 'N2:REALE', 'N2:REALE1', 'N2:REOP', 'N2:SWASIA', 'N2:TGLF', 'P:4295882861', 'R:MABK.KW'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 926
# decompress News FRAGMENT(s) for GUID  tr:FWN3WH062_2511051mR4bmGX3SYwgN15fcuo0eDOz+HsWX41Fwtjf1
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5066605934', 'R:MIRM.O', 'R:MIRM.OQ'], 'assetId': '5066605934', 'assetName': 'Mirum Pharmaceuticals Inc', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 1, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:FWN3WG1Y0_2511051280ULSxM3eiux3UJK0GI3d6AMVWpafIvFximI'}], 'noveltyCounts': [{'itemCount': 1, 'window': '12H'}, {'itemCount': 1, 'window': '24H'}, {'itemCount': 1, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 1, 'window': '7D'}], 'priceTargetIndicator': 'INCREASE', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.00732302, 'sentimentNeutral': 0.442096, 'sentimentPositive': 0.550581, 'sentimentWordCount': 14, 'volumeCounts': [{'itemCount': 11, 'window': '12H'}, {'itemCount': 11, 'window': '24H'}, {'itemCount': 12, 'window': '3D'}, {'itemCount': 13, 'window': '5D'}, {'itemCount': 13, 'window': '7D'}]}], 'newsItem': {'bodySize': 0, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 1, 'wordCount': 14}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:FWN3WH062_2511051mR4bmGX3SYwgN15fcuo0eDOz+HsWX41Fwtjf1', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'MIRUM PHARMACEUTICALS INC <MIRM.O>: BAIRD RAISES TARGET PRICE TO $80 FROM $72  ', 'language': 'en', 'metadata': {'altId': 'nFWN3WH062', 'audiences': ['NP:E', 'NP:PRL', 'NP:U'], 'feedTimestamp': '2025-11-05T05:08:09.483Z', 'firstCreated': '2025-11-05T05:08:09.476Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:RTRS', 'sourceId': 'FWN3WH062_2511051mR4bmGX3SYwgN15fcuo0eDOz+HsWX41Fwtjf1', 'sourceTimestamp': '2025-11-05T05:08:09.476Z', 'subjects': ['B:148', 'B:156', 'B:1729', 'B:277', 'E:L', 'G:4', 'G:6J', 'G:9', 'M:1QD', 'M:2CM', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CR', 'M:2CS', 'M:2CT', 'M:2CU', 'M:2CV', 'M:2CW', 'M:2CX', 'M:2CY', 'M:2CZ', 'M:2D0', 'M:2D1', 'M:2DZ', 'M:NY', 'M:Z', 'R:MIRM.O', 'N2:AMERS', 'N2:BLR', 'N2:CMPNY', 'N2:HECA', 'N2:LEN', 'N2:NAMER', 'N2:PHAR', 'N2:PHAR1', 'N2:PHMR', 'N2:PUBL', 'N2:RCH', 'N2:US', 'P:5066605934'], 'urgency': 1}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# RECEIVED:
# FRAGMENT length = 1025
# decompress News FRAGMENT(s) for GUID  tr:ASX5tNPYQ_2511052zsibfp7ad2T4l9GK7lkgP1s5X/YMwmwm4u73h
# News = {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY', 'assetCodes': ['P:5062343304'], 'assetId': '5062343304', 'assetName': 'Pivotal Metals Ltd', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 10, 'linkedIds': [{'idPosition': 0, 'linkedId': 'tr:ASXc7nNj6_2511022SHFOtjtsEiV1fz5f0qDHIPXI26rrrdsJKcJzR'}, {'idPosition': 1, 'linkedId': 'tr:ASXbM3cJP_2510302lssXinINokgNhe6hrUeYZrIKT8RZhw3aIht4f'}], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 1, 'window': '3D'}, {'itemCount': 1, 'window': '5D'}, {'itemCount': 2, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 0.0358057, 'sentimentClass': 0, 'sentimentNegative': 0.252779, 'sentimentNeutral': 0.389968, 'sentimentPositive': 0.357252, 'sentimentWordCount': 51, 'volumeCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 3, 'window': '3D'}, {'itemCount': 3, 'window': '5D'}, {'itemCount': 7, 'window': '7D'}]}, {'assetClass': 'COM', 'assetCodes': ['B:229', 'N2:MTAL'], 'assetId': 'MTAL', 'assetName': 'Non-Ferrous Metals', 'brokerAction': 'UNDEFINED', 'firstMentionSentence': 0, 'linkedIds': [], 'noveltyCounts': [{'itemCount': 0, 'window': '12H'}, {'itemCount': 0, 'window': '24H'}, {'itemCount': 0, 'window': '3D'}, {'itemCount': 0, 'window': '5D'}, {'itemCount': 0, 'window': '7D'}], 'priceTargetIndicator': 'UNDEFINED', 'relevance': 1.0, 'sentimentClass': 1, 'sentimentNegative': 0.364688, 'sentimentNeutral': 0.224465, 'sentimentPositive': 0.410846, 'sentimentWordCount': 9541, 'volumeCounts': [{'itemCount': 401, 'window': '12H'}, {'itemCount': 983, 'window': '24H'}, {'itemCount': 2244, 'window': '3D'}, {'itemCount': 3223, 'window': '5D'}, {'itemCount': 6077, 'window': '7D'}]}], 'newsItem': {'bodySize': 76280, 'companyCount': 1, 'exchangeAction': 'UNDEFINED', 'headlineTag': '', 'marketCommentary': False, 'sentenceCount': 463, 'wordCount': 9541}, 'systemVersion': 'TS:40080171'}, 'id': 'tr:ASX5tNPYQ_2511052zsibfp7ad2T4l9GK7lkgP1s5X/YMwmwm4u73h', 'newsItem': {'dataType': 'News', 'feedFamilyCode': 'tr', 'headline': 'Appendix 2A Amendment-PVT.AX', 'language': 'en', 'metadata': {'altId': 'nASX5tNPYQ', 'audiences': ['NP:ASX', 'NP:ASXN'], 'feedTimestamp': '2025-11-05T05:08:35.155Z', 'firstCreated': '2025-11-05T05:08:34.891Z', 'isArchive': False, 'takeSequence': 1}, 'provider': 'NS:ASX', 'sourceId': 'ASX5tNPYQ_2511052zsibfp7ad2T4l9GK7lkgP1s5X/YMwmwm4u73h', 'sourceTimestamp': '2025-11-05T05:08:34.891Z', 'subjects': ['B:1100', 'B:227', 'B:228', 'B:229', 'B:24', 'G:2H', 'G:5', 'G:K', 'M:1QD', 'M:2CN', 'M:2CP', 'M:2CQ', 'M:2CU', 'M:2CX', 'M:2DZ', 'M:32', 'M:3H', 'M:B6', 'M:NU', 'M:Z', 'R:PVT.AX', 'N2:ASIA', 'N2:AU', 'N2:AUNZ', 'N2:BMAT', 'N2:CMPNY', 'N2:LEN', 'N2:MEMI', 'N2:MEMI1', 'N2:MIN', 'N2:MINE', 'N2:MTAL', 'N2:MTPDF', 'N2:NEWR', 'N2:PUBL', 'N2:REG', 'P:5062343304'], 'urgency': 3}}
# RECEIVED:
# SENT:
# {
#   "Type":"Pong"
# }
# Sending authentication request with refresh token to https://api.refinitiv.com/auth/oauth2/v1/token ...
# Refinitiv Data Platform Authentication succeeded. RECEIVED:
# {
#   "access_token":"eyJhbGciOiJSUzI1NiIsImtpZCI6ImJlcGpHV0dkOW44WU9VQ1NwX3M3SXlRMmlKMFkzeWRFaHo1VDJJVlNqWTgiLCJ0eXAiOiJhdCtqd3QifQ.....GI9CMWGHhtxVP8NOx-G0PhZnoZFUWKHV4qBpEWqyCPcV_EwOZ6I62qnWC5T3vJ8xPJuRMJSHgePCPw0hROC29Kf5XDztgSHpla6rT0qrkf6ZbyIguq8OYV-GR1JmgtSlOqh_xf5lHxLmaJ5MwIRXsq0-4bNxHwCpjCDxcbAImJTNHfmxNDK147eubUPzHFEzUPSecgf3coMrhqzMSqfuQj5G6Ui5SlJGNDMXwrhRNwL7Af6R-uCneZVh9lGxLjViDLY47D8AiCchu6_kgplzuRDUdKE7pDWG4tpuhZZpxyBNkOhLqiIv3LgUcevNQdkqDZgXNuRqJDKPwGjjzMGKwA",
#   "expires_in":"600",
#   "refresh_token":"b8f14f19-3ced-42f7-87f1-54ae5df617d0",
#   "scope":"trapi.streaming.pricing.read",
#   "token_type":"Bearer"
# }
# Refreshing the access token
# SENT:
# {
#   "Domain":"Login",
#   "ID":1,
#   "Key":{
#     "Elements":{
#       "ApplicationId":"256",
#       "AuthenticationToken":"eyJhbGciOiJSUzI1NiIsImtpZCI6ImJlcGpHV0dkOW44WU9VQ1NwX3M3SXlRMmlKMFkzeWRFaHo1VDJJVlNqWTgiLCJ0eXAiOiJhdCtqd3QifQ.....GI9CMWGHhtxVP8NOx-G0PhZnoZFUWKHV4qBpEWqyCPcV_EwOZ6I62qnWC5T3vJ8xPJuRMJSHgePCPw0hROC29Kf5XDztgSHpla6rT0qrkf6ZbyIguq8OYV-GR1JmgtSlOqh_xf5lHxLmaJ5MwIRXsq0-4bNxHwCpjCDxcbAImJTNHfmxNDK147eubUPzHFEzUPSecgf3coMrhqzMSqfuQj5G6Ui5SlJGNDMXwrhRNwL7Af6R-uCneZVh9lGxLjViDLY47D8AiCchu6_kgplzuRDUdKE7pDWG4tpuhZZpxyBNkOhLqiIv3LgUcevNQdkqDZgXNuRqJDKPwGjjzMGKwA",
#       "Position":"192.168.68.118"
#     },
#     "Name":"GE-A-01103867-3-1368",
#     "NameType":"AuthnToken"
#   },
#   "Refresh":false
# }
# Close connection
# Closing the WebSocket connection
# WebSocket Closed

# %% [markdown]
# Check News Messages

# %%
_trna_messages[0:3]
# Out:
# [{'analytics': {'analyticsScores': [{'assetClass': 'CMPNY',
#      'assetCodes': ['P:4296689152', 'R:MRCU.BO', 'R:MRCU.INx'],
#      'assetId': '4296689152',
#      'assetName': 'Mercury Laboratories Ltd',
#      'brokerAction': 'UNDEFINED',
#      'firstMentionSentence': 1,
#      'linkedIds': [],
#      'noveltyCounts': [{'itemCount': 0, 'window': '12H'},
#       {'itemCount': 0, 'window': '24H'},
#       {'itemCount': 0, 'window': '3D'},
#       {'itemCount': 0, 'window': '5D'},
#       {'itemCount': 0, 'window': '7D'}],
#      'priceTargetIndicator': 'UNDEFINED',
#      'relevance': 1.0,
#      'sentimentClass': 1,
#      'sentimentNegative': 0.00782282,
#      'sentimentNeutral': 0.447781,
#      'sentimentPositive': 0.544396,
#      'sentimentWordCount': 82,
#      'volumeCounts': [{'itemCount': 0, 'window': '12H'},
#       {'itemCount': 1, 'window': '24H'},
#       {'itemCount': 1, 'window': '3D'},
#       {'itemCount': 1, 'window': '5D'},
#       {'itemCount': 1, 'window': '7D'}]}],
#    'newsItem': {'bodySize': 357,
#     'companyCount': 1,
#     'exchangeAction': 'UNDEFINED',
#     'headlineTag': '',
#     'marketCommentary': False,
#     'sentenceCount': 3,
#     'wordCount': 83},
#    'systemVersion': 'TS:40080171'},
#   'id': 'tr:BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K',
#   'newsItem': {'dataType': 'News',
#    'feedFamilyCode': 'tr',
#    'headline': 'Mercury Laboratories Ltd - 538964 - Board Meeting Intimation for Approval Of The Unaudited Financial Results For The Quarter And Half Year Ended On September 30, 2025 Scheduled To Be Held On November 11, 2025',
#    'language': 'en',
#    'metadata': {'altId': 'nBSE4YTRrJ',
#     'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'],
#     'feedTimestamp': '2025-11-05T04:51:03.815Z',
#     'firstCreated': '2025-11-05T04:51:03.803Z',
#     'isArchive': False,
#     'takeSequence': 1},
#    'provider': 'NS:BSE',
#    'sourceId': 'BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K',
#    'sourceTimestamp': '2025-11-05T04:51:03.803Z',
#    'subjects': ['B:148',
#     'B:156',
#     'B:1730',
#     'B:277',
#     'G:1',
#     'G:5B',
#     'G:CH',
#     'G:K',
#     'G:S',
#     'M:1QD',
#     'M:2CM',
#     'M:2CQ',
#     'M:2CU',
#     'M:2CX',
#     'M:2DZ',
#     'M:32',
#     'M:3H',
#     'M:NU',
#     'M:Z',
#     'R:MRCU.BO',
#     'N2:ASIA',
#     'N2:ASXPAC',
#     'N2:CMPNY',
#     'N2:DRUPRO',
#     'N2:EMRG',
#     'N2:HECA',
#     'N2:IN',
#     'N2:LEN',
#     'N2:MTPDF',
#     'N2:NEWR',
#     'N2:PHAR',
#     'N2:PHMR',
#     'N2:PUBL',
#     'N2:REG',
#     'N2:SASIA',
#     'P:4296689152'],
#    'urgency': 3}},
#  {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY',
#      'assetCodes': ['P:4295904129', 'R:HOG.N'],
#      'assetId': '4295904129',
#      'assetName': 'Harley-Davidson Inc',
#      'brokerAction': 'UNDEFINED',
#      'firstMentionSentence': 1,
#      'linkedIds': [],
#      'noveltyCounts': [{'itemCount': 0, 'window': '12H'},
#       {'itemCount': 0, 'window': '24H'},
#       {'itemCount': 0, 'window': '3D'},
#       {'itemCount': 0, 'window': '5D'},
#       {'itemCount': 0, 'window': '7D'}],
#      'priceTargetIndicator': 'UNDEFINED',
#      'relevance': 1.0,
#      'sentimentClass': 0,
#      'sentimentNegative': 0.118706,
#      'sentimentNeutral': 0.757679,
#      'sentimentPositive': 0.123614,
#      'sentimentWordCount': 61,
#      'volumeCounts': [{'itemCount': 2, 'window': '12H'},
#       {'itemCount': 10, 'window': '24H'},
#       {'itemCount': 10, 'window': '3D'},
#       {'itemCount': 10, 'window': '5D'},
#       {'itemCount': 10, 'window': '7D'}]}],
#    'newsItem': {'bodySize': 320,
#     'companyCount': 1,
#     'exchangeAction': 'UNDEFINED',
#     'headlineTag': 'BRIEF',
#     'marketCommentary': False,
#     'sentenceCount': 12,
#     'wordCount': 204},
#    'systemVersion': 'TS:40080171'},
#   'id': 'tr:L6N3WH07S_2511052h/Bz4R/n75XUNGD3gC5Xu9AG6fRzjJHf9Y04P',
#   'newsItem': {'dataType': 'News',
#    'feedFamilyCode': 'tr',
#    'headline': 'BRIEF-ハーレーダビッドソン、２０２５年に実施された新規・増加分の関税コストは第３四半期に２７００万ドル',
#    'language': 'ja',
#    'metadata': {'altId': 'nL6N3WH07S',
#     'audiences': ['NP:RINBX'],
#     'feedTimestamp': '2025-11-05T04:51:06.959Z',
#     'firstCreated': '2025-11-05T04:51:06.000Z',
#     'isArchive': False,
#     'takeSequence': 1},
#    'provider': 'NS:RTRS',
#    'sourceId': 'L6N3WH07S_2511052h/Bz4R/n75XUNGD3gC5Xu9AG6fRzjJHf9Y04P',
#    'sourceTimestamp': '2025-11-05T04:51:06.000Z',
#    'subjects': ['B:1293',
#     'B:255',
#     'B:71',
#     'B:72',
#     'E:1',
#     'E:G',
#     'G:4',
#     'G:6J',
#     'G:9',
#     'M:1A',
#     'M:1QD',
#     'M:2CM',
#     'M:2CN',
#     'M:2CP',
#     'M:2CQ',
#     'M:2CR',
#     'M:2CS',
#     'M:2CT',
#     'M:2CU',
#     'M:2CV',
#     'M:2CW',
#     'M:2CX',
#     'M:2CY',
#     'M:2CZ',
#     'M:2D0',
#     'M:2D1',
#     'M:2DZ',
#     'M:2I7',
#     'M:BX',
#     'M:CR',
#     'M:NY',
#     'M:Z',
#     'N2:AMERS',
#     'N2:AUTO',
#     'N2:BACT',
#     'N2:BLR',
#     'N2:BOJJ',
#     'N2:BRIEF',
#     'N2:CARM',
#     'N2:CMPNY',
#     'N2:CYCS',
#     'N2:JLN',
#     'N2:LJA',
#     'N2:MOTBIK',
#     'N2:NAMER',
#     'N2:PUBL',
#     'N2:RES',
#     'N2:TRN',
#     'N2:US',
#     'P:4295904129',
#     'R:HOG.N'],
#    'urgency': 3}},
#  {'analytics': {'analyticsScores': [{'assetClass': 'CMPNY',
#      'assetCodes': ['P:4295873142', 'R:CEAT.BO', 'R:CEAT.NS'],
#      'assetId': '4295873142',
#      'assetName': 'CEAT Ltd',
#      'brokerAction': 'UNDEFINED',
#      'firstMentionSentence': 1,
#      'linkedIds': [],
#      'noveltyCounts': [{'itemCount': 0, 'window': '12H'},
#       {'itemCount': 0, 'window': '24H'},
#       {'itemCount': 0, 'window': '3D'},
#       {'itemCount': 0, 'window': '5D'},
#       {'itemCount': 0, 'window': '7D'}],
#      'priceTargetIndicator': 'UNDEFINED',
#      'relevance': 1.0,
#      'sentimentClass': 0,
#      'sentimentNegative': 0.200723,
#      'sentimentNeutral': 0.60161,
#      'sentimentPositive': 0.197667,
#      'sentimentWordCount': 34,
#      'volumeCounts': [{'itemCount': 1, 'window': '12H'},
#       {'itemCount': 1, 'window': '24H'},
#       {'itemCount': 1, 'window': '3D'},
#       {'itemCount': 1, 'window': '5D'},
#       {'itemCount': 1, 'window': '7D'}]}],
#    'newsItem': {'bodySize': 204,
#     'companyCount': 1,
#     'exchangeAction': 'UNDEFINED',
#     'headlineTag': '',
#     'marketCommentary': False,
#     'sentenceCount': 3,
#     'wordCount': 35},
#    'systemVersion': 'TS:40080171'},
#   'id': 'tr:BSEbqtgxY_2511052J9sVE433TZ+SH/WYCeYqOtxA/vvDpPDanZS90',
#   'newsItem': {'dataType': 'News',
#    'feedFamilyCode': 'tr',
#    'headline': 'Ceat Ltd - 500878 - CEAT Limited Has Informed The Exchange About The Further Investment In Tyresnmore Online Private Limited',
#    'language': 'en',
#    'metadata': {'altId': 'nBSEbqtgxY',
#     'audiences': ['NP:BSEA', 'NP:BSEN', 'NP:CNR', 'NP:CNRA'],
#     'feedTimestamp': '2025-11-05T04:51:08.646Z',
#     'firstCreated': '2025-11-05T04:51:08.632Z',
#     'isArchive': False,
#     'takeSequence': 1},
#    'provider': 'NS:BSE',
#    'sourceId': 'BSEbqtgxY_2511052J9sVE433TZ+SH/WYCeYqOtxA/vvDpPDanZS90',
#    'sourceTimestamp': '2025-11-05T04:51:08.632Z',
#    'subjects': ['B:1308',
#     'B:255',
#     'B:71',
#     'B:74',
#     'G:1',
#     'G:5B',
#     'G:CH',
#     'G:K',
#     'G:S',
#     'M:1QD',
#     'M:1WJ',
#     'M:1WK',
#     'M:2CM',
#     'M:2CQ',
#     'M:2CU',
#     'M:2CX',
#     'M:2DZ',
#     'M:32',
#     'M:3H',
#     'M:NU',
#     'M:Z',
#     'R:CEAT.NS',
#     'N2:ASIA',
#     'N2:ASXPAC',
#     'N2:AUTO',
#     'N2:CMPNY',
#     'N2:CONPR',
#     'N2:CONPS',
#     'N2:CYCS',
#     'N2:EMRG',
#     'N2:IN',
#     'N2:LEN',
#     'N2:MTPDF',
#     'N2:NEWR',
#     'N2:PUBL',
#     'N2:REG',
#     'N2:RUBB',
#     'N2:SASIA',
#     'N2:TIRETB',
#     'P:4295873142'],
#    'urgency': 3}}]

# %% [markdown]
# This Notebook application connects to Real-Time Advanced Distribution Server via the WebSocket connection, then consumes TRNA Data as MRN data domain. When the Notebook receives TRNA data from Real-Time Advanced Distribution Server, it assembles, decodes MRN textual News Analytics message and keeps them in ```_trna_messages``` [list](https://docs.python.org/3.7/tutorial/datastructures.html#more-on-lists) variable. You can get each TRNA JSON message and associate analytics fields from this variable.

# %% [markdown]
# ## News Analytics Data Model Overview
#
# The structure of the data within each data feed is defined in the following sections. After assembly and decompression, the data appears as JSON in UTF-8.
#
# You can find the full detail of News Analytics Data Models and Fields in *User Guide* section of [My LSEG's News Analytics page](https://myaccount.lseg.com/en/product/machine-readable-news-analytics).
#
# The News Analytics feed has three top-level items:
# - *id*: The value of this field is in ```[feedFamilyCode]:[sourceId]``` format.
# - *analytics*: Analytics Groups sub-group containing the analytics scores
# - *newsItem*: This group contains metadata sourced directly from the STORY item, in contrast to the newsItem group also inside the analytics group that contains data derived from the TRNA scoring.

# %%
analytics_id  = _trna_messages[0]["id"]
print("Analytics id: ", analytics_id)
# Out:
# Analytics id:  tr:BSE4YTRrJ_2511052T1z0HN8/9d8ErWcEnrjyhBnQWl0h5JAkypZ2K

# %% [markdown]
# ### News Item Group (Top-Level Group)
#
# The News Analytics feed contains two news item groups. This top-level group contains values which are contained within the news item being processed; the other group (above section) within the analytics group contains values derived from the news item by the analytics system.
#
# Because the fields below are sourced from the incoming news item data and mapped to the below fields, those mappings can vary by the feedFamilyCode value. Those mappings are distinguished in the Notes section in the below table.
#
# Example Fields:
# - ```dataType```: The broad type of data the news item belongs to. One of "News", "Social"
# - ```feedFamilyCode```: A code that identifies the family of feeds the news item came from. Thomson Reuters feeds = "tr"
# - ```headline```: The headline text of the news item.
# - ```sourceTimestamp```: UTC timestamp of this news item. Millisecond precision. The source of this data varies by the feedFamilyCode value.
# - ```provider```: Identifier for the organization which provided the news item. The source of this data varies by the feedFamilyCode value.
#     * "tr": from provider field
#     * "mrvr": from sourceName or publisher field
# - ```urgency```: Differentiates story types. 1: alert, 3: article

# %%
news_item  = _trna_messages[0]["newsItem"]

# %%
print("dataType: ", news_item["dataType"])
print("Headline: ", news_item["headline"])
print("sourceTimestamp: ", news_item["sourceTimestamp"])
print("feedFamilyCode: ", news_item["feedFamilyCode"])
print("provider: ", news_item["provider"][3:]) # news_item["provider"] == NS:RTRS
print("urgency: ", news_item["urgency"], " : ", 
      (lambda item_type: "alert" if 1 else "article")(news_item["urgency"]))
# Out:
# dataType:  News
# Headline:  Mercury Laboratories Ltd - 538964 - Board Meeting Intimation for Approval Of The Unaudited Financial Results For The Quarter And Half Year Ended On September 30, 2025 Scheduled To Be Held On November 11, 2025
# sourceTimestamp:  2025-11-05T04:51:03.803Z
# feedFamilyCode:  tr
# provider:  BSE
# urgency:  3  :  alert

# %%
analytic_scores_group = _trna_messages[0]["analytics"]["analyticsScores"]

# %% [markdown]
# ### Analytics Score Group
#
# Each analytics score group contains all the analytics information derived from the news item for a specific asset as a simple group of named values.
#
# Example Fields:
# - ```assetClass```: The broad class that the asset belongs to. Also describes the type of TRTS sentiment engine used in the scoring.
#     * Either "CMPNY" for a company or "COM" for a commodity.
#     * Set to “CMPNY” for document-level scores because of use of the same scoring engine as used for company-level scores.
# - ```assetCodes```: List of prefixed codes, in conjunction with assetId field below, which identify the asset within various symbologies.
#
#     * By assetClass value:
#     “CMPNY”: “P:” prefix for PermID and “R:” for RIC. Can contain multiple RICs for a single company, including the primary one and those tagged to the news item.
#
#     * “COM”: “N2” for topic code
# - ```assetId```: Primary identifier for the asset. PermID for company and topic code for commodity.
# - ```assetName```: A human readable name for the asset, used as an identifier for unknown entity scoring.
# - ```brokerAction```: Denotes whether the news item is reporting the action of a broker recommendation for a security issued by the company.
#
#     * One of "UPGRADE", "DOWNGRADE", "MAINTAIN", "BROKER", "INITIATE", "UNDEFINED"
# - ```firstMentionSentence```: The first sentence, starting with the headline, in which the scored asset is mentioned. Thus, a value of 1 denotes the headline, 2 the first sentence of the story body, 3 the second sentence, etc.
# - ```priceTargetIndicator```: When the news item is a price target indicator for the asset.
#
#     * One of "INCREASE", "DECREASE", "MAINTAIN", "BROKER", "INITIATE", "UNDEFINED"
#     * Set to “UNDEFINED” for all Japanese-language and document-level scores.
# - ```relevance```: A decimal number indicating the relevance of the news item to the asset. It ranges from 0 to 1.
# - ```sentimentClass```: This field indicates the predominant sentiment class for this news item with respect to this asset. The indicated class is the one with the highest probability.
#     * 1: Positive
#     * 0: Neutral
#     * -1: Negative
# - ```sentimentNegative```: The probability that the sentiment of the news item was negative for the asset.
# - ```sentimentNeutral```: The probability that the sentiment of the news item was neutral for the asset.
# - ```sentimentPositive```: The probability that the sentiment of the news item was positive for the asset.
# - ```sentimentWordCount```: The number of lexical tokens (words and punctuation) in the sections of the item text that are deemed relevant to the asset.

# %% [markdown]
# #### TRNA Analytics Group Processing functions

# %%
def get_permid(asset_codes):
    for code in asset_codes:
        if code[:2] == "P:":
            return code[2:]

def get_company(asset_codes):
    company = [code[2:] for code in asset_codes if code[:2] == "R:"]
    return " ".join(company)

def get_topic_code(asset_codes):
    topic = [code[3:] for code in asset_codes if code[:3] == "N2:"]
    return " ".join(topic)

# %%
# Analytics Group Fields

asset_class = None
asset_codes = None
sentiment_class = {-1: 'Negative', 0: 'Neutral', 1: 'Postivie'}

for analytic_score in analytic_scores_group:
    if analytic_score["assetClass"]:
        asset_class = analytic_score["assetClass"]
        asset_codes = analytic_score["assetCodes"]
        print("assetClass: ", asset_class)
        print("assetCodes: ", asset_codes)
        if asset_class == "CMPNY":
            print("PermID: ", get_permid(asset_codes))
            print("Co: ", get_company(asset_codes))
        elif asset_class == "COM":
            print("Topic Codes: ", get_topic_code(asset_codes))
        print("assetId: ", analytic_score["assetId"])
        print("assetName: ", analytic_score["assetName"])
        print("brokerAction: ", analytic_score["brokerAction"])
        print("relevance: ",analytic_score["relevance"])
        print("sentimentClass: ", analytic_score["sentimentClass"], 
              ":", sentiment_class[analytic_score["sentimentClass"]] )
        print("sentimentPositive: ", analytic_score["sentimentPositive"])
        print("sentimentNeutral: ", analytic_score["sentimentNeutral"])
        print("sentimentNegative: ", analytic_score["sentimentNegative"])
        print("priceTargetIndicator: ", analytic_score["priceTargetIndicator"])
        print("firstMentionSentence: ", analytic_score["firstMentionSentence"])
        print("sentimentWordCount: ", analytic_score["sentimentWordCount"])
        print("--------------------------------------------------------")
# Out:
# assetClass:  CMPNY
# assetCodes:  ['P:4296689152', 'R:MRCU.BO', 'R:MRCU.INx']
# PermID:  4296689152
# Co:  MRCU.BO MRCU.INx
# assetId:  4296689152
# assetName:  Mercury Laboratories Ltd
# brokerAction:  UNDEFINED
# relevance:  1.0
# sentimentClass:  1 : Postivie
# sentimentPositive:  0.544396
# sentimentNeutral:  0.447781
# sentimentNegative:  0.00782282
# priceTargetIndicator:  UNDEFINED
# firstMentionSentence:  1
# sentimentWordCount:  82
# --------------------------------------------------------

# %% [markdown]
# ### Windowed Count Group
#
# The windowed count group is used to associate a count with the window of time it relates to. It is used for the noveltyCounts and volumeCounts.
#
# #### Novelty Counts
#
# The novelty of the content within a news item on a particular asset is calculated by comparing it with the asset-specific text over a cache of previous news items that contain the asset.
#
# The comparison between items is done using a linguistic fingerprint. If the news items are similar, they are termed as being “linked”. As a result, a content item can “link” only to an item of the same language.
#
# There are five historical periods that are used in the comparison. The default periods are 12 hours, 24 hours, 3 days, 5 days and 7 days prior to the news item’s timestamp.
#
# #### Volume Counts
#
# The volume of news for each asset is calculated. A cache of previous news items is maintained and the number of news items that mention the asset within each of five historical periods is calculated. The cache is language-specific, e.g., a volumeCount on an English-language item measures the number of other English-language items in that historical period.
#
# By default, the historical periods are 12 hours, 24 hours, 3 days, 5 days and 7 days prior to the news item’s timestamp and are the same used in the novelty calculations. Thus, direct comparisons between similar and total items within the historical periods can be achieved.
#
# Example Fields:
# - ```itemCount```: Number of items
# - ```window```: Length of time the count covers nH (for hours) or nD (for days). Default values are “12H”, “24H”, “3D”, “5D”, and “7D”.

# %% [markdown]
# #### TRNA Windowed Count Processing functions

# %%
def windowsed_count_group(group):
    for item in group:
        print("itemCount: ", item["itemCount"])
        print("window: ", item["window"])

# %%
# Windowed Count - Analytics Group Fields

for analytic_score in analytic_scores_group:
    print("Novelty Counts:\n")
    windowsed_count_group(analytic_score["noveltyCounts"])
    print("--------------------------------------------------------")
    print("Volumn Counts:\n")
    windowsed_count_group(analytic_score["volumeCounts"])
    print("--------------------------------------------------------")
# Out:
# Novelty Counts:
#
# itemCount:  0
# window:  12H
# itemCount:  0
# window:  24H
# itemCount:  0
# window:  3D
# itemCount:  0
# window:  5D
# itemCount:  0
# window:  7D
# --------------------------------------------------------
# Volumn Counts:
#
# itemCount:  0
# window:  12H
# itemCount:  1
# window:  24H
# itemCount:  1
# window:  3D
# itemCount:  1
# window:  5D
# itemCount:  1
# window:  7D
# --------------------------------------------------------

# %% [markdown]
# ### Linked Id Group
#
# The linked id group is used to associate an id with its position in a longer list of ids. It is used for the linkedIds.
# This group is not populated for document-level scores, since novelty is not calculated.
#
# Example Fields:
# - ```idPosition```: Position of the linkedId in the complete list of linked Ids. 0 is the first/oldest, and the largest/most recent is the 7-day itemCount minus 1.
# - ```linkedId```: id of the item at this position

# %%
linked_id_group = None

for analytic_score in analytic_scores_group:
    print("Linked Id Group: ")
    linked_id_group = analytic_score["linkedIds"]
    if linked_id_group:
        for linked_id in linked_id_group:
            print("idPosition: ", linked_id["idPosition"])
            print("linkedId: ", linked_id["linkedId"])
# Out:
# Linked Id Group:

# %% [markdown]
# ### News Item Group (Analytics Sub-group)
#
# The TRNA feed contains two news item groups. This group, within the analytics group, contains values derived from the news item by the analytics system.
#
# Example Fields:
# - ```companyCount```: The number of companies explicitly listed in the news item in the subjects field
# - ```exchangeAction```: One of "IMBALANCE", "HALT", "RESUME", "BLOCK TRADE", "INDICATION", "UNDEFINED".
#     * Set to “UNDEFINED” for all Japanese-language scores.
# - ```marketCommentary```: Indicator that the item is discussing general market conditions, such as “After the Bell” summaries.
# - ```sentenceCount```: The total number of sentences in the news item.
# - ```wordCount```: The total number of lexical tokens (words and punctuation) in the news item.

# %%
news_item_groups = _trna_messages[0]["analytics"]["newsItem"]

# %%
print("companyCount: ", news_item_groups["companyCount"])
print("exchangeAction: ", news_item_groups["exchangeAction"])
print("marketCommentary: ", news_item_groups["marketCommentary"])
print("sentenceCount: ", news_item_groups["sentenceCount"])
print("wordCount: ", news_item_groups["wordCount"])
# Out:
# companyCount:  1
# exchangeAction:  UNDEFINED
# marketCommentary:  False
# sentenceCount:  3
# wordCount:  83

# %% [markdown]
# ## Next Steps
#
# Once the application can retrieve each News Analytics field data from the Real-Time platform, the application needs to implement a business logic to collect and analyze those data based on interested Analytics asset. Please see the examples of how to use each asset below:
# - *Sentiment*: Positive sentiment typically leads to asset price rise, negative sentiment to a decline
# - *Relevance*: Filter out News Analytics records with low relevance
# - *Novelty*: Filter out News Analytics records that are similar to more than 0 or 1 recent news items
# - *Volume*: A sudden spike in overall news volume often leads to increased trading volume and volatility
#
# For more detail regarding each asset usage and information, please check [News Analytics Product page](https://myaccount.lseg.com/en/product/machine-readable-news-analytics).

# %% [markdown]
# ## References
#
# For further details, please check out the following resources:
#
# - [LSEG Real-Time products family page](https://developers.lseg.com/en/use-cases-catalog/real-time) on the [LSEG Developers Community](https://developers.lseg.com/) website.
# - [WebSocket API page](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/websocket-api).
# - [Developer Webinar Recording: Introduction to Electron WebSocket API](https://www.youtube.com/watch?v=CDKWMsIQfaw).
# - [News Analytics Product page](https://myaccount.lseg.com/en/product/machine-readable-news-analytics).
# - [Introduction to Machine Readable News with WebSocket API](https://developers.lseg.com/en/article-catalog/article/introduction-machine-readable-news-elektron-websocket-api-refinitiv).
# - [Introduction to Machine Readable News (MRN) with Enterprise Message API (EMA)](https://developers.lseg.com/en/article-catalog/article/introduction-machine-readable-news-mrn-elektron-message-api-ema).
# - [MRN Data Models and Real-Time SDK Implementation Guide](https://developers.lseg.com/en/api-catalog/real-time-opnsrc/rt-sdk-java/documentation#mrn-data-models-and-elektron-implementation-guide).
# - [MRN (Real-Time News) WebSocket Python example on GitHub](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.Python.MRN).
# - [MRN (Real-Time News) WebSocket Python Console example on GitHub](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.Python.MRN.RTO)
# - [MRN WebSocket JavaScript example on GitHub](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.Javascript.NewsMonitor).
# - [MRN WebSocket C# NewsViewer example on GitHub](https://github.com/LSEG-API-Samples/Example.WebSocketAPI.CSharp.MRNWebSocketViewer).
# - [Real-Time WebSocket API: The Real-Time Optimized Version 2 Authentication Migration Guide](https://developers.lseg.com/en/article-catalog/article/webSocket-api-rto-v2-authentication-migration-guide).
# - [Migrating the WebSocket Machine Readable News Application to Version 2 Authentication](https://developers.lseg.com/en/article-catalog/article/migrating-the-websocket-machine-readable-news-to-rto-v2).
#
# For any question related to this example or WebSocket API, please use the Developer Community [Q&A Forum](https://community.developers.refinitiv.com).
